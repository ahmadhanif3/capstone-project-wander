# %%
import pandas as pd
import os
import shutil

# %%
base_path = 'TA_DS'
clean_path = 'TA_DS_clean'

os.makedirs(clean_path)

# %%
for dirpath, dirnames, files in os.walk(base_path, topdown=False):  # Ensures directories are walked from the bottom-up
    # Initialize an empty list to store DataFrames
    dataframes = []
    
    for file in files:
        # Check if the file is a CSV
        if file.endswith('.csv'):
            # Construct full file path
            file_path = os.path.join(dirpath, file)
            # Read the CSV file
            df = pd.read_csv(file_path)
            # Append the DataFrame to the list
            dataframes.append(df)
    
    # Check if there are any DataFrames to concatenate
    if dataframes:
        # Concatenate all DataFrames in the list
        merged_df = pd.concat(dataframes, ignore_index=True)
        
        # Ensure dirpath is not the base path itself but one of its subdirectories
        if dirpath != base_path:
            output_filename = os.path.basename(dirpath) + '.csv'
            output_filepath = os.path.join(clean_path, output_filename)  # Change path to clean directory
            merged_df.to_csv(output_filepath, index=False)
            print(f"Merged file created: {output_filepath}")

print("All directories processed.")
# Out:
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Barat_Daya.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Besar.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Jaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Singkil.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Tamiang.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Tenggara.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Aceh_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Agam.csv
# Merged file created: TA_DS_clean\Kabupaten_Alor.csv
# Merged file created: TA_DS_clean\Kabupaten_Asahan.csv
# Merged file created: TA_DS_clean\Kabupaten_Asmat.csv
# Merged file created: TA_DS_clean\Kabupaten_Badung.csv
# Merged file created: TA_DS_clean\Kabupaten_Balangan.csv
# Merged file created: TA_DS_clean\Kabupaten_Bandung.csv
# Merged file created: TA_DS_clean\Kabupaten_Bandung_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Banggai.csv
# Merged file created: TA_DS_clean\Kabupaten_Banggai_Kepulauan.csv
# Merged file created: TA_DS_clean\Kabupaten_Banggai_Laut.csv
# Merged file created: TA_DS_clean\Kabupaten_Bangka.csv
# Merged file created: TA_DS_clean\Kabupaten_Bangkalan.csv
# Merged file created: TA_DS_clean\Kabupaten_Bangka_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Bangka_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Bangka_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Bangli.csv
# Merged file created: TA_DS_clean\Kabupaten_Banjar.csv
# Merged file created: TA_DS_clean\Kabupaten_Banjarnegara.csv
# Merged file created: TA_DS_clean\Kabupaten_Bantaeng.csv
# Merged file created: TA_DS_clean\Kabupaten_Banyuasin.csv
# Merged file created: TA_DS_clean\Kabupaten_Banyumas.csv
# Merged file created: TA_DS_clean\Kabupaten_Banyuwangi.csv
# Merged file created: TA_DS_clean\Kabupaten_Barito_Kuala.csv
# Merged file created: TA_DS_clean\Kabupaten_Barito_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Barito_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Barito_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Barru.csv
# Merged file created: TA_DS_clean\Kabupaten_Batang.csv
# Merged file created: TA_DS_clean\Kabupaten_Batang_Hari.csv
# Merged file created: TA_DS_clean\Kabupaten_Batu_Bara.csv
# Merged file created: TA_DS_clean\Kabupaten_Bekasi.csv
# Merged file created: TA_DS_clean\Kabupaten_Belitung.csv
# Merged file created: TA_DS_clean\Kabupaten_Belitung_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Belu.csv
# Merged file created: TA_DS_clean\Kabupaten_Bener_Meriah.csv
# Merged file created: TA_DS_clean\Kabupaten_Bengkalis.csv
# Merged file created: TA_DS_clean\Kabupaten_Bengkayang.csv
# Merged file created: TA_DS_clean\Kabupaten_Berau.csv
# Merged file created: TA_DS_clean\Kabupaten_Bima.csv
# Merged file created: TA_DS_clean\Kabupaten_Bintan.csv
# Merged file created: TA_DS_clean\Kabupaten_Bireuen.csv
# Merged file created: TA_DS_clean\Kabupaten_Blitar.csv
# Merged file created: TA_DS_clean\Kabupaten_Blora.csv
# Merged file created: TA_DS_clean\Kabupaten_Boalemo.csv
# Merged file created: TA_DS_clean\Kabupaten_Bogor.csv
# Merged file created: TA_DS_clean\Kabupaten_Bojonegoro.csv
# Merged file created: TA_DS_clean\Kabupaten_Bolaang_Mongondow.csv
# Merged file created: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Bombana.csv
# Merged file created: TA_DS_clean\Kabupaten_Bondowoso.csv
# Merged file created: TA_DS_clean\Kabupaten_Bone.csv
# Merged file created: TA_DS_clean\Kabupaten_Bone_Bolango.csv
# Merged file created: TA_DS_clean\Kabupaten_Boven_Digoel.csv
# Merged file created: TA_DS_clean\Kabupaten_Boyolali.csv
# Merged file created: TA_DS_clean\Kabupaten_Brebes.csv
# Merged file created: TA_DS_clean\Kabupaten_Buleleng.csv
# Merged file created: TA_DS_clean\Kabupaten_Bulukumba.csv
# Merged file created: TA_DS_clean\Kabupaten_Bulungan.csv
# Merged file created: TA_DS_clean\Kabupaten_Bungo.csv
# Merged file created: TA_DS_clean\Kabupaten_Buol.csv
# Merged file created: TA_DS_clean\Kabupaten_Buru.csv
# Merged file created: TA_DS_clean\Kabupaten_Buru_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Buton.csv
# Merged file created: TA_DS_clean\Kabupaten_Buton_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Ciamis.csv
# Merged file created: TA_DS_clean\Kabupaten_Cianjur.csv
# Merged file created: TA_DS_clean\Kabupaten_Cilacap.csv
# Merged file created: TA_DS_clean\Kabupaten_Cirebon.csv
# Merged file created: TA_DS_clean\Kabupaten_Dairi.csv
# Merged file created: TA_DS_clean\Kabupaten_Deiyai.csv
# Merged file created: TA_DS_clean\Kabupaten_Deli_Serdang.csv
# Merged file created: TA_DS_clean\Kabupaten_Demak.csv
# Merged file created: TA_DS_clean\Kabupaten_Dharmasraya.csv
# Merged file created: TA_DS_clean\Kabupaten_Dogiyai.csv
# Merged file created: TA_DS_clean\Kabupaten_Dompu.csv
# Merged file created: TA_DS_clean\Kabupaten_Donggala.csv
# Merged file created: TA_DS_clean\Kabupaten_Empat_Lawang.csv
# Merged file created: TA_DS_clean\Kabupaten_Ende.csv
# Merged file created: TA_DS_clean\Kabupaten_Enrekang.csv
# Merged file created: TA_DS_clean\Kabupaten_Fakfak.csv
# Merged file created: TA_DS_clean\Kabupaten_Flores_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Garut.csv
# Merged file created: TA_DS_clean\Kabupaten_Gayo_Lues.csv
# Merged file created: TA_DS_clean\Kabupaten_Gianyar.csv
# Merged file created: TA_DS_clean\Kabupaten_Gorontalo.csv
# Merged file created: TA_DS_clean\Kabupaten_Gorontalo_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Gowa.csv
# Merged file created: TA_DS_clean\Kabupaten_Gresik.csv
# Merged file created: TA_DS_clean\Kabupaten_Grobogan.csv
# Merged file created: TA_DS_clean\Kabupaten_Gunung_Mas.csv
# Merged file created: TA_DS_clean\Kabupaten_Halmahera_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Halmahera_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Halmahera_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Halmahera_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Hulu_Sungai_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Hulu_Sungai_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Hulu_Sungai_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Humbang_Hasundutan.csv
# Merged file created: TA_DS_clean\Kabupaten_Indragiri_Hilir.csv
# Merged file created: TA_DS_clean\Kabupaten_Indragiri_Hulu.csv
# Merged file created: TA_DS_clean\Kabupaten_Indramayu.csv
# Merged file created: TA_DS_clean\Kabupaten_Intan_Jaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Jayapura.csv
# Merged file created: TA_DS_clean\Kabupaten_Jayawijaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Jember.csv
# Merged file created: TA_DS_clean\Kabupaten_Jembrana.csv
# Merged file created: TA_DS_clean\Kabupaten_Jeneponto.csv
# Merged file created: TA_DS_clean\Kabupaten_Jepara.csv
# Merged file created: TA_DS_clean\Kabupaten_Jombang.csv
# Merged file created: TA_DS_clean\Kabupaten_Kaimana.csv
# Merged file created: TA_DS_clean\Kabupaten_Kampar.csv
# Merged file created: TA_DS_clean\Kabupaten_Kapuas.csv
# Merged file created: TA_DS_clean\Kabupaten_Kapuas_Hulu.csv
# Merged file created: TA_DS_clean\Kabupaten_Karanganyar.csv
# Merged file created: TA_DS_clean\Kabupaten_Karangasem.csv
# Merged file created: TA_DS_clean\Kabupaten_Karawang.csv
# Merged file created: TA_DS_clean\Kabupaten_Karimun.csv
# Merged file created: TA_DS_clean\Kabupaten_Karo.csv
# Merged file created: TA_DS_clean\Kabupaten_Katingan.csv
# Merged file created: TA_DS_clean\Kabupaten_Kayong_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Kebumen.csv
# Merged file created: TA_DS_clean\Kabupaten_Kediri.csv
# Merged file created: TA_DS_clean\Kabupaten_Keerom.csv
# Merged file created: TA_DS_clean\Kabupaten_Kendal.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Aru.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Mentawai.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Meranti.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Sangihe.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Selayar.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Sula.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Talaud.csv
# Merged file created: TA_DS_clean\Kabupaten_Kepulauan_Yapen.csv
# Merged file created: TA_DS_clean\Kabupaten_Kerinci.csv
# Merged file created: TA_DS_clean\Kabupaten_Ketapang.csv
# Merged file created: TA_DS_clean\Kabupaten_Klaten.csv
# Merged file created: TA_DS_clean\Kabupaten_Klungkung.csv
# Merged file created: TA_DS_clean\Kabupaten_Kolaka.csv
# Merged file created: TA_DS_clean\Kabupaten_Kolaka_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Kolaka_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Konawe.csv
# Merged file created: TA_DS_clean\Kabupaten_Konawe_Kepulauan.csv
# Merged file created: TA_DS_clean\Kabupaten_Konawe_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Konawe_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Kotabaru.csv
# Merged file created: TA_DS_clean\Kabupaten_Kotawaringin_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Kotawaringin_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Kuantan_Singingi.csv
# Merged file created: TA_DS_clean\Kabupaten_Kubu_Raya.csv
# Merged file created: TA_DS_clean\Kabupaten_Kudus.csv
# Merged file created: TA_DS_clean\Kabupaten_Kuningan.csv
# Merged file created: TA_DS_clean\Kabupaten_Kupang.csv
# Merged file created: TA_DS_clean\Kabupaten_Kutai_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Kutai_Kartanegara.csv
# Merged file created: TA_DS_clean\Kabupaten_Kutai_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Labuhanbatu.csv
# Merged file created: TA_DS_clean\Kabupaten_Labuhanbatu_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Labuhanbatu_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Lahat.csv
# Merged file created: TA_DS_clean\Kabupaten_Lamandau.csv
# Merged file created: TA_DS_clean\Kabupaten_Lamongan.csv
# Merged file created: TA_DS_clean\Kabupaten_Lampung_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Lampung_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Lampung_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Lampung_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Lampung_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Landak.csv
# Merged file created: TA_DS_clean\Kabupaten_Langkat.csv
# Merged file created: TA_DS_clean\Kabupaten_Lanny_Jaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Lebak.csv
# Merged file created: TA_DS_clean\Kabupaten_Lembata.csv
# Merged file created: TA_DS_clean\Kabupaten_Lima_Puluh_Kota.csv
# Merged file created: TA_DS_clean\Kabupaten_Lingga.csv
# Merged file created: TA_DS_clean\Kabupaten_Lombok_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Lombok_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Lombok_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Lombok_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Lumajang.csv
# Merged file created: TA_DS_clean\Kabupaten_Luwu.csv
# Merged file created: TA_DS_clean\Kabupaten_Luwu_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Luwu_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Madiun.csv
# Merged file created: TA_DS_clean\Kabupaten_Magelang.csv
# Merged file created: TA_DS_clean\Kabupaten_Magetan.csv
# Merged file created: TA_DS_clean\Kabupaten_Mahakam_Ulu.csv
# Merged file created: TA_DS_clean\Kabupaten_Majalengka.csv
# Merged file created: TA_DS_clean\Kabupaten_Majene.csv
# Merged file created: TA_DS_clean\Kabupaten_Malaka.csv
# Merged file created: TA_DS_clean\Kabupaten_Malang.csv
# Merged file created: TA_DS_clean\Kabupaten_Malinau.csv
# Merged file created: TA_DS_clean\Kabupaten_Maluku_Barat_Daya.csv
# Merged file created: TA_DS_clean\Kabupaten_Maluku_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Maluku_Tenggara.csv
# Merged file created: TA_DS_clean\Kabupaten_Maluku_Tenggara_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Mamasa.csv
# Merged file created: TA_DS_clean\Kabupaten_Mamberamo_Raya.csv
# Merged file created: TA_DS_clean\Kabupaten_Mamberamo_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Mamuju.csv
# Merged file created: TA_DS_clean\Kabupaten_Mamuju_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Mandailing_Natal.csv
# Merged file created: TA_DS_clean\Kabupaten_Manggarai.csv
# Merged file created: TA_DS_clean\Kabupaten_Manggarai_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Manggarai_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Manokwari.csv
# Merged file created: TA_DS_clean\Kabupaten_Manokwari_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Mappi.csv
# Merged file created: TA_DS_clean\Kabupaten_Maros.csv
# Merged file created: TA_DS_clean\Kabupaten_Maybrat.csv
# Merged file created: TA_DS_clean\Kabupaten_Melawi.csv
# Merged file created: TA_DS_clean\Kabupaten_Mempawah.csv
# Merged file created: TA_DS_clean\Kabupaten_Merangin.csv
# Merged file created: TA_DS_clean\Kabupaten_Merauke.csv
# Merged file created: TA_DS_clean\Kabupaten_Mesuji.csv
# Merged file created: TA_DS_clean\Kabupaten_Mimika.csv
# Merged file created: TA_DS_clean\Kabupaten_Minahasa.csv
# Merged file created: TA_DS_clean\Kabupaten_Minahasa_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Minahasa_Tenggara.csv
# Merged file created: TA_DS_clean\Kabupaten_Minahasa_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Mojokerto.csv
# Merged file created: TA_DS_clean\Kabupaten_Morowali.csv
# Merged file created: TA_DS_clean\Kabupaten_Morowali_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Muara_Enim.csv
# Merged file created: TA_DS_clean\Kabupaten_Muaro_Jambi.csv
# Merged file created: TA_DS_clean\Kabupaten_Muna.csv
# Merged file created: TA_DS_clean\Kabupaten_Muna_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Murung_Raya.csv
# Merged file created: TA_DS_clean\Kabupaten_Musi_Banyuasin.csv
# Merged file created: TA_DS_clean\Kabupaten_Musi_Rawas.csv
# Merged file created: TA_DS_clean\Kabupaten_Musi_Rawas_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Nabire.csv
# Merged file created: TA_DS_clean\Kabupaten_Nagan_Raya.csv
# Merged file created: TA_DS_clean\Kabupaten_Nagekeo.csv
# Merged file created: TA_DS_clean\Kabupaten_Natuna.csv
# Merged file created: TA_DS_clean\Kabupaten_Nduga.csv
# Merged file created: TA_DS_clean\Kabupaten_Ngada.csv
# Merged file created: TA_DS_clean\Kabupaten_Nganjuk.csv
# Merged file created: TA_DS_clean\Kabupaten_Ngawi.csv
# Merged file created: TA_DS_clean\Kabupaten_Nias.csv
# Merged file created: TA_DS_clean\Kabupaten_Nias_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Nias_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Nias_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Nunukan.csv
# Merged file created: TA_DS_clean\Kabupaten_Ogan_Ilir.csv
# Merged file created: TA_DS_clean\Kabupaten_Ogan_Komering_Ilir.csv
# Merged file created: TA_DS_clean\Kabupaten_Ogan_Komering_Ulu.csv
# Merged file created: TA_DS_clean\Kabupaten_Ogan_Komering_Ulu_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Ogan_Komering_Ulu_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Pacitan.csv
# Merged file created: TA_DS_clean\Kabupaten_Padang_Lawas.csv
# Merged file created: TA_DS_clean\Kabupaten_Padang_Lawas_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Padang_Pariaman.csv
# Merged file created: TA_DS_clean\Kabupaten_Pakpak_Bharat.csv
# Merged file created: TA_DS_clean\Kabupaten_Pamekasan.csv
# Merged file created: TA_DS_clean\Kabupaten_Pandeglang.csv
# Merged file created: TA_DS_clean\Kabupaten_Pangandaran.csv
# Merged file created: TA_DS_clean\Kabupaten_Pangkajene_Dan_Kepulauan.csv
# Merged file created: TA_DS_clean\Kabupaten_Paniai.csv
# Merged file created: TA_DS_clean\Kabupaten_Parigi_Moutong.csv
# Merged file created: TA_DS_clean\Kabupaten_Pasaman.csv
# Merged file created: TA_DS_clean\Kabupaten_Pasaman_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Paser.csv
# Merged file created: TA_DS_clean\Kabupaten_Pasuruan.csv
# Merged file created: TA_DS_clean\Kabupaten_Pati.csv
# Merged file created: TA_DS_clean\Kabupaten_Pegunungan_Bintang.csv
# Merged file created: TA_DS_clean\Kabupaten_Pekalongan.csv
# Merged file created: TA_DS_clean\Kabupaten_Pelalawan.csv
# Merged file created: TA_DS_clean\Kabupaten_Pemalang.csv
# Merged file created: TA_DS_clean\Kabupaten_Penajam_Paser_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Penukal_Abab_Lematang_Ilir.csv
# Merged file created: TA_DS_clean\Kabupaten_Pesawaran.csv
# Merged file created: TA_DS_clean\Kabupaten_Pesisir_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Pesisir_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Pidie.csv
# Merged file created: TA_DS_clean\Kabupaten_Pidie_Jaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Pinrang.csv
# Merged file created: TA_DS_clean\Kabupaten_Pohuwato.csv
# Merged file created: TA_DS_clean\Kabupaten_Polewali_Mandar.csv
# Merged file created: TA_DS_clean\Kabupaten_Ponorogo.csv
# Merged file created: TA_DS_clean\Kabupaten_Poso.csv
# Merged file created: TA_DS_clean\Kabupaten_Pringsewu.csv
# Merged file created: TA_DS_clean\Kabupaten_Probolinggo.csv
# Merged file created: TA_DS_clean\Kabupaten_Pulang_Pisau.csv
# Merged file created: TA_DS_clean\Kabupaten_Pulau_Morotai.csv
# Merged file created: TA_DS_clean\Kabupaten_Puncak.csv
# Merged file created: TA_DS_clean\Kabupaten_Puncak_Jaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Purbalingga.csv
# Merged file created: TA_DS_clean\Kabupaten_Purwakarta.csv
# Merged file created: TA_DS_clean\Kabupaten_Purworejo.csv
# Merged file created: TA_DS_clean\Kabupaten_Raja_Ampat.csv
# Merged file created: TA_DS_clean\Kabupaten_Rembang.csv
# Merged file created: TA_DS_clean\Kabupaten_Rokan_Hilir.csv
# Merged file created: TA_DS_clean\Kabupaten_Rokan_Hulu.csv
# Merged file created: TA_DS_clean\Kabupaten_Rote_Ndao.csv
# Merged file created: TA_DS_clean\Kabupaten_Sabu_Raijua.csv
# Merged file created: TA_DS_clean\Kabupaten_Sambas.csv
# Merged file created: TA_DS_clean\Kabupaten_Samosir.csv
# Merged file created: TA_DS_clean\Kabupaten_Sampang.csv
# Merged file created: TA_DS_clean\Kabupaten_Sanggau.csv
# Merged file created: TA_DS_clean\Kabupaten_Sarmi.csv
# Merged file created: TA_DS_clean\Kabupaten_Sarolangun.csv
# Merged file created: TA_DS_clean\Kabupaten_Sekadau.csv
# Merged file created: TA_DS_clean\Kabupaten_Semarang.csv
# Merged file created: TA_DS_clean\Kabupaten_Seram_Bagian_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Seram_Bagian_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Serang.csv
# Merged file created: TA_DS_clean\Kabupaten_Serdang_Bedagai.csv
# Merged file created: TA_DS_clean\Kabupaten_Seruyan.csv
# Merged file created: TA_DS_clean\Kabupaten_Siak.csv
# Merged file created: TA_DS_clean\Kabupaten_Sidenreng_Rappang.csv
# Merged file created: TA_DS_clean\Kabupaten_Sidoarjo.csv
# Merged file created: TA_DS_clean\Kabupaten_Sigi.csv
# Merged file created: TA_DS_clean\Kabupaten_Sijunjung.csv
# Merged file created: TA_DS_clean\Kabupaten_Sikka.csv
# Merged file created: TA_DS_clean\Kabupaten_Simalungun.csv
# Merged file created: TA_DS_clean\Kabupaten_Simeulue.csv
# Merged file created: TA_DS_clean\Kabupaten_Sinjai.csv
# Merged file created: TA_DS_clean\Kabupaten_Sintang.csv
# Merged file created: TA_DS_clean\Kabupaten_Situbondo.csv
# Merged file created: TA_DS_clean\Kabupaten_Solok.csv
# Merged file created: TA_DS_clean\Kabupaten_Solok_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Soppeng.csv
# Merged file created: TA_DS_clean\Kabupaten_Sorong.csv
# Merged file created: TA_DS_clean\Kabupaten_Sorong_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Sragen.csv
# Merged file created: TA_DS_clean\Kabupaten_Subang.csv
# Merged file created: TA_DS_clean\Kabupaten_Sukabumi.csv
# Merged file created: TA_DS_clean\Kabupaten_Sukamara.csv
# Merged file created: TA_DS_clean\Kabupaten_Sukoharjo.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumbawa.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumbawa_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumba_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumba_Barat_Daya.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumba_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumba_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumedang.csv
# Merged file created: TA_DS_clean\Kabupaten_Sumenep.csv
# Merged file created: TA_DS_clean\Kabupaten_Supiori.csv
# Merged file created: TA_DS_clean\Kabupaten_Tabalong.csv
# Merged file created: TA_DS_clean\Kabupaten_Tabanan.csv
# Merged file created: TA_DS_clean\Kabupaten_Takalar.csv
# Merged file created: TA_DS_clean\Kabupaten_Tambrauw.csv
# Merged file created: TA_DS_clean\Kabupaten_Tanah_Bumbu.csv
# Merged file created: TA_DS_clean\Kabupaten_Tanah_Datar.csv
# Merged file created: TA_DS_clean\Kabupaten_Tanah_Laut.csv
# Merged file created: TA_DS_clean\Kabupaten_Tana_Tidung.csv
# Merged file created: TA_DS_clean\Kabupaten_Tana_Toraja.csv
# Merged file created: TA_DS_clean\Kabupaten_Tangerang.csv
# Merged file created: TA_DS_clean\Kabupaten_Tanggamus.csv
# Merged file created: TA_DS_clean\Kabupaten_Tanjung_Jabung_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Tanjung_Jabung_Timur.csv
# Merged file created: TA_DS_clean\Kabupaten_Tapanuli_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Tapanuli_Tengah.csv
# Merged file created: TA_DS_clean\Kabupaten_Tapanuli_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Tapin.csv
# Merged file created: TA_DS_clean\Kabupaten_Tasikmalaya.csv
# Merged file created: TA_DS_clean\Kabupaten_Tebo.csv
# Merged file created: TA_DS_clean\Kabupaten_Tegal.csv
# Merged file created: TA_DS_clean\Kabupaten_Teluk_Bintuni.csv
# Merged file created: TA_DS_clean\Kabupaten_Teluk_Wondama.csv
# Merged file created: TA_DS_clean\Kabupaten_Temanggung.csv
# Merged file created: TA_DS_clean\Kabupaten_Timor_Tengah_Selatan.csv
# Merged file created: TA_DS_clean\Kabupaten_Timor_Tengah_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Toba_Samosir.csv
# Merged file created: TA_DS_clean\Kabupaten_Tojo_Una_Una.csv
# Merged file created: TA_DS_clean\Kabupaten_Tolikara.csv
# Merged file created: TA_DS_clean\Kabupaten_Toli_Toli.csv
# Merged file created: TA_DS_clean\Kabupaten_Toraja_Utara.csv
# Merged file created: TA_DS_clean\Kabupaten_Trenggalek.csv
# Merged file created: TA_DS_clean\Kabupaten_Tuban.csv
# Merged file created: TA_DS_clean\Kabupaten_Tulang_Bawang.csv
# Merged file created: TA_DS_clean\Kabupaten_Tulang_Bawang_Barat.csv
# Merged file created: TA_DS_clean\Kabupaten_Tulungagung.csv
# Merged file created: TA_DS_clean\Kabupaten_Wajo.csv
# Merged file created: TA_DS_clean\Kabupaten_Wakatobi.csv
# Merged file created: TA_DS_clean\Kabupaten_Waropen.csv
# Merged file created: TA_DS_clean\Kabupaten_Way_Kanan.csv
# Merged file created: TA_DS_clean\Kabupaten_Wonogiri.csv
# Merged file created: TA_DS_clean\Kabupaten_Wonosobo.csv
# Merged file created: TA_DS_clean\Kabupaten_Yahukimo.csv
# Merged file created: TA_DS_clean\Kabupaten_Yalimo.csv
# Merged file created: TA_DS_clean\Kab_Kepulauan_Seribu.csv
# Merged file created: TA_DS_clean\Kota_Ambon.csv
# Merged file created: TA_DS_clean\Kota_Balikpapan.csv
# Merged file created: TA_DS_clean\Kota_Bandar_Lampung.csv
# Merged file created: TA_DS_clean\Kota_Banda_Aceh.csv
# Merged file created: TA_DS_clean\Kota_Bandung.csv
# Merged file created: TA_DS_clean\Kota_Banjar.csv
# Merged file created: TA_DS_clean\Kota_Banjarbaru.csv
# Merged file created: TA_DS_clean\Kota_Banjarmasin.csv
# Merged file created: TA_DS_clean\Kota_Batam.csv
# Merged file created: TA_DS_clean\Kota_Batu.csv
# Merged file created: TA_DS_clean\Kota_Baubau.csv
# Merged file created: TA_DS_clean\Kota_Bekasi.csv
# Merged file created: TA_DS_clean\Kota_Biak.csv
# Merged file created: TA_DS_clean\Kota_Bima.csv
# Merged file created: TA_DS_clean\Kota_Binjai.csv
# Merged file created: TA_DS_clean\Kota_Bitung.csv
# Merged file created: TA_DS_clean\Kota_Blitar.csv
# Merged file created: TA_DS_clean\Kota_Bogor.csv
# Merged file created: TA_DS_clean\Kota_Bontang.csv
# Merged file created: TA_DS_clean\Kota_Bukittinggi.csv
# Merged file created: TA_DS_clean\Kota_Cilegon.csv
# Merged file created: TA_DS_clean\Kota_Cimahi.csv
# Merged file created: TA_DS_clean\Kota_Cirebon.csv
# Merged file created: TA_DS_clean\Kota_Denpasar.csv
# Merged file created: TA_DS_clean\Kota_Depok.csv
# Merged file created: TA_DS_clean\Kota_Dumai.csv
# Merged file created: TA_DS_clean\Kota_Gorontalo.csv
# Merged file created: TA_DS_clean\Kota_Jakarta_Barat.csv
# Merged file created: TA_DS_clean\Kota_Jakarta_Pusat.csv
# Merged file created: TA_DS_clean\Kota_Jakarta_Selatan.csv
# Merged file created: TA_DS_clean\Kota_Jakarta_Timur.csv
# Merged file created: TA_DS_clean\Kota_Jakarta_Utara.csv
# Merged file created: TA_DS_clean\Kota_Jambi.csv
# Merged file created: TA_DS_clean\Kota_Jayapura.csv
# Merged file created: TA_DS_clean\Kota_Kediri.csv
# Merged file created: TA_DS_clean\Kota_Kendari.csv
# Merged file created: TA_DS_clean\Kota_Kupang.csv
# Merged file created: TA_DS_clean\Kota_Lubuklinggau.csv
# Merged file created: TA_DS_clean\Kota_Madiun.csv
# Merged file created: TA_DS_clean\Kota_Magelang.csv
# Merged file created: TA_DS_clean\Kota_Makassar.csv
# Merged file created: TA_DS_clean\Kota_Malang.csv
# Merged file created: TA_DS_clean\Kota_Mamuju.csv
# Merged file created: TA_DS_clean\Kota_Mamuju_Utara.csv
# Merged file created: TA_DS_clean\Kota_Manado.csv
# Merged file created: TA_DS_clean\Kota_Mataram.csv
# Merged file created: TA_DS_clean\Kota_Medan.csv
# Merged file created: TA_DS_clean\Kota_Metro.csv
# Merged file created: TA_DS_clean\Kota_Mojokerto.csv
# Merged file created: TA_DS_clean\Kota_Padang.csv
# Merged file created: TA_DS_clean\Kota_Padang_Panjang.csv
# Merged file created: TA_DS_clean\Kota_Pagar_Alam.csv
# Merged file created: TA_DS_clean\Kota_Palangka_Raya.csv
# Merged file created: TA_DS_clean\Kota_Palembang.csv
# Merged file created: TA_DS_clean\Kota_Palopo.csv
# Merged file created: TA_DS_clean\Kota_Palu.csv
# Merged file created: TA_DS_clean\Kota_Pangkal_Pinang.csv
# Merged file created: TA_DS_clean\Kota_Parepare.csv
# Merged file created: TA_DS_clean\Kota_Pariaman.csv
# Merged file created: TA_DS_clean\Kota_Pasuruan.csv
# Merged file created: TA_DS_clean\Kota_Payakumbuh.csv
# Merged file created: TA_DS_clean\Kota_Pekalongan.csv
# Merged file created: TA_DS_clean\Kota_Pekanbaru.csv
# Merged file created: TA_DS_clean\Kota_Pematang_Siantar.csv
# Merged file created: TA_DS_clean\Kota_Pontianak.csv
# Merged file created: TA_DS_clean\Kota_Prabumulih.csv
# Merged file created: TA_DS_clean\Kota_Probolinggo.csv
# Merged file created: TA_DS_clean\Kota_Salatiga.csv
# Merged file created: TA_DS_clean\Kota_Samarinda.csv
# Merged file created: TA_DS_clean\Kota_Sawahlunto.csv
# Merged file created: TA_DS_clean\Kota_Semarang.csv
# Merged file created: TA_DS_clean\Kota_Serang.csv
# Merged file created: TA_DS_clean\Kota_Singkawang.csv
# Merged file created: TA_DS_clean\Kota_Soe.csv
# Merged file created: TA_DS_clean\Kota_Sorong.csv
# Merged file created: TA_DS_clean\Kota_Sukabumi.csv
# Merged file created: TA_DS_clean\Kota_Surabaya.csv
# Merged file created: TA_DS_clean\Kota_Surakarta.csv
# Merged file created: TA_DS_clean\Kota_Taman.csv
# Merged file created: TA_DS_clean\Kota_Tangerang.csv
# Merged file created: TA_DS_clean\Kota_Tangerang_Selatan.csv
# Merged file created: TA_DS_clean\Kota_Tanjungbalai.csv
# Merged file created: TA_DS_clean\Kota_Tanjung_Pinang.csv
# Merged file created: TA_DS_clean\Kota_Tarakan.csv
# Merged file created: TA_DS_clean\Kota_Tasikmalaya.csv
# Merged file created: TA_DS_clean\Kota_Tebing_Tinggi.csv
# Merged file created: TA_DS_clean\Kota_Tegal.csv
# Merged file created: TA_DS_clean\Kota_Ternate.csv
# Merged file created: TA_DS_clean\Kota_Tidore_Kepulauan.csv
# Merged file created: TA_DS_clean\Kota_Tomohon.csv
# Merged file created: TA_DS_clean\Kota_Tual.csv
# All directories processed.

# %%
initial_columns = None
column_inconsistencies = {}
total_files = 0
extra_price_level_count = 0
missing_columns_count = 0
missing_permanently_closed_count = 0
missing_plus_code_count = 0
missing_opening_hours_count = 0

# Walk through the directory containing the CSV files
for file_name in os.listdir(clean_path):
    if file_name.endswith('.csv'):
        total_files += 1
        file_path = os.path.join(clean_path, file_name)
        
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Get the set of columns from the current DataFrame
        current_columns = set(df.columns)
        
        # If it's the first file, initialize the initial_columns set
        if initial_columns is None:
            initial_columns = current_columns
            first_file = file_name  # Keep track of the first file for reference
        else:
            # Check for differences
            if current_columns != initial_columns:
                missing_columns = initial_columns - current_columns
                extra_columns = current_columns - initial_columns
                column_inconsistencies[file_name] = {'missing': missing_columns, 'extra': extra_columns}
                if 'price_level' in extra_columns:
                    extra_price_level_count += 1
                if missing_columns:
                    missing_columns_count += 1
                    # Count specific missing columns
                    if 'permanently_closed' in missing_columns:
                        missing_permanently_closed_count += 1
                    if 'plus_code' in missing_columns:
                        missing_plus_code_count += 1
                    if 'opening_hours' in missing_columns:
                        missing_opening_hours_count += 1

# Output the results
print(f"Total files processed: {total_files}")
if not column_inconsistencies:
    print("All files have consistent columns.")
else:
    print("Inconsistencies found in the columns across files:")
    for file, diffs in column_inconsistencies.items():
        if diffs['missing']:
            print(f"{file} is missing columns: {diffs['missing']}")
        if diffs['extra']:
            print(f"{file} has extra columns: {diffs['extra']}")

print(f"Number of files with extra 'price_level' column: {extra_price_level_count}")
print(f"Number of files with missing columns: {missing_columns_count}")
print(f"Number of files missing 'permanently_closed': {missing_permanently_closed_count}")
print(f"Number of files missing 'plus_code': {missing_plus_code_count}")
print(f"Number of files missing 'opening_hours': {missing_opening_hours_count}")
# Out:
# Total files processed: 485
# Inconsistencies found in the columns across files:
# Kabupaten_Badung.csv has extra columns: {'price_level'}
# Kabupaten_Bandung.csv has extra columns: {'price_level'}
# Kabupaten_Bandung_Barat.csv has extra columns: {'price_level'}
# Kabupaten_Banggai.csv has extra columns: {'price_level'}
# Kabupaten_Bangkalan.csv has extra columns: {'price_level'}
# Kabupaten_Bangka_Barat.csv has extra columns: {'price_level'}
# Kabupaten_Bangka_Tengah.csv has extra columns: {'price_level'}
# Kabupaten_Banyumas.csv has extra columns: {'price_level'}
# Kabupaten_Banyuwangi.csv has extra columns: {'price_level'}
# Kabupaten_Batang.csv has extra columns: {'price_level'}
# Kabupaten_Bekasi.csv has extra columns: {'price_level'}
# Kabupaten_Belitung.csv has extra columns: {'price_level'}
# Kabupaten_Bima.csv has extra columns: {'price_level'}
# Kabupaten_Bintan.csv has extra columns: {'price_level'}
# Kabupaten_Blitar.csv has extra columns: {'price_level'}
# Kabupaten_Bogor.csv has extra columns: {'price_level'}
# Kabupaten_Bojonegoro.csv has extra columns: {'price_level'}
# Kabupaten_Bondowoso.csv has extra columns: {'price_level'}
# Kabupaten_Buleleng.csv has extra columns: {'price_level'}
# Kabupaten_Bulukumba.csv has extra columns: {'price_level'}
# Kabupaten_Ciamis.csv has extra columns: {'price_level'}
# Kabupaten_Cilacap.csv has extra columns: {'price_level'}
# Kabupaten_Deli_Serdang.csv has extra columns: {'price_level'}
# Kabupaten_Demak.csv has extra columns: {'price_level'}
# Kabupaten_Enrekang.csv has extra columns: {'price_level'}
# Kabupaten_Flores_Timur.csv has extra columns: {'price_level'}
# Kabupaten_Gayo_Lues.csv has extra columns: {'price_level'}
# Kabupaten_Gianyar.csv has extra columns: {'price_level'}
# Kabupaten_Gorontalo.csv has extra columns: {'price_level'}
# Kabupaten_Grobogan.csv has extra columns: {'price_level'}
# Kabupaten_Halmahera_Barat.csv is missing columns: {'permanently_closed'}
# Kabupaten_Intan_Jaya.csv is missing columns: {'plus_code'}
# Kabupaten_Jayapura.csv has extra columns: {'price_level'}
# Kabupaten_Karanganyar.csv has extra columns: {'price_level'}
# Kabupaten_Karawang.csv has extra columns: {'price_level'}
# Kabupaten_Kediri.csv has extra columns: {'price_level'}
# Kabupaten_Kendal.csv has extra columns: {'price_level'}
# Kabupaten_Kepulauan_Meranti.csv has extra columns: {'price_level'}
# Kabupaten_Klaten.csv has extra columns: {'price_level'}
# Kabupaten_Kudus.csv has extra columns: {'price_level'}
# Kabupaten_Kuningan.csv has extra columns: {'price_level'}
# Kabupaten_Lamongan.csv has extra columns: {'price_level'}
# Kabupaten_Lampung_Timur.csv has extra columns: {'price_level'}
# Kabupaten_Lebak.csv has extra columns: {'price_level'}
# Kabupaten_Lima_Puluh_Kota.csv has extra columns: {'price_level'}
# Kabupaten_Lombok_Utara.csv has extra columns: {'price_level'}
# Kabupaten_Lumajang.csv has extra columns: {'price_level'}
# Kabupaten_Malang.csv has extra columns: {'price_level'}
# Kabupaten_Melawi.csv has extra columns: {'price_level'}
# Kabupaten_Merauke.csv has extra columns: {'price_level'}
# Kabupaten_Minahasa.csv has extra columns: {'price_level'}
# Kabupaten_Minahasa_Tenggara.csv has extra columns: {'price_level'}
# Kabupaten_Mojokerto.csv has extra columns: {'price_level'}
# Kabupaten_Muara_Enim.csv has extra columns: {'price_level'}
# Kabupaten_Muaro_Jambi.csv has extra columns: {'price_level'}
# Kabupaten_Ngada.csv has extra columns: {'price_level'}
# Kabupaten_Ngawi.csv has extra columns: {'price_level'}
# Kabupaten_Padang_Pariaman.csv has extra columns: {'price_level'}
# Kabupaten_Pamekasan.csv has extra columns: {'price_level'}
# Kabupaten_Pasaman_Barat.csv has extra columns: {'price_level'}
# Kabupaten_Pati.csv has extra columns: {'price_level'}
# Kabupaten_Pemalang.csv has extra columns: {'price_level'}
# Kabupaten_Probolinggo.csv has extra columns: {'price_level'}
# Kabupaten_Samosir.csv has extra columns: {'price_level'}
# Kabupaten_Semarang.csv has extra columns: {'price_level'}
# Kabupaten_Sijunjung.csv has extra columns: {'price_level'}
# Kabupaten_Sikka.csv has extra columns: {'price_level'}
# Kabupaten_Situbondo.csv has extra columns: {'price_level'}
# Kabupaten_Sorong_Selatan.csv is missing columns: {'plus_code', 'opening_hours'}
# Kabupaten_Sragen.csv has extra columns: {'price_level'}
# Kabupaten_Sukabumi.csv has extra columns: {'price_level'}
# Kabupaten_Sumbawa.csv has extra columns: {'price_level'}
# Kabupaten_Sumbawa_Barat.csv has extra columns: {'price_level'}
# Kabupaten_Sumba_Timur.csv has extra columns: {'price_level'}
# Kabupaten_Sumedang.csv has extra columns: {'price_level'}
# Kabupaten_Tana_Tidung.csv is missing columns: {'plus_code'}
# Kabupaten_Tangerang.csv has extra columns: {'price_level'}
# Kabupaten_Tanggamus.csv has extra columns: {'price_level'}
# Kabupaten_Tanjung_Jabung_Timur.csv has extra columns: {'price_level'}
# Kabupaten_Temanggung.csv has extra columns: {'price_level'}
# Kabupaten_Tulungagung.csv has extra columns: {'price_level'}
# Kabupaten_Wonogiri.csv has extra columns: {'price_level'}
# Kota_Balikpapan.csv has extra columns: {'price_level'}
# Kota_Bandung.csv has extra columns: {'price_level'}
# Kota_Banjar.csv has extra columns: {'price_level'}
# Kota_Batam.csv has extra columns: {'price_level'}
# Kota_Bekasi.csv has extra columns: {'price_level'}
# Kota_Biak.csv has extra columns: {'price_level'}
# Kota_Bima.csv is missing columns: {'permanently_closed'}
# Kota_Bima.csv has extra columns: {'price_level'}
# Kota_Bukittinggi.csv is missing columns: {'permanently_closed'}
# Kota_Depok.csv has extra columns: {'price_level'}
# Kota_Gorontalo.csv has extra columns: {'price_level'}
# Kota_Jakarta_Utara.csv has extra columns: {'price_level'}
# Kota_Jambi.csv has extra columns: {'price_level'}
# Kota_Jayapura.csv has extra columns: {'price_level'}
# Kota_Kupang.csv has extra columns: {'price_level'}
# Kota_Malang.csv has extra columns: {'price_level'}
# Kota_Medan.csv has extra columns: {'price_level'}
# Kota_Padang.csv has extra columns: {'price_level'}
# Kota_Pangkal_Pinang.csv has extra columns: {'price_level'}
# Kota_Salatiga.csv has extra columns: {'price_level'}
# Kota_Surabaya.csv has extra columns: {'price_level'}
# Kota_Surakarta.csv has extra columns: {'price_level'}
# Kota_Tangerang.csv has extra columns: {'price_level'}
# Kota_Tangerang_Selatan.csv has extra columns: {'price_level'}
# Kota_Tanjungbalai.csv has extra columns: {'price_level'}
# Kota_Tanjung_Pinang.csv is missing columns: {'permanently_closed'}
# Kota_Tebing_Tinggi.csv has extra columns: {'price_level'}
# Kota_Ternate.csv is missing columns: {'permanently_closed'}
# Kota_Tomohon.csv is missing columns: {'permanently_closed'}
# Number of files with extra 'price_level' column: 102
# Number of files with missing columns: 9
# Number of files missing 'permanently_closed': 6
# Number of files missing 'plus_code': 3
# Number of files missing 'opening_hours': 1

# %%
for file_name in os.listdir(clean_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(clean_path, file_name)
        print(f'Processing {file_path}')

        # Read the CSV file
        df = pd.read_csv(file_path)
        print(f'Initial shape: {df.shape}')

        # Drop 'price_level' column if it exists
        if 'price_level' in df.columns:
            df.drop('price_level', axis=1, inplace=True)
            print(f'Dropped price_level, new shape: {df.shape}')

        # Remove permanently closed businesses if column exists
        if 'permanently_closed' in df.columns:
            df = df[df['permanently_closed'] != True]
            print(f'Removed permanently closed businesses, new shape: {df.shape}')
            # Drop the 'permanently_closed' column
            df.drop('permanently_closed', axis=1, inplace=True)
            print(f'Dropped permanently closed column, new shape: {df.shape}')

        # Keep only operational businesses
        if 'business_status' in df.columns:
            df = df[df['business_status'] == 'OPERATIONAL']
            print(f'Kept operational businesses, new shape: {df.shape}')

        # Exclude travel agencies
        if 'types' in df.columns:
            df = df[~df['types'].str.contains('travel_agency')]
            print(f'Excluded travel agencies, new shape: {df.shape}')

        # Drop additional columns if they exist
        columns_to_drop = ['business_status', 'icon', 'icon_background_color', 'icon_mask_base_uri', 'reference', 'url', 'opening_hours', 'plus_code']
        df.drop(columns=[col for col in columns_to_drop if col in df.columns], axis=1, inplace=True)
        print(f'Dropped specified columns, new shape: {df.shape}')

        # Save the DataFrame
        df.to_csv(file_path, index=False)
        print(f'File overwritten with filtered data: {file_path}')

print("All files have been processed.")
# Out:
# Processing TA_DS_clean\Kabupaten_Aceh_Barat.csv
# Initial shape: (209, 17)
# Removed permanently closed businesses, new shape: (166, 17)
# Dropped permanently closed column, new shape: (166, 16)
# Kept operational businesses, new shape: (163, 16)
# Excluded travel agencies, new shape: (163, 16)
# Dropped specified columns, new shape: (163, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Barat.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Barat_Daya.csv
# Initial shape: (213, 17)
# Removed permanently closed businesses, new shape: (167, 17)
# Dropped permanently closed column, new shape: (167, 16)
# Kept operational businesses, new shape: (165, 16)
# Excluded travel agencies, new shape: (165, 16)
# Dropped specified columns, new shape: (165, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Barat_Daya.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Besar.csv
# Initial shape: (327, 17)
# Removed permanently closed businesses, new shape: (314, 17)
# Dropped permanently closed column, new shape: (314, 16)
# Kept operational businesses, new shape: (310, 16)
# Excluded travel agencies, new shape: (310, 16)
# Dropped specified columns, new shape: (310, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Besar.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Jaya.csv
# Initial shape: (330, 17)
# Removed permanently closed businesses, new shape: (299, 17)
# Dropped permanently closed column, new shape: (299, 16)
# Kept operational businesses, new shape: (295, 16)
# Excluded travel agencies, new shape: (295, 16)
# Dropped specified columns, new shape: (295, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Jaya.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Selatan.csv
# Initial shape: (219, 17)
# Removed permanently closed businesses, new shape: (160, 17)
# Dropped permanently closed column, new shape: (160, 16)
# Kept operational businesses, new shape: (160, 16)
# Excluded travel agencies, new shape: (160, 16)
# Dropped specified columns, new shape: (160, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Singkil.csv
# Initial shape: (202, 17)
# Removed permanently closed businesses, new shape: (169, 17)
# Dropped permanently closed column, new shape: (169, 16)
# Kept operational businesses, new shape: (168, 16)
# Excluded travel agencies, new shape: (167, 16)
# Dropped specified columns, new shape: (167, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Singkil.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Tamiang.csv
# Initial shape: (271, 17)
# Removed permanently closed businesses, new shape: (237, 17)
# Dropped permanently closed column, new shape: (237, 16)
# Kept operational businesses, new shape: (233, 16)
# Excluded travel agencies, new shape: (232, 16)
# Dropped specified columns, new shape: (232, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Tamiang.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Tengah.csv
# Initial shape: (148, 17)
# Removed permanently closed businesses, new shape: (147, 17)
# Dropped permanently closed column, new shape: (147, 16)
# Kept operational businesses, new shape: (145, 16)
# Excluded travel agencies, new shape: (143, 16)
# Dropped specified columns, new shape: (143, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Tenggara.csv
# Initial shape: (279, 17)
# Removed permanently closed businesses, new shape: (238, 17)
# Dropped permanently closed column, new shape: (238, 16)
# Kept operational businesses, new shape: (232, 16)
# Excluded travel agencies, new shape: (228, 16)
# Dropped specified columns, new shape: (228, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Tenggara.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Timur.csv
# Initial shape: (183, 17)
# Removed permanently closed businesses, new shape: (151, 17)
# Dropped permanently closed column, new shape: (151, 16)
# Kept operational businesses, new shape: (144, 16)
# Excluded travel agencies, new shape: (144, 16)
# Dropped specified columns, new shape: (144, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Timur.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Utara.csv
# Initial shape: (238, 17)
# Removed permanently closed businesses, new shape: (197, 17)
# Dropped permanently closed column, new shape: (197, 16)
# Kept operational businesses, new shape: (193, 16)
# Excluded travel agencies, new shape: (189, 16)
# Dropped specified columns, new shape: (189, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Aceh_Utara.csv
# Processing TA_DS_clean\Kabupaten_Agam.csv
# Initial shape: (698, 17)
# Removed permanently closed businesses, new shape: (667, 17)
# Dropped permanently closed column, new shape: (667, 16)
# Kept operational businesses, new shape: (661, 16)
# Excluded travel agencies, new shape: (660, 16)
# Dropped specified columns, new shape: (660, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Agam.csv
# Processing TA_DS_clean\Kabupaten_Alor.csv
# Initial shape: (587, 17)
# Removed permanently closed businesses, new shape: (439, 17)
# Dropped permanently closed column, new shape: (439, 16)
# Kept operational businesses, new shape: (434, 16)
# Excluded travel agencies, new shape: (433, 16)
# Dropped specified columns, new shape: (433, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Alor.csv
# Processing TA_DS_clean\Kabupaten_Asahan.csv
# Initial shape: (684, 17)
# Removed permanently closed businesses, new shape: (632, 17)
# Dropped permanently closed column, new shape: (632, 16)
# Kept operational businesses, new shape: (613, 16)
# Excluded travel agencies, new shape: (608, 16)
# Dropped specified columns, new shape: (608, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Asahan.csv
# Processing TA_DS_clean\Kabupaten_Asmat.csv
# Initial shape: (173, 17)
# Removed permanently closed businesses, new shape: (130, 17)
# Dropped permanently closed column, new shape: (130, 16)
# Kept operational businesses, new shape: (122, 16)
# Excluded travel agencies, new shape: (120, 16)
# Dropped specified columns, new shape: (120, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Asmat.csv
# Processing TA_DS_clean\Kabupaten_Badung.csv
# Initial shape: (192, 18)
# Dropped price_level, new shape: (192, 17)
# Removed permanently closed businesses, new shape: (188, 17)
# Dropped permanently closed column, new shape: (188, 16)
# Kept operational businesses, new shape: (182, 16)
# Excluded travel agencies, new shape: (181, 16)
# Dropped specified columns, new shape: (181, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Badung.csv
# Processing TA_DS_clean\Kabupaten_Balangan.csv
# Initial shape: (441, 17)
# Removed permanently closed businesses, new shape: (409, 17)
# Dropped permanently closed column, new shape: (409, 16)
# Kept operational businesses, new shape: (404, 16)
# Excluded travel agencies, new shape: (404, 16)
# Dropped specified columns, new shape: (404, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Balangan.csv
# Processing TA_DS_clean\Kabupaten_Bandung.csv
# Initial shape: (1262, 18)
# Dropped price_level, new shape: (1262, 17)
# Removed permanently closed businesses, new shape: (1183, 17)
# Dropped permanently closed column, new shape: (1183, 16)
# Kept operational businesses, new shape: (1171, 16)
# Excluded travel agencies, new shape: (1159, 16)
# Dropped specified columns, new shape: (1159, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bandung.csv
# Processing TA_DS_clean\Kabupaten_Bandung_Barat.csv
# Initial shape: (708, 18)
# Dropped price_level, new shape: (708, 17)
# Removed permanently closed businesses, new shape: (665, 17)
# Dropped permanently closed column, new shape: (665, 16)
# Kept operational businesses, new shape: (652, 16)
# Excluded travel agencies, new shape: (647, 16)
# Dropped specified columns, new shape: (647, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bandung_Barat.csv
# Processing TA_DS_clean\Kabupaten_Banggai.csv
# Initial shape: (610, 18)
# Dropped price_level, new shape: (610, 17)
# Removed permanently closed businesses, new shape: (501, 17)
# Dropped permanently closed column, new shape: (501, 16)
# Kept operational businesses, new shape: (493, 16)
# Excluded travel agencies, new shape: (489, 16)
# Dropped specified columns, new shape: (489, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banggai.csv
# Processing TA_DS_clean\Kabupaten_Banggai_Kepulauan.csv
# Initial shape: (609, 17)
# Removed permanently closed businesses, new shape: (466, 17)
# Dropped permanently closed column, new shape: (466, 16)
# Kept operational businesses, new shape: (456, 16)
# Excluded travel agencies, new shape: (455, 16)
# Dropped specified columns, new shape: (455, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banggai_Kepulauan.csv
# Processing TA_DS_clean\Kabupaten_Banggai_Laut.csv
# Initial shape: (226, 17)
# Removed permanently closed businesses, new shape: (193, 17)
# Dropped permanently closed column, new shape: (193, 16)
# Kept operational businesses, new shape: (186, 16)
# Excluded travel agencies, new shape: (185, 16)
# Dropped specified columns, new shape: (185, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banggai_Laut.csv
# Processing TA_DS_clean\Kabupaten_Bangka.csv
# Initial shape: (352, 17)
# Removed permanently closed businesses, new shape: (332, 17)
# Dropped permanently closed column, new shape: (332, 16)
# Kept operational businesses, new shape: (331, 16)
# Excluded travel agencies, new shape: (331, 16)
# Dropped specified columns, new shape: (331, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bangka.csv
# Processing TA_DS_clean\Kabupaten_Bangkalan.csv
# Initial shape: (513, 18)
# Dropped price_level, new shape: (513, 17)
# Removed permanently closed businesses, new shape: (460, 17)
# Dropped permanently closed column, new shape: (460, 16)
# Kept operational businesses, new shape: (453, 16)
# Excluded travel agencies, new shape: (451, 16)
# Dropped specified columns, new shape: (451, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bangkalan.csv
# Processing TA_DS_clean\Kabupaten_Bangka_Barat.csv
# Initial shape: (165, 18)
# Dropped price_level, new shape: (165, 17)
# Removed permanently closed businesses, new shape: (141, 17)
# Dropped permanently closed column, new shape: (141, 16)
# Kept operational businesses, new shape: (141, 16)
# Excluded travel agencies, new shape: (140, 16)
# Dropped specified columns, new shape: (140, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bangka_Barat.csv
# Processing TA_DS_clean\Kabupaten_Bangka_Selatan.csv
# Initial shape: (272, 17)
# Removed permanently closed businesses, new shape: (264, 17)
# Dropped permanently closed column, new shape: (264, 16)
# Kept operational businesses, new shape: (260, 16)
# Excluded travel agencies, new shape: (260, 16)
# Dropped specified columns, new shape: (260, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bangka_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Bangka_Tengah.csv
# Initial shape: (388, 18)
# Dropped price_level, new shape: (388, 17)
# Removed permanently closed businesses, new shape: (381, 17)
# Dropped permanently closed column, new shape: (381, 16)
# Kept operational businesses, new shape: (378, 16)
# Excluded travel agencies, new shape: (378, 16)
# Dropped specified columns, new shape: (378, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bangka_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Bangli.csv
# Initial shape: (203, 17)
# Removed permanently closed businesses, new shape: (195, 17)
# Dropped permanently closed column, new shape: (195, 16)
# Kept operational businesses, new shape: (195, 16)
# Excluded travel agencies, new shape: (195, 16)
# Dropped specified columns, new shape: (195, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bangli.csv
# Processing TA_DS_clean\Kabupaten_Banjar.csv
# Initial shape: (567, 17)
# Removed permanently closed businesses, new shape: (543, 17)
# Dropped permanently closed column, new shape: (543, 16)
# Kept operational businesses, new shape: (542, 16)
# Excluded travel agencies, new shape: (537, 16)
# Dropped specified columns, new shape: (537, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banjar.csv
# Processing TA_DS_clean\Kabupaten_Banjarnegara.csv
# Initial shape: (716, 17)
# Removed permanently closed businesses, new shape: (680, 17)
# Dropped permanently closed column, new shape: (680, 16)
# Kept operational businesses, new shape: (678, 16)
# Excluded travel agencies, new shape: (675, 16)
# Dropped specified columns, new shape: (675, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banjarnegara.csv
# Processing TA_DS_clean\Kabupaten_Bantaeng.csv
# Initial shape: (328, 17)
# Removed permanently closed businesses, new shape: (308, 17)
# Dropped permanently closed column, new shape: (308, 16)
# Kept operational businesses, new shape: (302, 16)
# Excluded travel agencies, new shape: (301, 16)
# Dropped specified columns, new shape: (301, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bantaeng.csv
# Processing TA_DS_clean\Kabupaten_Banyuasin.csv
# Initial shape: (458, 17)
# Removed permanently closed businesses, new shape: (423, 17)
# Dropped permanently closed column, new shape: (423, 16)
# Kept operational businesses, new shape: (418, 16)
# Excluded travel agencies, new shape: (416, 16)
# Dropped specified columns, new shape: (416, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banyuasin.csv
# Processing TA_DS_clean\Kabupaten_Banyumas.csv
# Initial shape: (1307, 18)
# Dropped price_level, new shape: (1307, 17)
# Removed permanently closed businesses, new shape: (1247, 17)
# Dropped permanently closed column, new shape: (1247, 16)
# Kept operational businesses, new shape: (1236, 16)
# Excluded travel agencies, new shape: (1232, 16)
# Dropped specified columns, new shape: (1232, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banyumas.csv
# Processing TA_DS_clean\Kabupaten_Banyuwangi.csv
# Initial shape: (974, 18)
# Dropped price_level, new shape: (974, 17)
# Removed permanently closed businesses, new shape: (922, 17)
# Dropped permanently closed column, new shape: (922, 16)
# Kept operational businesses, new shape: (894, 16)
# Excluded travel agencies, new shape: (889, 16)
# Dropped specified columns, new shape: (889, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Banyuwangi.csv
# Processing TA_DS_clean\Kabupaten_Barito_Kuala.csv
# Initial shape: (196, 17)
# Removed permanently closed businesses, new shape: (178, 17)
# Dropped permanently closed column, new shape: (178, 16)
# Kept operational businesses, new shape: (177, 16)
# Excluded travel agencies, new shape: (176, 16)
# Dropped specified columns, new shape: (176, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Barito_Kuala.csv
# Processing TA_DS_clean\Kabupaten_Barito_Selatan.csv
# Initial shape: (631, 17)
# Removed permanently closed businesses, new shape: (616, 17)
# Dropped permanently closed column, new shape: (616, 16)
# Kept operational businesses, new shape: (609, 16)
# Excluded travel agencies, new shape: (609, 16)
# Dropped specified columns, new shape: (609, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Barito_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Barito_Timur.csv
# Initial shape: (669, 17)
# Removed permanently closed businesses, new shape: (648, 17)
# Dropped permanently closed column, new shape: (648, 16)
# Kept operational businesses, new shape: (646, 16)
# Excluded travel agencies, new shape: (646, 16)
# Dropped specified columns, new shape: (646, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Barito_Timur.csv
# Processing TA_DS_clean\Kabupaten_Barito_Utara.csv
# Initial shape: (323, 17)
# Removed permanently closed businesses, new shape: (311, 17)
# Dropped permanently closed column, new shape: (311, 16)
# Kept operational businesses, new shape: (298, 16)
# Excluded travel agencies, new shape: (298, 16)
# Dropped specified columns, new shape: (298, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Barito_Utara.csv
# Processing TA_DS_clean\Kabupaten_Barru.csv
# Initial shape: (284, 17)
# Removed permanently closed businesses, new shape: (261, 17)
# Dropped permanently closed column, new shape: (261, 16)
# Kept operational businesses, new shape: (256, 16)
# Excluded travel agencies, new shape: (255, 16)
# Dropped specified columns, new shape: (255, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Barru.csv
# Processing TA_DS_clean\Kabupaten_Batang.csv
# Initial shape: (410, 18)
# Dropped price_level, new shape: (410, 17)
# Removed permanently closed businesses, new shape: (365, 17)
# Dropped permanently closed column, new shape: (365, 16)
# Kept operational businesses, new shape: (352, 16)
# Excluded travel agencies, new shape: (349, 16)
# Dropped specified columns, new shape: (349, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Batang.csv
# Processing TA_DS_clean\Kabupaten_Batang_Hari.csv
# Initial shape: (494, 17)
# Removed permanently closed businesses, new shape: (487, 17)
# Dropped permanently closed column, new shape: (487, 16)
# Kept operational businesses, new shape: (479, 16)
# Excluded travel agencies, new shape: (479, 16)
# Dropped specified columns, new shape: (479, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Batang_Hari.csv
# Processing TA_DS_clean\Kabupaten_Batu_Bara.csv
# Initial shape: (533, 17)
# Removed permanently closed businesses, new shape: (515, 17)
# Dropped permanently closed column, new shape: (515, 16)
# Kept operational businesses, new shape: (507, 16)
# Excluded travel agencies, new shape: (501, 16)
# Dropped specified columns, new shape: (501, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Batu_Bara.csv
# Processing TA_DS_clean\Kabupaten_Bekasi.csv
# Initial shape: (1279, 18)
# Dropped price_level, new shape: (1279, 17)
# Removed permanently closed businesses, new shape: (1180, 17)
# Dropped permanently closed column, new shape: (1180, 16)
# Kept operational businesses, new shape: (1164, 16)
# Excluded travel agencies, new shape: (1158, 16)
# Dropped specified columns, new shape: (1158, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bekasi.csv
# Processing TA_DS_clean\Kabupaten_Belitung.csv
# Initial shape: (390, 18)
# Dropped price_level, new shape: (390, 17)
# Removed permanently closed businesses, new shape: (389, 17)
# Dropped permanently closed column, new shape: (389, 16)
# Kept operational businesses, new shape: (387, 16)
# Excluded travel agencies, new shape: (382, 16)
# Dropped specified columns, new shape: (382, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Belitung.csv
# Processing TA_DS_clean\Kabupaten_Belitung_Timur.csv
# Initial shape: (185, 17)
# Removed permanently closed businesses, new shape: (171, 17)
# Dropped permanently closed column, new shape: (171, 16)
# Kept operational businesses, new shape: (169, 16)
# Excluded travel agencies, new shape: (169, 16)
# Dropped specified columns, new shape: (169, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Belitung_Timur.csv
# Processing TA_DS_clean\Kabupaten_Belu.csv
# Initial shape: (772, 17)
# Removed permanently closed businesses, new shape: (669, 17)
# Dropped permanently closed column, new shape: (669, 16)
# Kept operational businesses, new shape: (659, 16)
# Excluded travel agencies, new shape: (659, 16)
# Dropped specified columns, new shape: (659, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Belu.csv
# Processing TA_DS_clean\Kabupaten_Bener_Meriah.csv
# Initial shape: (151, 17)
# Removed permanently closed businesses, new shape: (150, 17)
# Dropped permanently closed column, new shape: (150, 16)
# Kept operational businesses, new shape: (149, 16)
# Excluded travel agencies, new shape: (149, 16)
# Dropped specified columns, new shape: (149, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bener_Meriah.csv
# Processing TA_DS_clean\Kabupaten_Bengkalis.csv
# Initial shape: (267, 17)
# Removed permanently closed businesses, new shape: (234, 17)
# Dropped permanently closed column, new shape: (234, 16)
# Kept operational businesses, new shape: (230, 16)
# Excluded travel agencies, new shape: (230, 16)
# Dropped specified columns, new shape: (230, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bengkalis.csv
# Processing TA_DS_clean\Kabupaten_Bengkayang.csv
# Initial shape: (511, 17)
# Removed permanently closed businesses, new shape: (492, 17)
# Dropped permanently closed column, new shape: (492, 16)
# Kept operational businesses, new shape: (486, 16)
# Excluded travel agencies, new shape: (483, 16)
# Dropped specified columns, new shape: (483, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bengkayang.csv
# Processing TA_DS_clean\Kabupaten_Berau.csv
# Initial shape: (468, 17)
# Removed permanently closed businesses, new shape: (428, 17)
# Dropped permanently closed column, new shape: (428, 16)
# Kept operational businesses, new shape: (405, 16)
# Excluded travel agencies, new shape: (403, 16)
# Dropped specified columns, new shape: (403, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Berau.csv
# Processing TA_DS_clean\Kabupaten_Bima.csv
# Initial shape: (796, 18)
# Dropped price_level, new shape: (796, 17)
# Removed permanently closed businesses, new shape: (655, 17)
# Dropped permanently closed column, new shape: (655, 16)
# Kept operational businesses, new shape: (645, 16)
# Excluded travel agencies, new shape: (642, 16)
# Dropped specified columns, new shape: (642, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bima.csv
# Processing TA_DS_clean\Kabupaten_Bintan.csv
# Initial shape: (230, 18)
# Dropped price_level, new shape: (230, 17)
# Removed permanently closed businesses, new shape: (217, 17)
# Dropped permanently closed column, new shape: (217, 16)
# Kept operational businesses, new shape: (214, 16)
# Excluded travel agencies, new shape: (211, 16)
# Dropped specified columns, new shape: (211, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bintan.csv
# Processing TA_DS_clean\Kabupaten_Bireuen.csv
# Initial shape: (377, 17)
# Removed permanently closed businesses, new shape: (364, 17)
# Dropped permanently closed column, new shape: (364, 16)
# Kept operational businesses, new shape: (359, 16)
# Excluded travel agencies, new shape: (359, 16)
# Dropped specified columns, new shape: (359, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bireuen.csv
# Processing TA_DS_clean\Kabupaten_Blitar.csv
# Initial shape: (880, 18)
# Dropped price_level, new shape: (880, 17)
# Removed permanently closed businesses, new shape: (809, 17)
# Dropped permanently closed column, new shape: (809, 16)
# Kept operational businesses, new shape: (800, 16)
# Excluded travel agencies, new shape: (799, 16)
# Dropped specified columns, new shape: (799, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Blitar.csv
# Processing TA_DS_clean\Kabupaten_Blora.csv
# Initial shape: (782, 17)
# Removed permanently closed businesses, new shape: (751, 17)
# Dropped permanently closed column, new shape: (751, 16)
# Kept operational businesses, new shape: (744, 16)
# Excluded travel agencies, new shape: (743, 16)
# Dropped specified columns, new shape: (743, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Blora.csv
# Processing TA_DS_clean\Kabupaten_Boalemo.csv
# Initial shape: (193, 17)
# Removed permanently closed businesses, new shape: (147, 17)
# Dropped permanently closed column, new shape: (147, 16)
# Kept operational businesses, new shape: (144, 16)
# Excluded travel agencies, new shape: (143, 16)
# Dropped specified columns, new shape: (143, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Boalemo.csv
# Processing TA_DS_clean\Kabupaten_Bogor.csv
# Initial shape: (1909, 18)
# Dropped price_level, new shape: (1909, 17)
# Removed permanently closed businesses, new shape: (1758, 17)
# Dropped permanently closed column, new shape: (1758, 16)
# Kept operational businesses, new shape: (1748, 16)
# Excluded travel agencies, new shape: (1733, 16)
# Dropped specified columns, new shape: (1733, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bogor.csv
# Processing TA_DS_clean\Kabupaten_Bojonegoro.csv
# Initial shape: (1065, 18)
# Dropped price_level, new shape: (1065, 17)
# Removed permanently closed businesses, new shape: (1024, 17)
# Dropped permanently closed column, new shape: (1024, 16)
# Kept operational businesses, new shape: (1022, 16)
# Excluded travel agencies, new shape: (1022, 16)
# Dropped specified columns, new shape: (1022, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bojonegoro.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow.csv
# Initial shape: (614, 17)
# Removed permanently closed businesses, new shape: (538, 17)
# Dropped permanently closed column, new shape: (538, 16)
# Kept operational businesses, new shape: (523, 16)
# Excluded travel agencies, new shape: (521, 16)
# Dropped specified columns, new shape: (521, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bolaang_Mongondow.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Selatan.csv
# Initial shape: (383, 17)
# Removed permanently closed businesses, new shape: (308, 17)
# Dropped permanently closed column, new shape: (308, 16)
# Kept operational businesses, new shape: (298, 16)
# Excluded travel agencies, new shape: (293, 16)
# Dropped specified columns, new shape: (293, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Timur.csv
# Initial shape: (313, 17)
# Removed permanently closed businesses, new shape: (262, 17)
# Dropped permanently closed column, new shape: (262, 16)
# Kept operational businesses, new shape: (251, 16)
# Excluded travel agencies, new shape: (251, 16)
# Dropped specified columns, new shape: (251, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Timur.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Utara.csv
# Initial shape: (194, 17)
# Removed permanently closed businesses, new shape: (142, 17)
# Dropped permanently closed column, new shape: (142, 16)
# Kept operational businesses, new shape: (140, 16)
# Excluded travel agencies, new shape: (140, 16)
# Dropped specified columns, new shape: (140, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Utara.csv
# Processing TA_DS_clean\Kabupaten_Bombana.csv
# Initial shape: (250, 17)
# Removed permanently closed businesses, new shape: (220, 17)
# Dropped permanently closed column, new shape: (220, 16)
# Kept operational businesses, new shape: (217, 16)
# Excluded travel agencies, new shape: (217, 16)
# Dropped specified columns, new shape: (217, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bombana.csv
# Processing TA_DS_clean\Kabupaten_Bondowoso.csv
# Initial shape: (773, 18)
# Dropped price_level, new shape: (773, 17)
# Removed permanently closed businesses, new shape: (761, 17)
# Dropped permanently closed column, new shape: (761, 16)
# Kept operational businesses, new shape: (743, 16)
# Excluded travel agencies, new shape: (743, 16)
# Dropped specified columns, new shape: (743, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bondowoso.csv
# Processing TA_DS_clean\Kabupaten_Bone.csv
# Initial shape: (752, 17)
# Removed permanently closed businesses, new shape: (659, 17)
# Dropped permanently closed column, new shape: (659, 16)
# Kept operational businesses, new shape: (652, 16)
# Excluded travel agencies, new shape: (650, 16)
# Dropped specified columns, new shape: (650, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bone.csv
# Processing TA_DS_clean\Kabupaten_Bone_Bolango.csv
# Initial shape: (904, 17)
# Removed permanently closed businesses, new shape: (852, 17)
# Dropped permanently closed column, new shape: (852, 16)
# Kept operational businesses, new shape: (842, 16)
# Excluded travel agencies, new shape: (840, 16)
# Dropped specified columns, new shape: (840, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bone_Bolango.csv
# Processing TA_DS_clean\Kabupaten_Boven_Digoel.csv
# Initial shape: (67, 17)
# Removed permanently closed businesses, new shape: (56, 17)
# Dropped permanently closed column, new shape: (56, 16)
# Kept operational businesses, new shape: (54, 16)
# Excluded travel agencies, new shape: (54, 16)
# Dropped specified columns, new shape: (54, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Boven_Digoel.csv
# Processing TA_DS_clean\Kabupaten_Boyolali.csv
# Initial shape: (805, 17)
# Removed permanently closed businesses, new shape: (750, 17)
# Dropped permanently closed column, new shape: (750, 16)
# Kept operational businesses, new shape: (745, 16)
# Excluded travel agencies, new shape: (745, 16)
# Dropped specified columns, new shape: (745, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Boyolali.csv
# Processing TA_DS_clean\Kabupaten_Brebes.csv
# Initial shape: (666, 17)
# Removed permanently closed businesses, new shape: (636, 17)
# Dropped permanently closed column, new shape: (636, 16)
# Kept operational businesses, new shape: (630, 16)
# Excluded travel agencies, new shape: (622, 16)
# Dropped specified columns, new shape: (622, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Brebes.csv
# Processing TA_DS_clean\Kabupaten_Buleleng.csv
# Initial shape: (407, 18)
# Dropped price_level, new shape: (407, 17)
# Removed permanently closed businesses, new shape: (395, 17)
# Dropped permanently closed column, new shape: (395, 16)
# Kept operational businesses, new shape: (394, 16)
# Excluded travel agencies, new shape: (391, 16)
# Dropped specified columns, new shape: (391, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Buleleng.csv
# Processing TA_DS_clean\Kabupaten_Bulukumba.csv
# Initial shape: (522, 18)
# Dropped price_level, new shape: (522, 17)
# Removed permanently closed businesses, new shape: (471, 17)
# Dropped permanently closed column, new shape: (471, 16)
# Kept operational businesses, new shape: (466, 16)
# Excluded travel agencies, new shape: (466, 16)
# Dropped specified columns, new shape: (466, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bulukumba.csv
# Processing TA_DS_clean\Kabupaten_Bulungan.csv
# Initial shape: (377, 17)
# Removed permanently closed businesses, new shape: (344, 17)
# Dropped permanently closed column, new shape: (344, 16)
# Kept operational businesses, new shape: (337, 16)
# Excluded travel agencies, new shape: (337, 16)
# Dropped specified columns, new shape: (337, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bulungan.csv
# Processing TA_DS_clean\Kabupaten_Bungo.csv
# Initial shape: (183, 17)
# Removed permanently closed businesses, new shape: (166, 17)
# Dropped permanently closed column, new shape: (166, 16)
# Kept operational businesses, new shape: (154, 16)
# Excluded travel agencies, new shape: (149, 16)
# Dropped specified columns, new shape: (149, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Bungo.csv
# Processing TA_DS_clean\Kabupaten_Buol.csv
# Initial shape: (246, 17)
# Removed permanently closed businesses, new shape: (185, 17)
# Dropped permanently closed column, new shape: (185, 16)
# Kept operational businesses, new shape: (182, 16)
# Excluded travel agencies, new shape: (181, 16)
# Dropped specified columns, new shape: (181, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Buol.csv
# Processing TA_DS_clean\Kabupaten_Buru.csv
# Initial shape: (360, 17)
# Removed permanently closed businesses, new shape: (334, 17)
# Dropped permanently closed column, new shape: (334, 16)
# Kept operational businesses, new shape: (332, 16)
# Excluded travel agencies, new shape: (332, 16)
# Dropped specified columns, new shape: (332, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Buru.csv
# Processing TA_DS_clean\Kabupaten_Buru_Selatan.csv
# Initial shape: (308, 17)
# Removed permanently closed businesses, new shape: (268, 17)
# Dropped permanently closed column, new shape: (268, 16)
# Kept operational businesses, new shape: (263, 16)
# Excluded travel agencies, new shape: (263, 16)
# Dropped specified columns, new shape: (263, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Buru_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Buton.csv
# Initial shape: (371, 17)
# Removed permanently closed businesses, new shape: (323, 17)
# Dropped permanently closed column, new shape: (323, 16)
# Kept operational businesses, new shape: (316, 16)
# Excluded travel agencies, new shape: (316, 16)
# Dropped specified columns, new shape: (316, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Buton.csv
# Processing TA_DS_clean\Kabupaten_Buton_Utara.csv
# Initial shape: (533, 17)
# Removed permanently closed businesses, new shape: (496, 17)
# Dropped permanently closed column, new shape: (496, 16)
# Kept operational businesses, new shape: (493, 16)
# Excluded travel agencies, new shape: (493, 16)
# Dropped specified columns, new shape: (493, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Buton_Utara.csv
# Processing TA_DS_clean\Kabupaten_Ciamis.csv
# Initial shape: (1172, 18)
# Dropped price_level, new shape: (1172, 17)
# Removed permanently closed businesses, new shape: (1084, 17)
# Dropped permanently closed column, new shape: (1084, 16)
# Kept operational businesses, new shape: (1081, 16)
# Excluded travel agencies, new shape: (1081, 16)
# Dropped specified columns, new shape: (1081, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Ciamis.csv
# Processing TA_DS_clean\Kabupaten_Cianjur.csv
# Initial shape: (1236, 17)
# Removed permanently closed businesses, new shape: (1123, 17)
# Dropped permanently closed column, new shape: (1123, 16)
# Kept operational businesses, new shape: (1115, 16)
# Excluded travel agencies, new shape: (1114, 16)
# Dropped specified columns, new shape: (1114, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Cianjur.csv
# Processing TA_DS_clean\Kabupaten_Cilacap.csv
# Initial shape: (922, 18)
# Dropped price_level, new shape: (922, 17)
# Removed permanently closed businesses, new shape: (863, 17)
# Dropped permanently closed column, new shape: (863, 16)
# Kept operational businesses, new shape: (853, 16)
# Excluded travel agencies, new shape: (853, 16)
# Dropped specified columns, new shape: (853, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Cilacap.csv
# Processing TA_DS_clean\Kabupaten_Cirebon.csv
# Initial shape: (959, 17)
# Removed permanently closed businesses, new shape: (927, 17)
# Dropped permanently closed column, new shape: (927, 16)
# Kept operational businesses, new shape: (913, 16)
# Excluded travel agencies, new shape: (910, 16)
# Dropped specified columns, new shape: (910, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Cirebon.csv
# Processing TA_DS_clean\Kabupaten_Dairi.csv
# Initial shape: (620, 17)
# Removed permanently closed businesses, new shape: (596, 17)
# Dropped permanently closed column, new shape: (596, 16)
# Kept operational businesses, new shape: (588, 16)
# Excluded travel agencies, new shape: (584, 16)
# Dropped specified columns, new shape: (584, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Dairi.csv
# Processing TA_DS_clean\Kabupaten_Deiyai.csv
# Initial shape: (234, 17)
# Removed permanently closed businesses, new shape: (140, 17)
# Dropped permanently closed column, new shape: (140, 16)
# Kept operational businesses, new shape: (138, 16)
# Excluded travel agencies, new shape: (132, 16)
# Dropped specified columns, new shape: (132, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Deiyai.csv
# Processing TA_DS_clean\Kabupaten_Deli_Serdang.csv
# Initial shape: (769, 18)
# Dropped price_level, new shape: (769, 17)
# Removed permanently closed businesses, new shape: (751, 17)
# Dropped permanently closed column, new shape: (751, 16)
# Kept operational businesses, new shape: (735, 16)
# Excluded travel agencies, new shape: (734, 16)
# Dropped specified columns, new shape: (734, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Deli_Serdang.csv
# Processing TA_DS_clean\Kabupaten_Demak.csv
# Initial shape: (308, 18)
# Dropped price_level, new shape: (308, 17)
# Removed permanently closed businesses, new shape: (282, 17)
# Dropped permanently closed column, new shape: (282, 16)
# Kept operational businesses, new shape: (278, 16)
# Excluded travel agencies, new shape: (278, 16)
# Dropped specified columns, new shape: (278, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Demak.csv
# Processing TA_DS_clean\Kabupaten_Dharmasraya.csv
# Initial shape: (165, 17)
# Removed permanently closed businesses, new shape: (136, 17)
# Dropped permanently closed column, new shape: (136, 16)
# Kept operational businesses, new shape: (129, 16)
# Excluded travel agencies, new shape: (129, 16)
# Dropped specified columns, new shape: (129, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Dharmasraya.csv
# Processing TA_DS_clean\Kabupaten_Dogiyai.csv
# Initial shape: (115, 17)
# Removed permanently closed businesses, new shape: (68, 17)
# Dropped permanently closed column, new shape: (68, 16)
# Kept operational businesses, new shape: (66, 16)
# Excluded travel agencies, new shape: (66, 16)
# Dropped specified columns, new shape: (66, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Dogiyai.csv
# Processing TA_DS_clean\Kabupaten_Dompu.csv
# Initial shape: (326, 17)
# Removed permanently closed businesses, new shape: (317, 17)
# Dropped permanently closed column, new shape: (317, 16)
# Kept operational businesses, new shape: (317, 16)
# Excluded travel agencies, new shape: (307, 16)
# Dropped specified columns, new shape: (307, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Dompu.csv
# Processing TA_DS_clean\Kabupaten_Donggala.csv
# Initial shape: (509, 17)
# Removed permanently closed businesses, new shape: (430, 17)
# Dropped permanently closed column, new shape: (430, 16)
# Kept operational businesses, new shape: (414, 16)
# Excluded travel agencies, new shape: (412, 16)
# Dropped specified columns, new shape: (412, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Donggala.csv
# Processing TA_DS_clean\Kabupaten_Empat_Lawang.csv
# Initial shape: (113, 17)
# Removed permanently closed businesses, new shape: (83, 17)
# Dropped permanently closed column, new shape: (83, 16)
# Kept operational businesses, new shape: (82, 16)
# Excluded travel agencies, new shape: (82, 16)
# Dropped specified columns, new shape: (82, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Empat_Lawang.csv
# Processing TA_DS_clean\Kabupaten_Ende.csv
# Initial shape: (894, 17)
# Removed permanently closed businesses, new shape: (750, 17)
# Dropped permanently closed column, new shape: (750, 16)
# Kept operational businesses, new shape: (742, 16)
# Excluded travel agencies, new shape: (740, 16)
# Dropped specified columns, new shape: (740, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Ende.csv
# Processing TA_DS_clean\Kabupaten_Enrekang.csv
# Initial shape: (604, 18)
# Dropped price_level, new shape: (604, 17)
# Removed permanently closed businesses, new shape: (539, 17)
# Dropped permanently closed column, new shape: (539, 16)
# Kept operational businesses, new shape: (535, 16)
# Excluded travel agencies, new shape: (535, 16)
# Dropped specified columns, new shape: (535, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Enrekang.csv
# Processing TA_DS_clean\Kabupaten_Fakfak.csv
# Initial shape: (210, 17)
# Removed permanently closed businesses, new shape: (150, 17)
# Dropped permanently closed column, new shape: (150, 16)
# Kept operational businesses, new shape: (146, 16)
# Excluded travel agencies, new shape: (145, 16)
# Dropped specified columns, new shape: (145, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Fakfak.csv
# Processing TA_DS_clean\Kabupaten_Flores_Timur.csv
# Initial shape: (674, 18)
# Dropped price_level, new shape: (674, 17)
# Removed permanently closed businesses, new shape: (455, 17)
# Dropped permanently closed column, new shape: (455, 16)
# Kept operational businesses, new shape: (438, 16)
# Excluded travel agencies, new shape: (434, 16)
# Dropped specified columns, new shape: (434, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Flores_Timur.csv
# Processing TA_DS_clean\Kabupaten_Garut.csv
# Initial shape: (1573, 17)
# Removed permanently closed businesses, new shape: (1481, 17)
# Dropped permanently closed column, new shape: (1481, 16)
# Kept operational businesses, new shape: (1465, 16)
# Excluded travel agencies, new shape: (1461, 16)
# Dropped specified columns, new shape: (1461, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Garut.csv
# Processing TA_DS_clean\Kabupaten_Gayo_Lues.csv
# Initial shape: (355, 18)
# Dropped price_level, new shape: (355, 17)
# Removed permanently closed businesses, new shape: (326, 17)
# Dropped permanently closed column, new shape: (326, 16)
# Kept operational businesses, new shape: (318, 16)
# Excluded travel agencies, new shape: (316, 16)
# Dropped specified columns, new shape: (316, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gayo_Lues.csv
# Processing TA_DS_clean\Kabupaten_Gianyar.csv
# Initial shape: (342, 18)
# Dropped price_level, new shape: (342, 17)
# Removed permanently closed businesses, new shape: (332, 17)
# Dropped permanently closed column, new shape: (332, 16)
# Kept operational businesses, new shape: (332, 16)
# Excluded travel agencies, new shape: (327, 16)
# Dropped specified columns, new shape: (327, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gianyar.csv
# Processing TA_DS_clean\Kabupaten_Gorontalo.csv
# Initial shape: (893, 18)
# Dropped price_level, new shape: (893, 17)
# Removed permanently closed businesses, new shape: (792, 17)
# Dropped permanently closed column, new shape: (792, 16)
# Kept operational businesses, new shape: (783, 16)
# Excluded travel agencies, new shape: (772, 16)
# Dropped specified columns, new shape: (772, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gorontalo.csv
# Processing TA_DS_clean\Kabupaten_Gorontalo_Utara.csv
# Initial shape: (218, 17)
# Removed permanently closed businesses, new shape: (204, 17)
# Dropped permanently closed column, new shape: (204, 16)
# Kept operational businesses, new shape: (193, 16)
# Excluded travel agencies, new shape: (193, 16)
# Dropped specified columns, new shape: (193, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gorontalo_Utara.csv
# Processing TA_DS_clean\Kabupaten_Gowa.csv
# Initial shape: (760, 17)
# Removed permanently closed businesses, new shape: (706, 17)
# Dropped permanently closed column, new shape: (706, 16)
# Kept operational businesses, new shape: (699, 16)
# Excluded travel agencies, new shape: (697, 16)
# Dropped specified columns, new shape: (697, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gowa.csv
# Processing TA_DS_clean\Kabupaten_Gresik.csv
# Initial shape: (576, 17)
# Removed permanently closed businesses, new shape: (537, 17)
# Dropped permanently closed column, new shape: (537, 16)
# Kept operational businesses, new shape: (529, 16)
# Excluded travel agencies, new shape: (527, 16)
# Dropped specified columns, new shape: (527, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gresik.csv
# Processing TA_DS_clean\Kabupaten_Grobogan.csv
# Initial shape: (697, 18)
# Dropped price_level, new shape: (697, 17)
# Removed permanently closed businesses, new shape: (671, 17)
# Dropped permanently closed column, new shape: (671, 16)
# Kept operational businesses, new shape: (665, 16)
# Excluded travel agencies, new shape: (665, 16)
# Dropped specified columns, new shape: (665, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Grobogan.csv
# Processing TA_DS_clean\Kabupaten_Gunung_Mas.csv
# Initial shape: (140, 17)
# Removed permanently closed businesses, new shape: (127, 17)
# Dropped permanently closed column, new shape: (127, 16)
# Kept operational businesses, new shape: (125, 16)
# Excluded travel agencies, new shape: (125, 16)
# Dropped specified columns, new shape: (125, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Gunung_Mas.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Barat.csv
# Initial shape: (240, 16)
# Kept operational businesses, new shape: (239, 16)
# Excluded travel agencies, new shape: (239, 16)
# Dropped specified columns, new shape: (239, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Halmahera_Barat.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Selatan.csv
# Initial shape: (251, 17)
# Removed permanently closed businesses, new shape: (216, 17)
# Dropped permanently closed column, new shape: (216, 16)
# Kept operational businesses, new shape: (215, 16)
# Excluded travel agencies, new shape: (214, 16)
# Dropped specified columns, new shape: (214, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Halmahera_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Tengah.csv
# Initial shape: (131, 17)
# Removed permanently closed businesses, new shape: (118, 17)
# Dropped permanently closed column, new shape: (118, 16)
# Kept operational businesses, new shape: (115, 16)
# Excluded travel agencies, new shape: (115, 16)
# Dropped specified columns, new shape: (115, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Halmahera_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Utara.csv
# Initial shape: (474, 17)
# Removed permanently closed businesses, new shape: (402, 17)
# Dropped permanently closed column, new shape: (402, 16)
# Kept operational businesses, new shape: (394, 16)
# Excluded travel agencies, new shape: (392, 16)
# Dropped specified columns, new shape: (392, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Halmahera_Utara.csv
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Selatan.csv
# Initial shape: (523, 17)
# Removed permanently closed businesses, new shape: (489, 17)
# Dropped permanently closed column, new shape: (489, 16)
# Kept operational businesses, new shape: (480, 16)
# Excluded travel agencies, new shape: (479, 16)
# Dropped specified columns, new shape: (479, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Hulu_Sungai_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Tengah.csv
# Initial shape: (637, 17)
# Removed permanently closed businesses, new shape: (612, 17)
# Dropped permanently closed column, new shape: (612, 16)
# Kept operational businesses, new shape: (606, 16)
# Excluded travel agencies, new shape: (606, 16)
# Dropped specified columns, new shape: (606, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Hulu_Sungai_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Utara.csv
# Initial shape: (506, 17)
# Removed permanently closed businesses, new shape: (492, 17)
# Dropped permanently closed column, new shape: (492, 16)
# Kept operational businesses, new shape: (489, 16)
# Excluded travel agencies, new shape: (488, 16)
# Dropped specified columns, new shape: (488, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Hulu_Sungai_Utara.csv
# Processing TA_DS_clean\Kabupaten_Humbang_Hasundutan.csv
# Initial shape: (396, 17)
# Removed permanently closed businesses, new shape: (389, 17)
# Dropped permanently closed column, new shape: (389, 16)
# Kept operational businesses, new shape: (385, 16)
# Excluded travel agencies, new shape: (385, 16)
# Dropped specified columns, new shape: (385, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Humbang_Hasundutan.csv
# Processing TA_DS_clean\Kabupaten_Indragiri_Hilir.csv
# Initial shape: (192, 17)
# Removed permanently closed businesses, new shape: (168, 17)
# Dropped permanently closed column, new shape: (168, 16)
# Kept operational businesses, new shape: (155, 16)
# Excluded travel agencies, new shape: (150, 16)
# Dropped specified columns, new shape: (150, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Indragiri_Hilir.csv
# Processing TA_DS_clean\Kabupaten_Indragiri_Hulu.csv
# Initial shape: (360, 17)
# Removed permanently closed businesses, new shape: (341, 17)
# Dropped permanently closed column, new shape: (341, 16)
# Kept operational businesses, new shape: (330, 16)
# Excluded travel agencies, new shape: (330, 16)
# Dropped specified columns, new shape: (330, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Indragiri_Hulu.csv
# Processing TA_DS_clean\Kabupaten_Indramayu.csv
# Initial shape: (894, 17)
# Removed permanently closed businesses, new shape: (869, 17)
# Dropped permanently closed column, new shape: (869, 16)
# Kept operational businesses, new shape: (861, 16)
# Excluded travel agencies, new shape: (857, 16)
# Dropped specified columns, new shape: (857, 8)
# File overwritten with filtered data: TA_DS_clean\Kabupaten_Indramayu.csv
# Processing TA_DS_clean\Kabupaten_Intan_Jaya.csv
# Initial shape: (37, 16)
# ...
# Dropped specified columns, new shape: (355, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Padang_Panjang.csv
# Processing TA_DS_clean\Kota_Pagar_Alam.csv
# Initial shape: (300, 17)
# Removed permanently closed businesses, new shape: (298, 17)
# Dropped permanently closed column, new shape: (298, 16)
# Kept operational businesses, new shape: (298, 16)
# Excluded travel agencies, new shape: (298, 16)
# Dropped specified columns, new shape: (298, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pagar_Alam.csv
# Processing TA_DS_clean\Kota_Palangka_Raya.csv
# Initial shape: (240, 17)
# Removed permanently closed businesses, new shape: (227, 17)
# Dropped permanently closed column, new shape: (227, 16)
# Kept operational businesses, new shape: (226, 16)
# Excluded travel agencies, new shape: (226, 16)
# Dropped specified columns, new shape: (226, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Palangka_Raya.csv
# Processing TA_DS_clean\Kota_Palembang.csv
# Initial shape: (779, 17)
# Removed permanently closed businesses, new shape: (772, 17)
# Dropped permanently closed column, new shape: (772, 16)
# Kept operational businesses, new shape: (770, 16)
# Excluded travel agencies, new shape: (770, 16)
# Dropped specified columns, new shape: (770, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Palembang.csv
# Processing TA_DS_clean\Kota_Palopo.csv
# Initial shape: (385, 17)
# Removed permanently closed businesses, new shape: (379, 17)
# Dropped permanently closed column, new shape: (379, 16)
# Kept operational businesses, new shape: (378, 16)
# Excluded travel agencies, new shape: (376, 16)
# Dropped specified columns, new shape: (376, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Palopo.csv
# Processing TA_DS_clean\Kota_Palu.csv
# Initial shape: (424, 17)
# Removed permanently closed businesses, new shape: (423, 17)
# Dropped permanently closed column, new shape: (423, 16)
# Kept operational businesses, new shape: (421, 16)
# Excluded travel agencies, new shape: (420, 16)
# Dropped specified columns, new shape: (420, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Palu.csv
# Processing TA_DS_clean\Kota_Pangkal_Pinang.csv
# Initial shape: (761, 18)
# Dropped price_level, new shape: (761, 17)
# Removed permanently closed businesses, new shape: (752, 17)
# Dropped permanently closed column, new shape: (752, 16)
# Kept operational businesses, new shape: (738, 16)
# Excluded travel agencies, new shape: (736, 16)
# Dropped specified columns, new shape: (736, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pangkal_Pinang.csv
# Processing TA_DS_clean\Kota_Parepare.csv
# Initial shape: (204, 17)
# Removed permanently closed businesses, new shape: (190, 17)
# Dropped permanently closed column, new shape: (190, 16)
# Kept operational businesses, new shape: (182, 16)
# Excluded travel agencies, new shape: (182, 16)
# Dropped specified columns, new shape: (182, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Parepare.csv
# Processing TA_DS_clean\Kota_Pariaman.csv
# Initial shape: (271, 17)
# Removed permanently closed businesses, new shape: (270, 17)
# Dropped permanently closed column, new shape: (270, 16)
# Kept operational businesses, new shape: (269, 16)
# Excluded travel agencies, new shape: (264, 16)
# Dropped specified columns, new shape: (264, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pariaman.csv
# Processing TA_DS_clean\Kota_Pasuruan.csv
# Initial shape: (86, 17)
# Removed permanently closed businesses, new shape: (82, 17)
# Dropped permanently closed column, new shape: (82, 16)
# Kept operational businesses, new shape: (82, 16)
# Excluded travel agencies, new shape: (82, 16)
# Dropped specified columns, new shape: (82, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pasuruan.csv
# Processing TA_DS_clean\Kota_Payakumbuh.csv
# Initial shape: (295, 17)
# Removed permanently closed businesses, new shape: (291, 17)
# Dropped permanently closed column, new shape: (291, 16)
# Kept operational businesses, new shape: (289, 16)
# Excluded travel agencies, new shape: (286, 16)
# Dropped specified columns, new shape: (286, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Payakumbuh.csv
# Processing TA_DS_clean\Kota_Pekalongan.csv
# Initial shape: (300, 17)
# Removed permanently closed businesses, new shape: (287, 17)
# Dropped permanently closed column, new shape: (287, 16)
# Kept operational businesses, new shape: (287, 16)
# Excluded travel agencies, new shape: (287, 16)
# Dropped specified columns, new shape: (287, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pekalongan.csv
# Processing TA_DS_clean\Kota_Pekanbaru.csv
# Initial shape: (570, 17)
# Removed permanently closed businesses, new shape: (563, 17)
# Dropped permanently closed column, new shape: (563, 16)
# Kept operational businesses, new shape: (558, 16)
# Excluded travel agencies, new shape: (555, 16)
# Dropped specified columns, new shape: (555, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pekanbaru.csv
# Processing TA_DS_clean\Kota_Pematang_Siantar.csv
# Initial shape: (244, 17)
# Removed permanently closed businesses, new shape: (224, 17)
# Dropped permanently closed column, new shape: (224, 16)
# Kept operational businesses, new shape: (220, 16)
# Excluded travel agencies, new shape: (220, 16)
# Dropped specified columns, new shape: (220, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pematang_Siantar.csv
# Processing TA_DS_clean\Kota_Pontianak.csv
# Initial shape: (360, 17)
# Removed permanently closed businesses, new shape: (353, 17)
# Dropped permanently closed column, new shape: (353, 16)
# Kept operational businesses, new shape: (352, 16)
# Excluded travel agencies, new shape: (348, 16)
# Dropped specified columns, new shape: (348, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Pontianak.csv
# Processing TA_DS_clean\Kota_Prabumulih.csv
# Initial shape: (278, 17)
# Removed permanently closed businesses, new shape: (239, 17)
# Dropped permanently closed column, new shape: (239, 16)
# Kept operational businesses, new shape: (222, 16)
# Excluded travel agencies, new shape: (221, 16)
# Dropped specified columns, new shape: (221, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Prabumulih.csv
# Processing TA_DS_clean\Kota_Probolinggo.csv
# Initial shape: (133, 17)
# Removed permanently closed businesses, new shape: (128, 17)
# Dropped permanently closed column, new shape: (128, 16)
# Kept operational businesses, new shape: (128, 16)
# Excluded travel agencies, new shape: (128, 16)
# Dropped specified columns, new shape: (128, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Probolinggo.csv
# Processing TA_DS_clean\Kota_Salatiga.csv
# Initial shape: (264, 18)
# Dropped price_level, new shape: (264, 17)
# Removed permanently closed businesses, new shape: (261, 17)
# Dropped permanently closed column, new shape: (261, 16)
# Kept operational businesses, new shape: (260, 16)
# Excluded travel agencies, new shape: (259, 16)
# Dropped specified columns, new shape: (259, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Salatiga.csv
# Processing TA_DS_clean\Kota_Samarinda.csv
# Initial shape: (555, 17)
# Removed permanently closed businesses, new shape: (535, 17)
# Dropped permanently closed column, new shape: (535, 16)
# Kept operational businesses, new shape: (532, 16)
# Excluded travel agencies, new shape: (530, 16)
# Dropped specified columns, new shape: (530, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Samarinda.csv
# Processing TA_DS_clean\Kota_Sawahlunto.csv
# Initial shape: (310, 17)
# Removed permanently closed businesses, new shape: (272, 17)
# Dropped permanently closed column, new shape: (272, 16)
# Kept operational businesses, new shape: (264, 16)
# Excluded travel agencies, new shape: (262, 16)
# Dropped specified columns, new shape: (262, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Sawahlunto.csv
# Processing TA_DS_clean\Kota_Semarang.csv
# Initial shape: (298, 17)
# Removed permanently closed businesses, new shape: (295, 17)
# Dropped permanently closed column, new shape: (295, 16)
# Kept operational businesses, new shape: (294, 16)
# Excluded travel agencies, new shape: (286, 16)
# Dropped specified columns, new shape: (286, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Semarang.csv
# Processing TA_DS_clean\Kota_Serang.csv
# Initial shape: (244, 17)
# Removed permanently closed businesses, new shape: (240, 17)
# Dropped permanently closed column, new shape: (240, 16)
# Kept operational businesses, new shape: (238, 16)
# Excluded travel agencies, new shape: (238, 16)
# Dropped specified columns, new shape: (238, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Serang.csv
# Processing TA_DS_clean\Kota_Singkawang.csv
# Initial shape: (286, 17)
# Removed permanently closed businesses, new shape: (276, 17)
# Dropped permanently closed column, new shape: (276, 16)
# Kept operational businesses, new shape: (274, 16)
# Excluded travel agencies, new shape: (274, 16)
# Dropped specified columns, new shape: (274, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Singkawang.csv
# Processing TA_DS_clean\Kota_Soe.csv
# Initial shape: (185, 17)
# Removed permanently closed businesses, new shape: (145, 17)
# Dropped permanently closed column, new shape: (145, 16)
# Kept operational businesses, new shape: (141, 16)
# Excluded travel agencies, new shape: (140, 16)
# Dropped specified columns, new shape: (140, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Soe.csv
# Processing TA_DS_clean\Kota_Sorong.csv
# Initial shape: (840, 17)
# Removed permanently closed businesses, new shape: (831, 17)
# Dropped permanently closed column, new shape: (831, 16)
# Kept operational businesses, new shape: (829, 16)
# Excluded travel agencies, new shape: (825, 16)
# Dropped specified columns, new shape: (825, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Sorong.csv
# Processing TA_DS_clean\Kota_Sukabumi.csv
# Initial shape: (241, 17)
# Removed permanently closed businesses, new shape: (237, 17)
# Dropped permanently closed column, new shape: (237, 16)
# Kept operational businesses, new shape: (234, 16)
# Excluded travel agencies, new shape: (233, 16)
# Dropped specified columns, new shape: (233, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Sukabumi.csv
# Processing TA_DS_clean\Kota_Surabaya.csv
# Initial shape: (1374, 18)
# Dropped price_level, new shape: (1374, 17)
# Removed permanently closed businesses, new shape: (1351, 17)
# Dropped permanently closed column, new shape: (1351, 16)
# Kept operational businesses, new shape: (1325, 16)
# Excluded travel agencies, new shape: (1305, 16)
# Dropped specified columns, new shape: (1305, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Surabaya.csv
# Processing TA_DS_clean\Kota_Surakarta.csv
# Initial shape: (329, 18)
# Dropped price_level, new shape: (329, 17)
# Removed permanently closed businesses, new shape: (317, 17)
# Dropped permanently closed column, new shape: (317, 16)
# Kept operational businesses, new shape: (317, 16)
# Excluded travel agencies, new shape: (317, 16)
# Dropped specified columns, new shape: (317, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Surakarta.csv
# Processing TA_DS_clean\Kota_Taman.csv
# Initial shape: (144, 17)
# Removed permanently closed businesses, new shape: (137, 17)
# Dropped permanently closed column, new shape: (137, 16)
# Kept operational businesses, new shape: (137, 16)
# Excluded travel agencies, new shape: (128, 16)
# Dropped specified columns, new shape: (128, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Taman.csv
# Processing TA_DS_clean\Kota_Tangerang.csv
# Initial shape: (472, 18)
# Dropped price_level, new shape: (472, 17)
# Removed permanently closed businesses, new shape: (419, 17)
# Dropped permanently closed column, new shape: (419, 16)
# Kept operational businesses, new shape: (414, 16)
# Excluded travel agencies, new shape: (413, 16)
# Dropped specified columns, new shape: (413, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tangerang.csv
# Processing TA_DS_clean\Kota_Tangerang_Selatan.csv
# Initial shape: (287, 18)
# Dropped price_level, new shape: (287, 17)
# Removed permanently closed businesses, new shape: (273, 17)
# Dropped permanently closed column, new shape: (273, 16)
# Kept operational businesses, new shape: (261, 16)
# Excluded travel agencies, new shape: (259, 16)
# Dropped specified columns, new shape: (259, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tangerang_Selatan.csv
# Processing TA_DS_clean\Kota_Tanjungbalai.csv
# Initial shape: (158, 18)
# Dropped price_level, new shape: (158, 17)
# Removed permanently closed businesses, new shape: (138, 17)
# Dropped permanently closed column, new shape: (138, 16)
# Kept operational businesses, new shape: (130, 16)
# Excluded travel agencies, new shape: (129, 16)
# Dropped specified columns, new shape: (129, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tanjungbalai.csv
# Processing TA_DS_clean\Kota_Tanjung_Pinang.csv
# Initial shape: (240, 16)
# Kept operational businesses, new shape: (240, 16)
# Excluded travel agencies, new shape: (234, 16)
# Dropped specified columns, new shape: (234, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tanjung_Pinang.csv
# Processing TA_DS_clean\Kota_Tarakan.csv
# Initial shape: (240, 17)
# Removed permanently closed businesses, new shape: (221, 17)
# Dropped permanently closed column, new shape: (221, 16)
# Kept operational businesses, new shape: (221, 16)
# Excluded travel agencies, new shape: (221, 16)
# Dropped specified columns, new shape: (221, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tarakan.csv
# Processing TA_DS_clean\Kota_Tasikmalaya.csv
# Initial shape: (207, 17)
# Removed permanently closed businesses, new shape: (201, 17)
# Dropped permanently closed column, new shape: (201, 16)
# Kept operational businesses, new shape: (201, 16)
# Excluded travel agencies, new shape: (199, 16)
# Dropped specified columns, new shape: (199, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tasikmalaya.csv
# Processing TA_DS_clean\Kota_Tebing_Tinggi.csv
# Initial shape: (447, 18)
# Dropped price_level, new shape: (447, 17)
# Removed permanently closed businesses, new shape: (412, 17)
# Dropped permanently closed column, new shape: (412, 16)
# Kept operational businesses, new shape: (392, 16)
# Excluded travel agencies, new shape: (368, 16)
# Dropped specified columns, new shape: (368, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tebing_Tinggi.csv
# Processing TA_DS_clean\Kota_Tegal.csv
# Initial shape: (300, 17)
# Removed permanently closed businesses, new shape: (288, 17)
# Dropped permanently closed column, new shape: (288, 16)
# Kept operational businesses, new shape: (288, 16)
# Excluded travel agencies, new shape: (288, 16)
# Dropped specified columns, new shape: (288, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tegal.csv
# Processing TA_DS_clean\Kota_Ternate.csv
# Initial shape: (240, 16)
# Kept operational businesses, new shape: (238, 16)
# Excluded travel agencies, new shape: (236, 16)
# Dropped specified columns, new shape: (236, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Ternate.csv
# Processing TA_DS_clean\Kota_Tidore_Kepulauan.csv
# Initial shape: (168, 17)
# Removed permanently closed businesses, new shape: (136, 17)
# Dropped permanently closed column, new shape: (136, 16)
# Kept operational businesses, new shape: (134, 16)
# Excluded travel agencies, new shape: (134, 16)
# Dropped specified columns, new shape: (134, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tidore_Kepulauan.csv
# Processing TA_DS_clean\Kota_Tomohon.csv
# Initial shape: (300, 16)
# Kept operational businesses, new shape: (300, 16)
# Excluded travel agencies, new shape: (300, 16)
# Dropped specified columns, new shape: (300, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tomohon.csv
# Processing TA_DS_clean\Kota_Tual.csv
# Initial shape: (127, 17)
# Removed permanently closed businesses, new shape: (125, 17)
# Dropped permanently closed column, new shape: (125, 16)
# Kept operational businesses, new shape: (117, 16)
# Excluded travel agencies, new shape: (112, 16)
# Dropped specified columns, new shape: (112, 8)
# File overwritten with filtered data: TA_DS_clean\Kota_Tual.csv
# All files have been processed.

# %%
for file_name in os.listdir(clean_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(clean_path, file_name)
        print(f'Processing {file_path} for duplicates')

        # Load the CSV file
        df = pd.read_csv(file_path)
        initial_shape = df.shape
        print(f'Initial shape: {initial_shape}')

        # Remove duplicates based on 'place_id'
        df.drop_duplicates(subset='place_id', keep='first', inplace=True)
        new_shape = df.shape
        print(f'Duplicates removed, new shape: {new_shape}')

        # Save the DataFrame back to CSV
        df.to_csv(file_path, index=False)
        print(f'File overwritten with duplicates removed: {file_path}')

print("All duplicates have been processed.")
# Out:
# Processing TA_DS_clean\Kabupaten_Aceh_Barat.csv for duplicates
# Initial shape: (163, 8)
# Duplicates removed, new shape: (78, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Barat.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Barat_Daya.csv for duplicates
# Initial shape: (165, 8)
# Duplicates removed, new shape: (55, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Barat_Daya.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Besar.csv for duplicates
# Initial shape: (310, 8)
# Duplicates removed, new shape: (175, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Besar.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Jaya.csv for duplicates
# Initial shape: (295, 8)
# Duplicates removed, new shape: (187, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Jaya.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Selatan.csv for duplicates
# Initial shape: (160, 8)
# Duplicates removed, new shape: (67, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Singkil.csv for duplicates
# Initial shape: (167, 8)
# Duplicates removed, new shape: (98, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Singkil.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Tamiang.csv for duplicates
# Initial shape: (232, 8)
# Duplicates removed, new shape: (108, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Tamiang.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Tengah.csv for duplicates
# Initial shape: (143, 8)
# Duplicates removed, new shape: (92, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Tenggara.csv for duplicates
# Initial shape: (228, 8)
# Duplicates removed, new shape: (89, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Tenggara.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Timur.csv for duplicates
# Initial shape: (144, 8)
# Duplicates removed, new shape: (71, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Timur.csv
# Processing TA_DS_clean\Kabupaten_Aceh_Utara.csv for duplicates
# Initial shape: (189, 8)
# Duplicates removed, new shape: (139, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Aceh_Utara.csv
# Processing TA_DS_clean\Kabupaten_Agam.csv for duplicates
# Initial shape: (660, 8)
# Duplicates removed, new shape: (296, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Agam.csv
# Processing TA_DS_clean\Kabupaten_Alor.csv for duplicates
# Initial shape: (433, 8)
# Duplicates removed, new shape: (114, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Alor.csv
# Processing TA_DS_clean\Kabupaten_Asahan.csv for duplicates
# Initial shape: (608, 8)
# Duplicates removed, new shape: (231, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Asahan.csv
# Processing TA_DS_clean\Kabupaten_Asmat.csv for duplicates
# Initial shape: (120, 8)
# Duplicates removed, new shape: (66, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Asmat.csv
# Processing TA_DS_clean\Kabupaten_Badung.csv for duplicates
# Initial shape: (181, 8)
# Duplicates removed, new shape: (163, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Badung.csv
# Processing TA_DS_clean\Kabupaten_Balangan.csv for duplicates
# Initial shape: (404, 8)
# Duplicates removed, new shape: (108, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Balangan.csv
# Processing TA_DS_clean\Kabupaten_Bandung.csv for duplicates
# Initial shape: (1159, 8)
# Duplicates removed, new shape: (755, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bandung.csv
# Processing TA_DS_clean\Kabupaten_Bandung_Barat.csv for duplicates
# Initial shape: (647, 8)
# Duplicates removed, new shape: (508, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bandung_Barat.csv
# Processing TA_DS_clean\Kabupaten_Banggai.csv for duplicates
# Initial shape: (489, 8)
# Duplicates removed, new shape: (175, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banggai.csv
# Processing TA_DS_clean\Kabupaten_Banggai_Kepulauan.csv for duplicates
# Initial shape: (455, 8)
# Duplicates removed, new shape: (134, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banggai_Kepulauan.csv
# Processing TA_DS_clean\Kabupaten_Banggai_Laut.csv for duplicates
# Initial shape: (185, 8)
# Duplicates removed, new shape: (87, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banggai_Laut.csv
# Processing TA_DS_clean\Kabupaten_Bangka.csv for duplicates
# Initial shape: (331, 8)
# Duplicates removed, new shape: (191, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bangka.csv
# Processing TA_DS_clean\Kabupaten_Bangkalan.csv for duplicates
# Initial shape: (451, 8)
# Duplicates removed, new shape: (187, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bangkalan.csv
# Processing TA_DS_clean\Kabupaten_Bangka_Barat.csv for duplicates
# Initial shape: (140, 8)
# Duplicates removed, new shape: (129, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bangka_Barat.csv
# Processing TA_DS_clean\Kabupaten_Bangka_Selatan.csv for duplicates
# Initial shape: (260, 8)
# Duplicates removed, new shape: (145, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bangka_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Bangka_Tengah.csv for duplicates
# Initial shape: (378, 8)
# Duplicates removed, new shape: (183, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bangka_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Bangli.csv for duplicates
# Initial shape: (195, 8)
# Duplicates removed, new shape: (154, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bangli.csv
# Processing TA_DS_clean\Kabupaten_Banjar.csv for duplicates
# Initial shape: (537, 8)
# Duplicates removed, new shape: (286, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banjar.csv
# Processing TA_DS_clean\Kabupaten_Banjarnegara.csv for duplicates
# Initial shape: (675, 8)
# Duplicates removed, new shape: (370, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banjarnegara.csv
# Processing TA_DS_clean\Kabupaten_Bantaeng.csv for duplicates
# Initial shape: (301, 8)
# Duplicates removed, new shape: (86, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bantaeng.csv
# Processing TA_DS_clean\Kabupaten_Banyuasin.csv for duplicates
# Initial shape: (416, 8)
# Duplicates removed, new shape: (208, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banyuasin.csv
# Processing TA_DS_clean\Kabupaten_Banyumas.csv for duplicates
# Initial shape: (1232, 8)
# Duplicates removed, new shape: (626, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banyumas.csv
# Processing TA_DS_clean\Kabupaten_Banyuwangi.csv for duplicates
# Initial shape: (889, 8)
# Duplicates removed, new shape: (613, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Banyuwangi.csv
# Processing TA_DS_clean\Kabupaten_Barito_Kuala.csv for duplicates
# Initial shape: (176, 8)
# Duplicates removed, new shape: (90, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Barito_Kuala.csv
# Processing TA_DS_clean\Kabupaten_Barito_Selatan.csv for duplicates
# Initial shape: (609, 8)
# Duplicates removed, new shape: (203, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Barito_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Barito_Timur.csv for duplicates
# Initial shape: (646, 8)
# Duplicates removed, new shape: (150, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Barito_Timur.csv
# Processing TA_DS_clean\Kabupaten_Barito_Utara.csv for duplicates
# Initial shape: (298, 8)
# Duplicates removed, new shape: (153, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Barito_Utara.csv
# Processing TA_DS_clean\Kabupaten_Barru.csv for duplicates
# Initial shape: (255, 8)
# Duplicates removed, new shape: (104, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Barru.csv
# Processing TA_DS_clean\Kabupaten_Batang.csv for duplicates
# Initial shape: (349, 8)
# Duplicates removed, new shape: (258, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Batang.csv
# Processing TA_DS_clean\Kabupaten_Batang_Hari.csv for duplicates
# Initial shape: (479, 8)
# Duplicates removed, new shape: (91, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Batang_Hari.csv
# Processing TA_DS_clean\Kabupaten_Batu_Bara.csv for duplicates
# Initial shape: (501, 8)
# Duplicates removed, new shape: (140, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Batu_Bara.csv
# Processing TA_DS_clean\Kabupaten_Bekasi.csv for duplicates
# Initial shape: (1158, 8)
# Duplicates removed, new shape: (542, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bekasi.csv
# Processing TA_DS_clean\Kabupaten_Belitung.csv for duplicates
# Initial shape: (382, 8)
# Duplicates removed, new shape: (173, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Belitung.csv
# Processing TA_DS_clean\Kabupaten_Belitung_Timur.csv for duplicates
# Initial shape: (169, 8)
# Duplicates removed, new shape: (108, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Belitung_Timur.csv
# Processing TA_DS_clean\Kabupaten_Belu.csv for duplicates
# Initial shape: (659, 8)
# Duplicates removed, new shape: (118, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Belu.csv
# Processing TA_DS_clean\Kabupaten_Bener_Meriah.csv for duplicates
# Initial shape: (149, 8)
# Duplicates removed, new shape: (100, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bener_Meriah.csv
# Processing TA_DS_clean\Kabupaten_Bengkalis.csv for duplicates
# Initial shape: (230, 8)
# Duplicates removed, new shape: (132, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bengkalis.csv
# Processing TA_DS_clean\Kabupaten_Bengkayang.csv for duplicates
# Initial shape: (483, 8)
# Duplicates removed, new shape: (161, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bengkayang.csv
# Processing TA_DS_clean\Kabupaten_Berau.csv for duplicates
# Initial shape: (403, 8)
# Duplicates removed, new shape: (213, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Berau.csv
# Processing TA_DS_clean\Kabupaten_Bima.csv for duplicates
# Initial shape: (642, 8)
# Duplicates removed, new shape: (341, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bima.csv
# Processing TA_DS_clean\Kabupaten_Bintan.csv for duplicates
# Initial shape: (211, 8)
# Duplicates removed, new shape: (131, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bintan.csv
# Processing TA_DS_clean\Kabupaten_Bireuen.csv for duplicates
# Initial shape: (359, 8)
# Duplicates removed, new shape: (127, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bireuen.csv
# Processing TA_DS_clean\Kabupaten_Blitar.csv for duplicates
# Initial shape: (799, 8)
# Duplicates removed, new shape: (509, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Blitar.csv
# Processing TA_DS_clean\Kabupaten_Blora.csv for duplicates
# Initial shape: (743, 8)
# Duplicates removed, new shape: (384, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Blora.csv
# Processing TA_DS_clean\Kabupaten_Boalemo.csv for duplicates
# Initial shape: (143, 8)
# Duplicates removed, new shape: (84, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Boalemo.csv
# Processing TA_DS_clean\Kabupaten_Bogor.csv for duplicates
# Initial shape: (1733, 8)
# Duplicates removed, new shape: (1385, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bogor.csv
# Processing TA_DS_clean\Kabupaten_Bojonegoro.csv for duplicates
# Initial shape: (1022, 8)
# Duplicates removed, new shape: (368, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bojonegoro.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow.csv for duplicates
# Initial shape: (521, 8)
# Duplicates removed, new shape: (179, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bolaang_Mongondow.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Selatan.csv for duplicates
# Initial shape: (293, 8)
# Duplicates removed, new shape: (101, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Timur.csv for duplicates
# Initial shape: (251, 8)
# Duplicates removed, new shape: (109, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Timur.csv
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Utara.csv for duplicates
# Initial shape: (140, 8)
# Duplicates removed, new shape: (58, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bolaang_Mongondow_Utara.csv
# Processing TA_DS_clean\Kabupaten_Bombana.csv for duplicates
# Initial shape: (217, 8)
# Duplicates removed, new shape: (83, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bombana.csv
# Processing TA_DS_clean\Kabupaten_Bondowoso.csv for duplicates
# Initial shape: (743, 8)
# Duplicates removed, new shape: (234, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bondowoso.csv
# Processing TA_DS_clean\Kabupaten_Bone.csv for duplicates
# Initial shape: (650, 8)
# Duplicates removed, new shape: (197, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bone.csv
# Processing TA_DS_clean\Kabupaten_Bone_Bolango.csv for duplicates
# Initial shape: (840, 8)
# Duplicates removed, new shape: (172, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bone_Bolango.csv
# Processing TA_DS_clean\Kabupaten_Boven_Digoel.csv for duplicates
# Initial shape: (54, 8)
# Duplicates removed, new shape: (21, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Boven_Digoel.csv
# Processing TA_DS_clean\Kabupaten_Boyolali.csv for duplicates
# Initial shape: (745, 8)
# Duplicates removed, new shape: (456, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Boyolali.csv
# Processing TA_DS_clean\Kabupaten_Brebes.csv for duplicates
# Initial shape: (622, 8)
# Duplicates removed, new shape: (391, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Brebes.csv
# Processing TA_DS_clean\Kabupaten_Buleleng.csv for duplicates
# Initial shape: (391, 8)
# Duplicates removed, new shape: (360, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Buleleng.csv
# Processing TA_DS_clean\Kabupaten_Bulukumba.csv for duplicates
# Initial shape: (466, 8)
# Duplicates removed, new shape: (187, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bulukumba.csv
# Processing TA_DS_clean\Kabupaten_Bulungan.csv for duplicates
# Initial shape: (337, 8)
# Duplicates removed, new shape: (113, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bulungan.csv
# Processing TA_DS_clean\Kabupaten_Bungo.csv for duplicates
# Initial shape: (149, 8)
# Duplicates removed, new shape: (71, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Bungo.csv
# Processing TA_DS_clean\Kabupaten_Buol.csv for duplicates
# Initial shape: (181, 8)
# Duplicates removed, new shape: (52, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Buol.csv
# Processing TA_DS_clean\Kabupaten_Buru.csv for duplicates
# Initial shape: (332, 8)
# Duplicates removed, new shape: (72, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Buru.csv
# Processing TA_DS_clean\Kabupaten_Buru_Selatan.csv for duplicates
# Initial shape: (263, 8)
# Duplicates removed, new shape: (81, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Buru_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Buton.csv for duplicates
# Initial shape: (316, 8)
# Duplicates removed, new shape: (219, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Buton.csv
# Processing TA_DS_clean\Kabupaten_Buton_Utara.csv for duplicates
# Initial shape: (493, 8)
# Duplicates removed, new shape: (162, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Buton_Utara.csv
# Processing TA_DS_clean\Kabupaten_Ciamis.csv for duplicates
# Initial shape: (1081, 8)
# Duplicates removed, new shape: (618, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Ciamis.csv
# Processing TA_DS_clean\Kabupaten_Cianjur.csv for duplicates
# Initial shape: (1114, 8)
# Duplicates removed, new shape: (695, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Cianjur.csv
# Processing TA_DS_clean\Kabupaten_Cilacap.csv for duplicates
# Initial shape: (853, 8)
# Duplicates removed, new shape: (491, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Cilacap.csv
# Processing TA_DS_clean\Kabupaten_Cirebon.csv for duplicates
# Initial shape: (910, 8)
# Duplicates removed, new shape: (347, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Cirebon.csv
# Processing TA_DS_clean\Kabupaten_Dairi.csv for duplicates
# Initial shape: (584, 8)
# Duplicates removed, new shape: (248, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Dairi.csv
# Processing TA_DS_clean\Kabupaten_Deiyai.csv for duplicates
# Initial shape: (132, 8)
# Duplicates removed, new shape: (21, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Deiyai.csv
# Processing TA_DS_clean\Kabupaten_Deli_Serdang.csv for duplicates
# Initial shape: (734, 8)
# Duplicates removed, new shape: (286, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Deli_Serdang.csv
# Processing TA_DS_clean\Kabupaten_Demak.csv for duplicates
# Initial shape: (278, 8)
# Duplicates removed, new shape: (191, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Demak.csv
# Processing TA_DS_clean\Kabupaten_Dharmasraya.csv for duplicates
# Initial shape: (129, 8)
# Duplicates removed, new shape: (56, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Dharmasraya.csv
# Processing TA_DS_clean\Kabupaten_Dogiyai.csv for duplicates
# Initial shape: (66, 8)
# Duplicates removed, new shape: (32, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Dogiyai.csv
# Processing TA_DS_clean\Kabupaten_Dompu.csv for duplicates
# Initial shape: (307, 8)
# Duplicates removed, new shape: (169, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Dompu.csv
# Processing TA_DS_clean\Kabupaten_Donggala.csv for duplicates
# Initial shape: (412, 8)
# Duplicates removed, new shape: (185, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Donggala.csv
# Processing TA_DS_clean\Kabupaten_Empat_Lawang.csv for duplicates
# Initial shape: (82, 8)
# Duplicates removed, new shape: (45, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Empat_Lawang.csv
# Processing TA_DS_clean\Kabupaten_Ende.csv for duplicates
# Initial shape: (740, 8)
# Duplicates removed, new shape: (170, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Ende.csv
# Processing TA_DS_clean\Kabupaten_Enrekang.csv for duplicates
# Initial shape: (535, 8)
# Duplicates removed, new shape: (172, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Enrekang.csv
# Processing TA_DS_clean\Kabupaten_Fakfak.csv for duplicates
# Initial shape: (145, 8)
# Duplicates removed, new shape: (49, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Fakfak.csv
# Processing TA_DS_clean\Kabupaten_Flores_Timur.csv for duplicates
# Initial shape: (434, 8)
# Duplicates removed, new shape: (161, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Flores_Timur.csv
# Processing TA_DS_clean\Kabupaten_Garut.csv for duplicates
# Initial shape: (1461, 8)
# Duplicates removed, new shape: (719, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Garut.csv
# Processing TA_DS_clean\Kabupaten_Gayo_Lues.csv for duplicates
# Initial shape: (316, 8)
# Duplicates removed, new shape: (137, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gayo_Lues.csv
# Processing TA_DS_clean\Kabupaten_Gianyar.csv for duplicates
# Initial shape: (327, 8)
# Duplicates removed, new shape: (249, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gianyar.csv
# Processing TA_DS_clean\Kabupaten_Gorontalo.csv for duplicates
# Initial shape: (772, 8)
# Duplicates removed, new shape: (253, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gorontalo.csv
# Processing TA_DS_clean\Kabupaten_Gorontalo_Utara.csv for duplicates
# Initial shape: (193, 8)
# Duplicates removed, new shape: (119, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gorontalo_Utara.csv
# Processing TA_DS_clean\Kabupaten_Gowa.csv for duplicates
# Initial shape: (697, 8)
# Duplicates removed, new shape: (381, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gowa.csv
# Processing TA_DS_clean\Kabupaten_Gresik.csv for duplicates
# Initial shape: (527, 8)
# Duplicates removed, new shape: (281, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gresik.csv
# Processing TA_DS_clean\Kabupaten_Grobogan.csv for duplicates
# Initial shape: (665, 8)
# Duplicates removed, new shape: (375, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Grobogan.csv
# Processing TA_DS_clean\Kabupaten_Gunung_Mas.csv for duplicates
# Initial shape: (125, 8)
# Duplicates removed, new shape: (74, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Gunung_Mas.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Barat.csv for duplicates
# Initial shape: (239, 8)
# Duplicates removed, new shape: (76, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Halmahera_Barat.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Selatan.csv for duplicates
# Initial shape: (214, 8)
# Duplicates removed, new shape: (134, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Halmahera_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Tengah.csv for duplicates
# Initial shape: (115, 8)
# Duplicates removed, new shape: (83, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Halmahera_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Halmahera_Utara.csv for duplicates
# Initial shape: (392, 8)
# Duplicates removed, new shape: (136, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Halmahera_Utara.csv
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Selatan.csv for duplicates
# Initial shape: (479, 8)
# Duplicates removed, new shape: (134, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Hulu_Sungai_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Tengah.csv for duplicates
# Initial shape: (606, 8)
# Duplicates removed, new shape: (123, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Hulu_Sungai_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Utara.csv for duplicates
# Initial shape: (488, 8)
# Duplicates removed, new shape: (121, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Hulu_Sungai_Utara.csv
# Processing TA_DS_clean\Kabupaten_Humbang_Hasundutan.csv for duplicates
# Initial shape: (385, 8)
# Duplicates removed, new shape: (174, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Humbang_Hasundutan.csv
# Processing TA_DS_clean\Kabupaten_Indragiri_Hilir.csv for duplicates
# Initial shape: (150, 8)
# Duplicates removed, new shape: (63, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Indragiri_Hilir.csv
# Processing TA_DS_clean\Kabupaten_Indragiri_Hulu.csv for duplicates
# Initial shape: (330, 8)
# Duplicates removed, new shape: (124, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Indragiri_Hulu.csv
# Processing TA_DS_clean\Kabupaten_Indramayu.csv for duplicates
# Initial shape: (857, 8)
# Duplicates removed, new shape: (318, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Indramayu.csv
# Processing TA_DS_clean\Kabupaten_Intan_Jaya.csv for duplicates
# Initial shape: (15, 8)
# Duplicates removed, new shape: (11, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Intan_Jaya.csv
# Processing TA_DS_clean\Kabupaten_Jayapura.csv for duplicates
# Initial shape: (334, 8)
# Duplicates removed, new shape: (162, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jayapura.csv
# Processing TA_DS_clean\Kabupaten_Jayawijaya.csv for duplicates
# Initial shape: (433, 8)
# Duplicates removed, new shape: (73, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jayawijaya.csv
# Processing TA_DS_clean\Kabupaten_Jember.csv for duplicates
# Initial shape: (959, 8)
# Duplicates removed, new shape: (421, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jember.csv
# Processing TA_DS_clean\Kabupaten_Jembrana.csv for duplicates
# Initial shape: (196, 8)
# Duplicates removed, new shape: (134, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jembrana.csv
# Processing TA_DS_clean\Kabupaten_Jeneponto.csv for duplicates
# Initial shape: (360, 8)
# Duplicates removed, new shape: (125, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jeneponto.csv
# Processing TA_DS_clean\Kabupaten_Jepara.csv for duplicates
# Initial shape: (670, 8)
# Duplicates removed, new shape: (407, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jepara.csv
# Processing TA_DS_clean\Kabupaten_Jombang.csv for duplicates
# Initial shape: (697, 8)
# Duplicates removed, new shape: (253, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Jombang.csv
# Processing TA_DS_clean\Kabupaten_Kaimana.csv for duplicates
# Initial shape: (125, 8)
# Duplicates removed, new shape: (56, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kaimana.csv
# Processing TA_DS_clean\Kabupaten_Kampar.csv for duplicates
# Initial shape: (793, 8)
# Duplicates removed, new shape: (271, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kampar.csv
# Processing TA_DS_clean\Kabupaten_Kapuas.csv for duplicates
# Initial shape: (250, 8)
# Duplicates removed, new shape: (120, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kapuas.csv
# Processing TA_DS_clean\Kabupaten_Kapuas_Hulu.csv for duplicates
# Initial shape: (154, 8)
# Duplicates removed, new shape: (101, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kapuas_Hulu.csv
# Processing TA_DS_clean\Kabupaten_Karanganyar.csv for duplicates
# Initial shape: (653, 8)
# Duplicates removed, new shape: (411, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Karanganyar.csv
# Processing TA_DS_clean\Kabupaten_Karangasem.csv for duplicates
# Initial shape: (444, 8)
# Duplicates removed, new shape: (298, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Karangasem.csv
# Processing TA_DS_clean\Kabupaten_Karawang.csv for duplicates
# Initial shape: (972, 8)
# Duplicates removed, new shape: (417, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Karawang.csv
# Processing TA_DS_clean\Kabupaten_Karimun.csv for duplicates
# Initial shape: (247, 8)
# Duplicates removed, new shape: (96, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Karimun.csv
# Processing TA_DS_clean\Kabupaten_Karo.csv for duplicates
# Initial shape: (502, 8)
# Duplicates removed, new shape: (231, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Karo.csv
# Processing TA_DS_clean\Kabupaten_Katingan.csv for duplicates
# Initial shape: (82, 8)
# Duplicates removed, new shape: (56, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Katingan.csv
# Processing TA_DS_clean\Kabupaten_Kayong_Utara.csv for duplicates
# Initial shape: (218, 8)
# Duplicates removed, new shape: (115, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kayong_Utara.csv
# Processing TA_DS_clean\Kabupaten_Kebumen.csv for duplicates
# Initial shape: (1587, 8)
# Duplicates removed, new shape: (508, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kebumen.csv
# Processing TA_DS_clean\Kabupaten_Kediri.csv for duplicates
# Initial shape: (889, 8)
# Duplicates removed, new shape: (402, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kediri.csv
# Processing TA_DS_clean\Kabupaten_Keerom.csv for duplicates
# Initial shape: (114, 8)
# Duplicates removed, new shape: (61, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Keerom.csv
# Processing TA_DS_clean\Kabupaten_Kendal.csv for duplicates
# Initial shape: (834, 8)
# Duplicates removed, new shape: (334, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kendal.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Aru.csv for duplicates
# Initial shape: (176, 8)
# Duplicates removed, new shape: (27, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Aru.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Mentawai.csv for duplicates
# Initial shape: (139, 8)
# Duplicates removed, new shape: (75, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Mentawai.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Meranti.csv for duplicates
# Initial shape: (499, 8)
# Duplicates removed, new shape: (114, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Meranti.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Sangihe.csv for duplicates
# Initial shape: (371, 8)
# Duplicates removed, new shape: (117, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Sangihe.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Selayar.csv for duplicates
# Initial shape: (312, 8)
# Duplicates removed, new shape: (124, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Selayar.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Sula.csv for duplicates
# Initial shape: (107, 8)
# Duplicates removed, new shape: (54, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Sula.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Talaud.csv for duplicates
# Initial shape: (308, 8)
# Duplicates removed, new shape: (84, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Talaud.csv
# Processing TA_DS_clean\Kabupaten_Kepulauan_Yapen.csv for duplicates
# Initial shape: (77, 8)
# Duplicates removed, new shape: (53, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kepulauan_Yapen.csv
# Processing TA_DS_clean\Kabupaten_Kerinci.csv for duplicates
# Initial shape: (488, 8)
# Duplicates removed, new shape: (179, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kerinci.csv
# Processing TA_DS_clean\Kabupaten_Ketapang.csv for duplicates
# Initial shape: (473, 8)
# Duplicates removed, new shape: (122, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Ketapang.csv
# Processing TA_DS_clean\Kabupaten_Klaten.csv for duplicates
# Initial shape: (1139, 8)
# Duplicates removed, new shape: (409, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Klaten.csv
# Processing TA_DS_clean\Kabupaten_Klungkung.csv for duplicates
# Initial shape: (221, 8)
# Duplicates removed, new shape: (171, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Klungkung.csv
# Processing TA_DS_clean\Kabupaten_Kolaka.csv for duplicates
# Initial shape: (645, 8)
# Duplicates removed, new shape: (133, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kolaka.csv
# Processing TA_DS_clean\Kabupaten_Kolaka_Timur.csv for duplicates
# Initial shape: (894, 8)
# Duplicates removed, new shape: (135, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kolaka_Timur.csv
# Processing TA_DS_clean\Kabupaten_Kolaka_Utara.csv for duplicates
# Initial shape: (156, 8)
# Duplicates removed, new shape: (84, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kolaka_Utara.csv
# Processing TA_DS_clean\Kabupaten_Konawe.csv for duplicates
# Initial shape: (305, 8)
# Duplicates removed, new shape: (135, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Konawe.csv
# Processing TA_DS_clean\Kabupaten_Konawe_Kepulauan.csv for duplicates
# Initial shape: (110, 8)
# Duplicates removed, new shape: (35, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Konawe_Kepulauan.csv
# Processing TA_DS_clean\Kabupaten_Konawe_Selatan.csv for duplicates
# Initial shape: (758, 8)
# Duplicates removed, new shape: (185, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Konawe_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Konawe_Utara.csv for duplicates
# Initial shape: (573, 8)
# Duplicates removed, new shape: (145, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Konawe_Utara.csv
# Processing TA_DS_clean\Kabupaten_Kotabaru.csv for duplicates
# Initial shape: (776, 8)
# Duplicates removed, new shape: (242, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kotabaru.csv
# Processing TA_DS_clean\Kabupaten_Kotawaringin_Barat.csv for duplicates
# Initial shape: (472, 8)
# Duplicates removed, new shape: (148, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kotawaringin_Barat.csv
# Processing TA_DS_clean\Kabupaten_Kotawaringin_Timur.csv for duplicates
# Initial shape: (518, 8)
# Duplicates removed, new shape: (194, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kotawaringin_Timur.csv
# Processing TA_DS_clean\Kabupaten_Kuantan_Singingi.csv for duplicates
# Initial shape: (650, 8)
# Duplicates removed, new shape: (118, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kuantan_Singingi.csv
# Processing TA_DS_clean\Kabupaten_Kubu_Raya.csv for duplicates
# Initial shape: (229, 8)
# Duplicates removed, new shape: (110, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kubu_Raya.csv
# Processing TA_DS_clean\Kabupaten_Kudus.csv for duplicates
# Initial shape: (298, 8)
# Duplicates removed, new shape: (162, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kudus.csv
# Processing TA_DS_clean\Kabupaten_Kuningan.csv for duplicates
# Initial shape: (1317, 8)
# Duplicates removed, new shape: (475, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kuningan.csv
# Processing TA_DS_clean\Kabupaten_Kupang.csv for duplicates
# Initial shape: (782, 8)
# Duplicates removed, new shape: (328, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kupang.csv
# Processing TA_DS_clean\Kabupaten_Kutai_Barat.csv for duplicates
# Initial shape: (190, 8)
# Duplicates removed, new shape: (108, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kutai_Barat.csv
# Processing TA_DS_clean\Kabupaten_Kutai_Kartanegara.csv for duplicates
# Initial shape: (549, 8)
# Duplicates removed, new shape: (421, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kutai_Kartanegara.csv
# Processing TA_DS_clean\Kabupaten_Kutai_Timur.csv for duplicates
# Initial shape: (266, 8)
# Duplicates removed, new shape: (200, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Kutai_Timur.csv
# Processing TA_DS_clean\Kabupaten_Labuhanbatu.csv for duplicates
# Initial shape: (304, 8)
# Duplicates removed, new shape: (124, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Labuhanbatu.csv
# Processing TA_DS_clean\Kabupaten_Labuhanbatu_Selatan.csv for duplicates
# Initial shape: (316, 8)
# Duplicates removed, new shape: (79, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Labuhanbatu_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Labuhanbatu_Utara.csv for duplicates
# Initial shape: (333, 8)
# Duplicates removed, new shape: (98, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Labuhanbatu_Utara.csv
# Processing TA_DS_clean\Kabupaten_Lahat.csv for duplicates
# Initial shape: (277, 8)
# Duplicates removed, new shape: (146, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lahat.csv
# Processing TA_DS_clean\Kabupaten_Lamandau.csv for duplicates
# Initial shape: (315, 8)
# Duplicates removed, new shape: (103, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lamandau.csv
# Processing TA_DS_clean\Kabupaten_Lamongan.csv for duplicates
# Initial shape: (862, 8)
# Duplicates removed, new shape: (309, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lamongan.csv
# Processing TA_DS_clean\Kabupaten_Lampung_Barat.csv for duplicates
# Initial shape: (392, 8)
# Duplicates removed, new shape: (195, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lampung_Barat.csv
# Processing TA_DS_clean\Kabupaten_Lampung_Selatan.csv for duplicates
# Initial shape: (515, 8)
# Duplicates removed, new shape: (372, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lampung_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Lampung_Tengah.csv for duplicates
# Initial shape: (522, 8)
# Duplicates removed, new shape: (261, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lampung_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Lampung_Timur.csv for duplicates
# Initial shape: (652, 8)
# Duplicates removed, new shape: (242, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lampung_Timur.csv
# Processing TA_DS_clean\Kabupaten_Lampung_Utara.csv for duplicates
# Initial shape: (503, 8)
# Duplicates removed, new shape: (154, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lampung_Utara.csv
# Processing TA_DS_clean\Kabupaten_Landak.csv for duplicates
# Initial shape: (131, 8)
# Duplicates removed, new shape: (85, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Landak.csv
# Processing TA_DS_clean\Kabupaten_Langkat.csv for duplicates
# Initial shape: (552, 8)
# Duplicates removed, new shape: (310, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Langkat.csv
# Processing TA_DS_clean\Kabupaten_Lanny_Jaya.csv for duplicates
# Initial shape: (235, 8)
# Duplicates removed, new shape: (73, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lanny_Jaya.csv
# Processing TA_DS_clean\Kabupaten_Lebak.csv for duplicates
# Initial shape: (1326, 8)
# Duplicates removed, new shape: (681, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lebak.csv
# Processing TA_DS_clean\Kabupaten_Lembata.csv for duplicates
# Initial shape: (204, 8)
# Duplicates removed, new shape: (80, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lembata.csv
# Processing TA_DS_clean\Kabupaten_Lima_Puluh_Kota.csv for duplicates
# Initial shape: (340, 8)
# Duplicates removed, new shape: (213, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lima_Puluh_Kota.csv
# Processing TA_DS_clean\Kabupaten_Lingga.csv for duplicates
# Initial shape: (224, 8)
# Duplicates removed, new shape: (85, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lingga.csv
# Processing TA_DS_clean\Kabupaten_Lombok_Barat.csv for duplicates
# Initial shape: (441, 8)
# Duplicates removed, new shape: (342, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lombok_Barat.csv
# Processing TA_DS_clean\Kabupaten_Lombok_Tengah.csv for duplicates
# Initial shape: (516, 8)
# Duplicates removed, new shape: (337, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lombok_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Lombok_Timur.csv for duplicates
# Initial shape: (776, 8)
# Duplicates removed, new shape: (468, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lombok_Timur.csv
# Processing TA_DS_clean\Kabupaten_Lombok_Utara.csv for duplicates
# Initial shape: (259, 8)
# Duplicates removed, new shape: (184, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lombok_Utara.csv
# Processing TA_DS_clean\Kabupaten_Lumajang.csv for duplicates
# Initial shape: (770, 8)
# Duplicates removed, new shape: (290, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Lumajang.csv
# Processing TA_DS_clean\Kabupaten_Luwu.csv for duplicates
# Initial shape: (504, 8)
# Duplicates removed, new shape: (226, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Luwu.csv
# Processing TA_DS_clean\Kabupaten_Luwu_Timur.csv for duplicates
# Initial shape: (305, 8)
# Duplicates removed, new shape: (157, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Luwu_Timur.csv
# Processing TA_DS_clean\Kabupaten_Luwu_Utara.csv for duplicates
# Initial shape: (336, 8)
# Duplicates removed, new shape: (117, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Luwu_Utara.csv
# Processing TA_DS_clean\Kabupaten_Madiun.csv for duplicates
# Initial shape: (428, 8)
# Duplicates removed, new shape: (235, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Madiun.csv
# Processing TA_DS_clean\Kabupaten_Magelang.csv for duplicates
# Initial shape: (727, 8)
# Duplicates removed, new shape: (546, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Magelang.csv
# Processing TA_DS_clean\Kabupaten_Magetan.csv for duplicates
# Initial shape: (654, 8)
# Duplicates removed, new shape: (271, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Magetan.csv
# Processing TA_DS_clean\Kabupaten_Mahakam_Ulu.csv for duplicates
# Initial shape: (43, 8)
# Duplicates removed, new shape: (20, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mahakam_Ulu.csv
# Processing TA_DS_clean\Kabupaten_Majalengka.csv for duplicates
# Initial shape: (980, 8)
# Duplicates removed, new shape: (356, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Majalengka.csv
# Processing TA_DS_clean\Kabupaten_Majene.csv for duplicates
# Initial shape: (236, 8)
# Duplicates removed, new shape: (107, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Majene.csv
# Processing TA_DS_clean\Kabupaten_Malaka.csv for duplicates
# Initial shape: (205, 8)
# Duplicates removed, new shape: (67, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Malaka.csv
# Processing TA_DS_clean\Kabupaten_Malang.csv for duplicates
# Initial shape: (867, 8)
# Duplicates removed, new shape: (745, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Malang.csv
# Processing TA_DS_clean\Kabupaten_Malinau.csv for duplicates
# Initial shape: (243, 8)
# Duplicates removed, new shape: (56, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Malinau.csv
# Processing TA_DS_clean\Kabupaten_Maluku_Barat_Daya.csv for duplicates
# Initial shape: (54, 8)
# Duplicates removed, new shape: (45, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Maluku_Barat_Daya.csv
# Processing TA_DS_clean\Kabupaten_Maluku_Tengah.csv for duplicates
# Initial shape: (120, 8)
# Duplicates removed, new shape: (85, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Maluku_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Maluku_Tenggara.csv for duplicates
# Initial shape: (242, 8)
# Duplicates removed, new shape: (86, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Maluku_Tenggara.csv
# Processing TA_DS_clean\Kabupaten_Maluku_Tenggara_Barat.csv for duplicates
# Initial shape: (118, 8)
# Duplicates removed, new shape: (54, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Maluku_Tenggara_Barat.csv
# Processing TA_DS_clean\Kabupaten_Mamasa.csv for duplicates
# Initial shape: (345, 8)
# Duplicates removed, new shape: (136, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mamasa.csv
# Processing TA_DS_clean\Kabupaten_Mamberamo_Raya.csv for duplicates
# Initial shape: (15, 8)
# Duplicates removed, new shape: (7, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mamberamo_Raya.csv
# Processing TA_DS_clean\Kabupaten_Mamberamo_Tengah.csv for duplicates
# Initial shape: (6, 8)
# Duplicates removed, new shape: (6, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mamberamo_Tengah.csv
# Processing TA_DS_clean\Kabupaten_Mamuju.csv for duplicates
# Initial shape: (342, 8)
# Duplicates removed, new shape: (145, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mamuju.csv
# Processing TA_DS_clean\Kabupaten_Mamuju_Utara.csv for duplicates
# Initial shape: (176, 8)
# Duplicates removed, new shape: (93, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mamuju_Utara.csv
# Processing TA_DS_clean\Kabupaten_Mandailing_Natal.csv for duplicates
# Initial shape: (761, 8)
# Duplicates removed, new shape: (189, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mandailing_Natal.csv
# Processing TA_DS_clean\Kabupaten_Manggarai.csv for duplicates
# Initial shape: (498, 8)
# Duplicates removed, new shape: (187, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Manggarai.csv
# Processing TA_DS_clean\Kabupaten_Manggarai_Barat.csv for duplicates
# Initial shape: (441, 8)
# Duplicates removed, new shape: (239, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Manggarai_Barat.csv
# Processing TA_DS_clean\Kabupaten_Manggarai_Timur.csv for duplicates
# Initial shape: (346, 8)
# Duplicates removed, new shape: (156, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Manggarai_Timur.csv
# Processing TA_DS_clean\Kabupaten_Manokwari.csv for duplicates
# Initial shape: (305, 8)
# Duplicates removed, new shape: (97, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Manokwari.csv
# Processing TA_DS_clean\Kabupaten_Manokwari_Selatan.csv for duplicates
# Initial shape: (46, 8)
# Duplicates removed, new shape: (30, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Manokwari_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Mappi.csv for duplicates
# Initial shape: (153, 8)
# Duplicates removed, new shape: (20, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mappi.csv
# Processing TA_DS_clean\Kabupaten_Maros.csv for duplicates
# Initial shape: (644, 8)
# Duplicates removed, new shape: (230, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Maros.csv
# Processing TA_DS_clean\Kabupaten_Maybrat.csv for duplicates
# Initial shape: (82, 8)
# Duplicates removed, new shape: (17, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Maybrat.csv
# Processing TA_DS_clean\Kabupaten_Melawi.csv for duplicates
# Initial shape: (359, 8)
# Duplicates removed, new shape: (95, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Melawi.csv
# Processing TA_DS_clean\Kabupaten_Mempawah.csv for duplicates
# Initial shape: (559, 8)
# Duplicates removed, new shape: (111, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mempawah.csv
# Processing TA_DS_clean\Kabupaten_Merangin.csv for duplicates
# Initial shape: (489, 8)
# Duplicates removed, new shape: (168, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Merangin.csv
# Processing TA_DS_clean\Kabupaten_Merauke.csv for duplicates
# Initial shape: (409, 8)
# Duplicates removed, new shape: (72, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Merauke.csv
# Processing TA_DS_clean\Kabupaten_Mesuji.csv for duplicates
# Initial shape: (126, 8)
# Duplicates removed, new shape: (54, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mesuji.csv
# Processing TA_DS_clean\Kabupaten_Mimika.csv for duplicates
# Initial shape: (34, 8)
# Duplicates removed, new shape: (30, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mimika.csv
# Processing TA_DS_clean\Kabupaten_Minahasa.csv for duplicates
# Initial shape: (1004, 8)
# Duplicates removed, new shape: (364, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Minahasa.csv
# Processing TA_DS_clean\Kabupaten_Minahasa_Selatan.csv for duplicates
# Initial shape: (535, 8)
# Duplicates removed, new shape: (184, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Minahasa_Selatan.csv
# Processing TA_DS_clean\Kabupaten_Minahasa_Tenggara.csv for duplicates
# Initial shape: (319, 8)
# Duplicates removed, new shape: (123, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Minahasa_Tenggara.csv
# Processing TA_DS_clean\Kabupaten_Minahasa_Utara.csv for duplicates
# Initial shape: (483, 8)
# Duplicates removed, new shape: (253, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Minahasa_Utara.csv
# Processing TA_DS_clean\Kabupaten_Mojokerto.csv for duplicates
# Initial shape: (290, 8)
# Duplicates removed, new shape: (228, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Mojokerto.csv
# Processing TA_DS_clean\Kabupaten_Morowali.csv for duplicates
# Initial shape: (552, 8)
# Duplicates removed, new shape: (168, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kabupaten_Morowali.csv
# Processing TA_DS_clean\Kabupaten_Morowali_Utara.csv for duplicates
# ...
# Processing TA_DS_clean\Kota_Batam.csv for duplicates
# Initial shape: (704, 8)
# Duplicates removed, new shape: (319, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Batam.csv
# Processing TA_DS_clean\Kota_Batu.csv for duplicates
# Initial shape: (166, 8)
# Duplicates removed, new shape: (129, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Batu.csv
# Processing TA_DS_clean\Kota_Baubau.csv for duplicates
# Initial shape: (180, 8)
# Duplicates removed, new shape: (96, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Baubau.csv
# Processing TA_DS_clean\Kota_Bekasi.csv for duplicates
# Initial shape: (352, 8)
# Duplicates removed, new shape: (170, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Bekasi.csv
# Processing TA_DS_clean\Kota_Biak.csv for duplicates
# Initial shape: (321, 8)
# Duplicates removed, new shape: (102, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Biak.csv
# Processing TA_DS_clean\Kota_Bima.csv for duplicates
# Initial shape: (300, 8)
# Duplicates removed, new shape: (77, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Bima.csv
# Processing TA_DS_clean\Kota_Binjai.csv for duplicates
# Initial shape: (224, 8)
# Duplicates removed, new shape: (70, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Binjai.csv
# Processing TA_DS_clean\Kota_Bitung.csv for duplicates
# Initial shape: (318, 8)
# Duplicates removed, new shape: (102, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Bitung.csv
# Processing TA_DS_clean\Kota_Blitar.csv for duplicates
# Initial shape: (166, 8)
# Duplicates removed, new shape: (89, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Blitar.csv
# Processing TA_DS_clean\Kota_Bogor.csv for duplicates
# Initial shape: (285, 8)
# Duplicates removed, new shape: (162, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Bogor.csv
# Processing TA_DS_clean\Kota_Bontang.csv for duplicates
# Initial shape: (159, 8)
# Duplicates removed, new shape: (58, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Bontang.csv
# Processing TA_DS_clean\Kota_Bukittinggi.csv for duplicates
# Initial shape: (342, 8)
# Duplicates removed, new shape: (75, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Bukittinggi.csv
# Processing TA_DS_clean\Kota_Cilegon.csv for duplicates
# Initial shape: (214, 8)
# Duplicates removed, new shape: (94, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Cilegon.csv
# Processing TA_DS_clean\Kota_Cimahi.csv for duplicates
# Initial shape: (134, 8)
# Duplicates removed, new shape: (73, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Cimahi.csv
# Processing TA_DS_clean\Kota_Cirebon.csv for duplicates
# Initial shape: (121, 8)
# Duplicates removed, new shape: (71, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Cirebon.csv
# Processing TA_DS_clean\Kota_Denpasar.csv for duplicates
# Initial shape: (207, 8)
# Duplicates removed, new shape: (129, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Denpasar.csv
# Processing TA_DS_clean\Kota_Depok.csv for duplicates
# Initial shape: (282, 8)
# Duplicates removed, new shape: (201, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Depok.csv
# Processing TA_DS_clean\Kota_Dumai.csv for duplicates
# Initial shape: (405, 8)
# Duplicates removed, new shape: (82, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Dumai.csv
# Processing TA_DS_clean\Kota_Gorontalo.csv for duplicates
# Initial shape: (495, 8)
# Duplicates removed, new shape: (111, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Gorontalo.csv
# Processing TA_DS_clean\Kota_Jakarta_Barat.csv for duplicates
# Initial shape: (172, 8)
# Duplicates removed, new shape: (115, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jakarta_Barat.csv
# Processing TA_DS_clean\Kota_Jakarta_Pusat.csv for duplicates
# Initial shape: (195, 8)
# Duplicates removed, new shape: (95, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jakarta_Pusat.csv
# Processing TA_DS_clean\Kota_Jakarta_Selatan.csv for duplicates
# Initial shape: (322, 8)
# Duplicates removed, new shape: (186, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jakarta_Selatan.csv
# Processing TA_DS_clean\Kota_Jakarta_Timur.csv for duplicates
# Initial shape: (289, 8)
# Duplicates removed, new shape: (189, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jakarta_Timur.csv
# Processing TA_DS_clean\Kota_Jakarta_Utara.csv for duplicates
# Initial shape: (253, 8)
# Duplicates removed, new shape: (183, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jakarta_Utara.csv
# Processing TA_DS_clean\Kota_Jambi.csv for duplicates
# Initial shape: (472, 8)
# Duplicates removed, new shape: (126, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jambi.csv
# Processing TA_DS_clean\Kota_Jayapura.csv for duplicates
# Initial shape: (387, 8)
# Duplicates removed, new shape: (173, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Jayapura.csv
# Processing TA_DS_clean\Kota_Kediri.csv for duplicates
# Initial shape: (414, 8)
# Duplicates removed, new shape: (167, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Kediri.csv
# Processing TA_DS_clean\Kota_Kendari.csv for duplicates
# Initial shape: (410, 8)
# Duplicates removed, new shape: (85, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Kendari.csv
# Processing TA_DS_clean\Kota_Kupang.csv for duplicates
# Initial shape: (201, 8)
# Duplicates removed, new shape: (100, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Kupang.csv
# Processing TA_DS_clean\Kota_Lubuklinggau.csv for duplicates
# Initial shape: (317, 8)
# Duplicates removed, new shape: (69, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Lubuklinggau.csv
# Processing TA_DS_clean\Kota_Madiun.csv for duplicates
# Initial shape: (223, 8)
# Duplicates removed, new shape: (86, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Madiun.csv
# Processing TA_DS_clean\Kota_Magelang.csv for duplicates
# Initial shape: (287, 8)
# Duplicates removed, new shape: (79, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Magelang.csv
# Processing TA_DS_clean\Kota_Makassar.csv for duplicates
# Initial shape: (759, 8)
# Duplicates removed, new shape: (194, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Makassar.csv
# Processing TA_DS_clean\Kota_Malang.csv for duplicates
# Initial shape: (264, 8)
# Duplicates removed, new shape: (148, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Malang.csv
# Processing TA_DS_clean\Kota_Mamuju.csv for duplicates
# Initial shape: (127, 8)
# Duplicates removed, new shape: (62, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Mamuju.csv
# Processing TA_DS_clean\Kota_Mamuju_Utara.csv for duplicates
# Initial shape: (122, 8)
# Duplicates removed, new shape: (75, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Mamuju_Utara.csv
# Processing TA_DS_clean\Kota_Manado.csv for duplicates
# Initial shape: (394, 8)
# Duplicates removed, new shape: (128, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Manado.csv
# Processing TA_DS_clean\Kota_Mataram.csv for duplicates
# Initial shape: (284, 8)
# Duplicates removed, new shape: (105, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Mataram.csv
# Processing TA_DS_clean\Kota_Medan.csv for duplicates
# Initial shape: (832, 8)
# Duplicates removed, new shape: (165, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Medan.csv
# Processing TA_DS_clean\Kota_Metro.csv for duplicates
# Initial shape: (230, 8)
# Duplicates removed, new shape: (75, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Metro.csv
# Processing TA_DS_clean\Kota_Mojokerto.csv for duplicates
# Initial shape: (137, 8)
# Duplicates removed, new shape: (87, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Mojokerto.csv
# Processing TA_DS_clean\Kota_Padang.csv for duplicates
# Initial shape: (757, 8)
# Duplicates removed, new shape: (265, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Padang.csv
# Processing TA_DS_clean\Kota_Padang_Panjang.csv for duplicates
# Initial shape: (355, 8)
# Duplicates removed, new shape: (98, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Padang_Panjang.csv
# Processing TA_DS_clean\Kota_Pagar_Alam.csv for duplicates
# Initial shape: (298, 8)
# Duplicates removed, new shape: (83, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pagar_Alam.csv
# Processing TA_DS_clean\Kota_Palangka_Raya.csv for duplicates
# Initial shape: (226, 8)
# Duplicates removed, new shape: (135, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Palangka_Raya.csv
# Processing TA_DS_clean\Kota_Palembang.csv for duplicates
# Initial shape: (770, 8)
# Duplicates removed, new shape: (190, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Palembang.csv
# Processing TA_DS_clean\Kota_Palopo.csv for duplicates
# Initial shape: (376, 8)
# Duplicates removed, new shape: (77, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Palopo.csv
# Processing TA_DS_clean\Kota_Palu.csv for duplicates
# Initial shape: (420, 8)
# Duplicates removed, new shape: (113, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Palu.csv
# Processing TA_DS_clean\Kota_Pangkal_Pinang.csv for duplicates
# Initial shape: (736, 8)
# Duplicates removed, new shape: (104, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pangkal_Pinang.csv
# Processing TA_DS_clean\Kota_Parepare.csv for duplicates
# Initial shape: (182, 8)
# Duplicates removed, new shape: (71, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Parepare.csv
# Processing TA_DS_clean\Kota_Pariaman.csv for duplicates
# Initial shape: (264, 8)
# Duplicates removed, new shape: (82, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pariaman.csv
# Processing TA_DS_clean\Kota_Pasuruan.csv for duplicates
# Initial shape: (82, 8)
# Duplicates removed, new shape: (77, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pasuruan.csv
# Processing TA_DS_clean\Kota_Payakumbuh.csv for duplicates
# Initial shape: (286, 8)
# Duplicates removed, new shape: (91, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Payakumbuh.csv
# Processing TA_DS_clean\Kota_Pekalongan.csv for duplicates
# Initial shape: (287, 8)
# Duplicates removed, new shape: (78, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pekalongan.csv
# Processing TA_DS_clean\Kota_Pekanbaru.csv for duplicates
# Initial shape: (555, 8)
# Duplicates removed, new shape: (157, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pekanbaru.csv
# Processing TA_DS_clean\Kota_Pematang_Siantar.csv for duplicates
# Initial shape: (220, 8)
# Duplicates removed, new shape: (60, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pematang_Siantar.csv
# Processing TA_DS_clean\Kota_Pontianak.csv for duplicates
# Initial shape: (348, 8)
# Duplicates removed, new shape: (82, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Pontianak.csv
# Processing TA_DS_clean\Kota_Prabumulih.csv for duplicates
# Initial shape: (221, 8)
# Duplicates removed, new shape: (55, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Prabumulih.csv
# Processing TA_DS_clean\Kota_Probolinggo.csv for duplicates
# Initial shape: (128, 8)
# Duplicates removed, new shape: (64, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Probolinggo.csv
# Processing TA_DS_clean\Kota_Salatiga.csv for duplicates
# Initial shape: (259, 8)
# Duplicates removed, new shape: (76, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Salatiga.csv
# Processing TA_DS_clean\Kota_Samarinda.csv for duplicates
# Initial shape: (530, 8)
# Duplicates removed, new shape: (186, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Samarinda.csv
# Processing TA_DS_clean\Kota_Sawahlunto.csv for duplicates
# Initial shape: (262, 8)
# Duplicates removed, new shape: (92, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Sawahlunto.csv
# Processing TA_DS_clean\Kota_Semarang.csv for duplicates
# Initial shape: (286, 8)
# Duplicates removed, new shape: (140, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Semarang.csv
# Processing TA_DS_clean\Kota_Serang.csv for duplicates
# Initial shape: (238, 8)
# Duplicates removed, new shape: (123, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Serang.csv
# Processing TA_DS_clean\Kota_Singkawang.csv for duplicates
# Initial shape: (274, 8)
# Duplicates removed, new shape: (76, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Singkawang.csv
# Processing TA_DS_clean\Kota_Soe.csv for duplicates
# Initial shape: (140, 8)
# Duplicates removed, new shape: (37, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Soe.csv
# Processing TA_DS_clean\Kota_Sorong.csv for duplicates
# Initial shape: (825, 8)
# Duplicates removed, new shape: (80, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Sorong.csv
# Processing TA_DS_clean\Kota_Sukabumi.csv for duplicates
# Initial shape: (233, 8)
# Duplicates removed, new shape: (92, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Sukabumi.csv
# Processing TA_DS_clean\Kota_Surabaya.csv for duplicates
# Initial shape: (1305, 8)
# Duplicates removed, new shape: (259, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Surabaya.csv
# Processing TA_DS_clean\Kota_Surakarta.csv for duplicates
# Initial shape: (317, 8)
# Duplicates removed, new shape: (97, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Surakarta.csv
# Processing TA_DS_clean\Kota_Taman.csv for duplicates
# Initial shape: (128, 8)
# Duplicates removed, new shape: (98, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Taman.csv
# Processing TA_DS_clean\Kota_Tangerang.csv for duplicates
# Initial shape: (413, 8)
# Duplicates removed, new shape: (212, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tangerang.csv
# Processing TA_DS_clean\Kota_Tangerang_Selatan.csv for duplicates
# Initial shape: (259, 8)
# Duplicates removed, new shape: (162, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tangerang_Selatan.csv
# Processing TA_DS_clean\Kota_Tanjungbalai.csv for duplicates
# Initial shape: (129, 8)
# Duplicates removed, new shape: (57, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tanjungbalai.csv
# Processing TA_DS_clean\Kota_Tanjung_Pinang.csv for duplicates
# Initial shape: (234, 8)
# Duplicates removed, new shape: (63, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tanjung_Pinang.csv
# Processing TA_DS_clean\Kota_Tarakan.csv for duplicates
# Initial shape: (221, 8)
# Duplicates removed, new shape: (64, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tarakan.csv
# Processing TA_DS_clean\Kota_Tasikmalaya.csv for duplicates
# Initial shape: (199, 8)
# Duplicates removed, new shape: (99, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tasikmalaya.csv
# Processing TA_DS_clean\Kota_Tebing_Tinggi.csv for duplicates
# Initial shape: (368, 8)
# Duplicates removed, new shape: (118, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tebing_Tinggi.csv
# Processing TA_DS_clean\Kota_Tegal.csv for duplicates
# Initial shape: (288, 8)
# Duplicates removed, new shape: (88, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tegal.csv
# Processing TA_DS_clean\Kota_Ternate.csv for duplicates
# Initial shape: (236, 8)
# Duplicates removed, new shape: (73, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Ternate.csv
# Processing TA_DS_clean\Kota_Tidore_Kepulauan.csv for duplicates
# Initial shape: (134, 8)
# Duplicates removed, new shape: (62, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tidore_Kepulauan.csv
# Processing TA_DS_clean\Kota_Tomohon.csv for duplicates
# Initial shape: (300, 8)
# Duplicates removed, new shape: (120, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tomohon.csv
# Processing TA_DS_clean\Kota_Tual.csv for duplicates
# Initial shape: (112, 8)
# Duplicates removed, new shape: (67, 8)
# File overwritten with duplicates removed: TA_DS_clean\Kota_Tual.csv
# All duplicates have been processed.

# %%
for file_name in os.listdir(clean_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(clean_path, file_name)
        print(f'Processing {file_path} for missing values')

        # Load the CSV file
        df = pd.read_csv(file_path)

        # Check for missing values in each column
        missing_values = df.isnull().sum()

        # Filter and print only columns that have missing values
        missing_values = missing_values[missing_values > 0]
        if not missing_values.empty:
            print(f'Columns with missing values in {file_name}:\n{missing_values}')
        else:
            print(f'No missing values in {file_name}.')

print("Missing values check completed.")
# Out:
# Processing TA_DS_clean\Kabupaten_Aceh_Barat.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Barat.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Barat_Daya.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Barat_Daya.csv:
# photos    15
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Besar.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Besar.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Jaya.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Jaya.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Selatan.csv:
# photos    16
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Singkil.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Singkil.csv:
# photos    26
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Tamiang.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Tamiang.csv:
# photos    33
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Tengah.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Tenggara.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Tenggara.csv:
# photos    14
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Timur.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Timur.csv:
# photos    21
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Aceh_Utara.csv for missing values
# Columns with missing values in Kabupaten_Aceh_Utara.csv:
# photos    49
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Agam.csv for missing values
# Columns with missing values in Kabupaten_Agam.csv:
# photos    70
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Alor.csv for missing values
# Columns with missing values in Kabupaten_Alor.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Asahan.csv for missing values
# Columns with missing values in Kabupaten_Asahan.csv:
# photos    80
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Asmat.csv for missing values
# Columns with missing values in Kabupaten_Asmat.csv:
# photos    12
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Badung.csv for missing values
# Columns with missing values in Kabupaten_Badung.csv:
# photos    33
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Balangan.csv for missing values
# Columns with missing values in Kabupaten_Balangan.csv:
# photos    34
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bandung.csv for missing values
# Columns with missing values in Kabupaten_Bandung.csv:
# photos    191
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bandung_Barat.csv for missing values
# Columns with missing values in Kabupaten_Bandung_Barat.csv:
# photos    115
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banggai.csv for missing values
# Columns with missing values in Kabupaten_Banggai.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banggai_Kepulauan.csv for missing values
# Columns with missing values in Kabupaten_Banggai_Kepulauan.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banggai_Laut.csv for missing values
# Columns with missing values in Kabupaten_Banggai_Laut.csv:
# photos    21
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bangka.csv for missing values
# Columns with missing values in Kabupaten_Bangka.csv:
# photos    54
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bangkalan.csv for missing values
# Columns with missing values in Kabupaten_Bangkalan.csv:
# photos    54
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bangka_Barat.csv for missing values
# Columns with missing values in Kabupaten_Bangka_Barat.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bangka_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Bangka_Selatan.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bangka_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Bangka_Tengah.csv:
# photos    50
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bangli.csv for missing values
# Columns with missing values in Kabupaten_Bangli.csv:
# photos    27
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banjar.csv for missing values
# Columns with missing values in Kabupaten_Banjar.csv:
# photos    107
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banjarnegara.csv for missing values
# Columns with missing values in Kabupaten_Banjarnegara.csv:
# photos    91
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bantaeng.csv for missing values
# Columns with missing values in Kabupaten_Bantaeng.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banyuasin.csv for missing values
# Columns with missing values in Kabupaten_Banyuasin.csv:
# photos    84
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banyumas.csv for missing values
# Columns with missing values in Kabupaten_Banyumas.csv:
# photos    157
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Banyuwangi.csv for missing values
# Columns with missing values in Kabupaten_Banyuwangi.csv:
# photos    146
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Barito_Kuala.csv for missing values
# Columns with missing values in Kabupaten_Barito_Kuala.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Barito_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Barito_Selatan.csv:
# photos    69
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Barito_Timur.csv for missing values
# Columns with missing values in Kabupaten_Barito_Timur.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Barito_Utara.csv for missing values
# Columns with missing values in Kabupaten_Barito_Utara.csv:
# photos    42
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Barru.csv for missing values
# Columns with missing values in Kabupaten_Barru.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Batang.csv for missing values
# Columns with missing values in Kabupaten_Batang.csv:
# photos    68
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Batang_Hari.csv for missing values
# Columns with missing values in Kabupaten_Batang_Hari.csv:
# photos    27
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Batu_Bara.csv for missing values
# Columns with missing values in Kabupaten_Batu_Bara.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bekasi.csv for missing values
# Columns with missing values in Kabupaten_Bekasi.csv:
# photos    186
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Belitung.csv for missing values
# Columns with missing values in Kabupaten_Belitung.csv:
# photos    39
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Belitung_Timur.csv for missing values
# Columns with missing values in Kabupaten_Belitung_Timur.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Belu.csv for missing values
# Columns with missing values in Kabupaten_Belu.csv:
# photos    41
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bener_Meriah.csv for missing values
# Columns with missing values in Kabupaten_Bener_Meriah.csv:
# photos    26
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bengkalis.csv for missing values
# Columns with missing values in Kabupaten_Bengkalis.csv:
# photos    38
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bengkayang.csv for missing values
# Columns with missing values in Kabupaten_Bengkayang.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Berau.csv for missing values
# Columns with missing values in Kabupaten_Berau.csv:
# photos    58
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bima.csv for missing values
# Columns with missing values in Kabupaten_Bima.csv:
# photos    96
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bintan.csv for missing values
# Columns with missing values in Kabupaten_Bintan.csv:
# photos    49
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bireuen.csv for missing values
# Columns with missing values in Kabupaten_Bireuen.csv:
# photos    33
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Blitar.csv for missing values
# Columns with missing values in Kabupaten_Blitar.csv:
# photos    146
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Blora.csv for missing values
# Columns with missing values in Kabupaten_Blora.csv:
# photos    226
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Boalemo.csv for missing values
# Columns with missing values in Kabupaten_Boalemo.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bogor.csv for missing values
# Columns with missing values in Kabupaten_Bogor.csv:
# photos    318
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bojonegoro.csv for missing values
# Columns with missing values in Kabupaten_Bojonegoro.csv:
# photos    120
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow.csv for missing values
# Columns with missing values in Kabupaten_Bolaang_Mongondow.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Bolaang_Mongondow_Selatan.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Timur.csv for missing values
# Columns with missing values in Kabupaten_Bolaang_Mongondow_Timur.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bolaang_Mongondow_Utara.csv for missing values
# Columns with missing values in Kabupaten_Bolaang_Mongondow_Utara.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bombana.csv for missing values
# Columns with missing values in Kabupaten_Bombana.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bondowoso.csv for missing values
# Columns with missing values in Kabupaten_Bondowoso.csv:
# photos    45
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bone.csv for missing values
# Columns with missing values in Kabupaten_Bone.csv:
# photos    85
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bone_Bolango.csv for missing values
# Columns with missing values in Kabupaten_Bone_Bolango.csv:
# photos    47
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Boven_Digoel.csv for missing values
# Columns with missing values in Kabupaten_Boven_Digoel.csv:
# photos    16
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Boyolali.csv for missing values
# Columns with missing values in Kabupaten_Boyolali.csv:
# photos    103
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Brebes.csv for missing values
# Columns with missing values in Kabupaten_Brebes.csv:
# photos    125
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Buleleng.csv for missing values
# Columns with missing values in Kabupaten_Buleleng.csv:
# photos    73
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bulukumba.csv for missing values
# Columns with missing values in Kabupaten_Bulukumba.csv:
# photos    53
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bulungan.csv for missing values
# Columns with missing values in Kabupaten_Bulungan.csv:
# photos    47
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Bungo.csv for missing values
# Columns with missing values in Kabupaten_Bungo.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Buol.csv for missing values
# Columns with missing values in Kabupaten_Buol.csv:
# photos    18
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Buru.csv for missing values
# Columns with missing values in Kabupaten_Buru.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Buru_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Buru_Selatan.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Buton.csv for missing values
# Columns with missing values in Kabupaten_Buton.csv:
# photos    65
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Buton_Utara.csv for missing values
# Columns with missing values in Kabupaten_Buton_Utara.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ciamis.csv for missing values
# Columns with missing values in Kabupaten_Ciamis.csv:
# photos    161
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Cianjur.csv for missing values
# Columns with missing values in Kabupaten_Cianjur.csv:
# photos    207
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Cilacap.csv for missing values
# Columns with missing values in Kabupaten_Cilacap.csv:
# photos    161
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Cirebon.csv for missing values
# Columns with missing values in Kabupaten_Cirebon.csv:
# photos    113
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Dairi.csv for missing values
# Columns with missing values in Kabupaten_Dairi.csv:
# photos    67
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Deiyai.csv for missing values
# Columns with missing values in Kabupaten_Deiyai.csv:
# photos    10
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Deli_Serdang.csv for missing values
# Columns with missing values in Kabupaten_Deli_Serdang.csv:
# photos    83
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Demak.csv for missing values
# Columns with missing values in Kabupaten_Demak.csv:
# photos    76
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Dharmasraya.csv for missing values
# Columns with missing values in Kabupaten_Dharmasraya.csv:
# photos    21
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Dogiyai.csv for missing values
# Columns with missing values in Kabupaten_Dogiyai.csv:
# formatted_address    1
# photos               9
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Dompu.csv for missing values
# Columns with missing values in Kabupaten_Dompu.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Donggala.csv for missing values
# Columns with missing values in Kabupaten_Donggala.csv:
# photos    49
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Empat_Lawang.csv for missing values
# Columns with missing values in Kabupaten_Empat_Lawang.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ende.csv for missing values
# Columns with missing values in Kabupaten_Ende.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Enrekang.csv for missing values
# Columns with missing values in Kabupaten_Enrekang.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Fakfak.csv for missing values
# Columns with missing values in Kabupaten_Fakfak.csv:
# photos    12
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Flores_Timur.csv for missing values
# Columns with missing values in Kabupaten_Flores_Timur.csv:
# photos    59
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Garut.csv for missing values
# Columns with missing values in Kabupaten_Garut.csv:
# photos    222
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gayo_Lues.csv for missing values
# Columns with missing values in Kabupaten_Gayo_Lues.csv:
# photos    27
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gianyar.csv for missing values
# Columns with missing values in Kabupaten_Gianyar.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gorontalo.csv for missing values
# Columns with missing values in Kabupaten_Gorontalo.csv:
# photos    95
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gorontalo_Utara.csv for missing values
# Columns with missing values in Kabupaten_Gorontalo_Utara.csv:
# photos    48
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gowa.csv for missing values
# Columns with missing values in Kabupaten_Gowa.csv:
# photos    120
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gresik.csv for missing values
# Columns with missing values in Kabupaten_Gresik.csv:
# photos    69
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Grobogan.csv for missing values
# Columns with missing values in Kabupaten_Grobogan.csv:
# photos    108
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Gunung_Mas.csv for missing values
# Columns with missing values in Kabupaten_Gunung_Mas.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Halmahera_Barat.csv for missing values
# Columns with missing values in Kabupaten_Halmahera_Barat.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Halmahera_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Halmahera_Selatan.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Halmahera_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Halmahera_Tengah.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Halmahera_Utara.csv for missing values
# Columns with missing values in Kabupaten_Halmahera_Utara.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Hulu_Sungai_Selatan.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Hulu_Sungai_Tengah.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Hulu_Sungai_Utara.csv for missing values
# Columns with missing values in Kabupaten_Hulu_Sungai_Utara.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Humbang_Hasundutan.csv for missing values
# Columns with missing values in Kabupaten_Humbang_Hasundutan.csv:
# photos    45
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Indragiri_Hilir.csv for missing values
# Columns with missing values in Kabupaten_Indragiri_Hilir.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Indragiri_Hulu.csv for missing values
# Columns with missing values in Kabupaten_Indragiri_Hulu.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Indramayu.csv for missing values
# Columns with missing values in Kabupaten_Indramayu.csv:
# photos    117
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Intan_Jaya.csv for missing values
# Columns with missing values in Kabupaten_Intan_Jaya.csv:
# photos    7
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jayapura.csv for missing values
# Columns with missing values in Kabupaten_Jayapura.csv:
# photos    48
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jayawijaya.csv for missing values
# Columns with missing values in Kabupaten_Jayawijaya.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jember.csv for missing values
# Columns with missing values in Kabupaten_Jember.csv:
# photos    151
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jembrana.csv for missing values
# Columns with missing values in Kabupaten_Jembrana.csv:
# photos    34
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jeneponto.csv for missing values
# Columns with missing values in Kabupaten_Jeneponto.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jepara.csv for missing values
# Columns with missing values in Kabupaten_Jepara.csv:
# photos    96
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Jombang.csv for missing values
# Columns with missing values in Kabupaten_Jombang.csv:
# photos    76
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kaimana.csv for missing values
# Columns with missing values in Kabupaten_Kaimana.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kampar.csv for missing values
# Columns with missing values in Kabupaten_Kampar.csv:
# photos    71
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kapuas.csv for missing values
# Columns with missing values in Kabupaten_Kapuas.csv:
# photos    57
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kapuas_Hulu.csv for missing values
# Columns with missing values in Kabupaten_Kapuas_Hulu.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Karanganyar.csv for missing values
# Columns with missing values in Kabupaten_Karanganyar.csv:
# photos    103
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Karangasem.csv for missing values
# Columns with missing values in Kabupaten_Karangasem.csv:
# photos    79
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Karawang.csv for missing values
# Columns with missing values in Kabupaten_Karawang.csv:
# photos    147
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Karimun.csv for missing values
# Columns with missing values in Kabupaten_Karimun.csv:
# photos    26
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Karo.csv for missing values
# Columns with missing values in Kabupaten_Karo.csv:
# photos    56
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Katingan.csv for missing values
# Columns with missing values in Kabupaten_Katingan.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kayong_Utara.csv for missing values
# Columns with missing values in Kabupaten_Kayong_Utara.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kebumen.csv for missing values
# Columns with missing values in Kabupaten_Kebumen.csv:
# photos    109
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kediri.csv for missing values
# Columns with missing values in Kabupaten_Kediri.csv:
# photos    94
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Keerom.csv for missing values
# Columns with missing values in Kabupaten_Keerom.csv:
# photos    21
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kendal.csv for missing values
# Columns with missing values in Kabupaten_Kendal.csv:
# photos    109
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Aru.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Aru.csv:
# photos    11
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Mentawai.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Mentawai.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Meranti.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Meranti.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Sangihe.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Sangihe.csv:
# photos    40
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Selayar.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Selayar.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Sula.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Sula.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Talaud.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Talaud.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kepulauan_Yapen.csv for missing values
# Columns with missing values in Kabupaten_Kepulauan_Yapen.csv:
# photos    27
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kerinci.csv for missing values
# Columns with missing values in Kabupaten_Kerinci.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ketapang.csv for missing values
# Columns with missing values in Kabupaten_Ketapang.csv:
# photos    41
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Klaten.csv for missing values
# Columns with missing values in Kabupaten_Klaten.csv:
# photos    108
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Klungkung.csv for missing values
# Columns with missing values in Kabupaten_Klungkung.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kolaka.csv for missing values
# Columns with missing values in Kabupaten_Kolaka.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kolaka_Timur.csv for missing values
# Columns with missing values in Kabupaten_Kolaka_Timur.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kolaka_Utara.csv for missing values
# Columns with missing values in Kabupaten_Kolaka_Utara.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Konawe.csv for missing values
# Columns with missing values in Kabupaten_Konawe.csv:
# photos    41
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Konawe_Kepulauan.csv for missing values
# Columns with missing values in Kabupaten_Konawe_Kepulauan.csv:
# photos    9
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Konawe_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Konawe_Selatan.csv:
# photos    59
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Konawe_Utara.csv for missing values
# Columns with missing values in Kabupaten_Konawe_Utara.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kotabaru.csv for missing values
# Columns with missing values in Kabupaten_Kotabaru.csv:
# photos    91
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kotawaringin_Barat.csv for missing values
# Columns with missing values in Kabupaten_Kotawaringin_Barat.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kotawaringin_Timur.csv for missing values
# Columns with missing values in Kabupaten_Kotawaringin_Timur.csv:
# photos    63
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kuantan_Singingi.csv for missing values
# Columns with missing values in Kabupaten_Kuantan_Singingi.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kubu_Raya.csv for missing values
# Columns with missing values in Kabupaten_Kubu_Raya.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kudus.csv for missing values
# Columns with missing values in Kabupaten_Kudus.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kuningan.csv for missing values
# Columns with missing values in Kabupaten_Kuningan.csv:
# photos    143
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kupang.csv for missing values
# Columns with missing values in Kabupaten_Kupang.csv:
# photos    95
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kutai_Barat.csv for missing values
# Columns with missing values in Kabupaten_Kutai_Barat.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kutai_Kartanegara.csv for missing values
# Columns with missing values in Kabupaten_Kutai_Kartanegara.csv:
# photos    151
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Kutai_Timur.csv for missing values
# Columns with missing values in Kabupaten_Kutai_Timur.csv:
# photos    77
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Labuhanbatu.csv for missing values
# Columns with missing values in Kabupaten_Labuhanbatu.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Labuhanbatu_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Labuhanbatu_Selatan.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Labuhanbatu_Utara.csv for missing values
# Columns with missing values in Kabupaten_Labuhanbatu_Utara.csv:
# photos    38
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lahat.csv for missing values
# Columns with missing values in Kabupaten_Lahat.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lamandau.csv for missing values
# Columns with missing values in Kabupaten_Lamandau.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lamongan.csv for missing values
# Columns with missing values in Kabupaten_Lamongan.csv:
# photos    119
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lampung_Barat.csv for missing values
# Columns with missing values in Kabupaten_Lampung_Barat.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lampung_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Lampung_Selatan.csv:
# photos    86
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lampung_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Lampung_Tengah.csv:
# photos    128
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lampung_Timur.csv for missing values
# Columns with missing values in Kabupaten_Lampung_Timur.csv:
# photos    76
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lampung_Utara.csv for missing values
# Columns with missing values in Kabupaten_Lampung_Utara.csv:
# photos    51
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Landak.csv for missing values
# Columns with missing values in Kabupaten_Landak.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Langkat.csv for missing values
# Columns with missing values in Kabupaten_Langkat.csv:
# photos    87
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lanny_Jaya.csv for missing values
# Columns with missing values in Kabupaten_Lanny_Jaya.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lebak.csv for missing values
# Columns with missing values in Kabupaten_Lebak.csv:
# photos    164
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lembata.csv for missing values
# Columns with missing values in Kabupaten_Lembata.csv:
# photos    22
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lima_Puluh_Kota.csv for missing values
# Columns with missing values in Kabupaten_Lima_Puluh_Kota.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lingga.csv for missing values
# Columns with missing values in Kabupaten_Lingga.csv:
# photos    27
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lombok_Barat.csv for missing values
# Columns with missing values in Kabupaten_Lombok_Barat.csv:
# photos    87
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lombok_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Lombok_Tengah.csv:
# photos    91
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lombok_Timur.csv for missing values
# Columns with missing values in Kabupaten_Lombok_Timur.csv:
# photos    96
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lombok_Utara.csv for missing values
# Columns with missing values in Kabupaten_Lombok_Utara.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Lumajang.csv for missing values
# Columns with missing values in Kabupaten_Lumajang.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Luwu.csv for missing values
# Columns with missing values in Kabupaten_Luwu.csv:
# photos    76
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Luwu_Timur.csv for missing values
# Columns with missing values in Kabupaten_Luwu_Timur.csv:
# photos    40
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Luwu_Utara.csv for missing values
# Columns with missing values in Kabupaten_Luwu_Utara.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Madiun.csv for missing values
# Columns with missing values in Kabupaten_Madiun.csv:
# photos    71
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Magelang.csv for missing values
# Columns with missing values in Kabupaten_Magelang.csv:
# photos    108
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Magetan.csv for missing values
# Columns with missing values in Kabupaten_Magetan.csv:
# photos    87
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mahakam_Ulu.csv for missing values
# Columns with missing values in Kabupaten_Mahakam_Ulu.csv:
# photos    11
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Majalengka.csv for missing values
# Columns with missing values in Kabupaten_Majalengka.csv:
# photos    121
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Majene.csv for missing values
# Columns with missing values in Kabupaten_Majene.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Malaka.csv for missing values
# Columns with missing values in Kabupaten_Malaka.csv:
# photos    22
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Malang.csv for missing values
# Columns with missing values in Kabupaten_Malang.csv:
# photos    157
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Malinau.csv for missing values
# Columns with missing values in Kabupaten_Malinau.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Maluku_Barat_Daya.csv for missing values
# Columns with missing values in Kabupaten_Maluku_Barat_Daya.csv:
# photos    11
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Maluku_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Maluku_Tengah.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Maluku_Tenggara.csv for missing values
# Columns with missing values in Kabupaten_Maluku_Tenggara.csv:
# photos    38
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Maluku_Tenggara_Barat.csv for missing values
# Columns with missing values in Kabupaten_Maluku_Tenggara_Barat.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mamasa.csv for missing values
# Columns with missing values in Kabupaten_Mamasa.csv:
# photos    69
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mamberamo_Raya.csv for missing values
# Columns with missing values in Kabupaten_Mamberamo_Raya.csv:
# photos    2
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mamberamo_Tengah.csv for missing values
# Columns with missing values in Kabupaten_Mamberamo_Tengah.csv:
# photos    2
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mamuju.csv for missing values
# Columns with missing values in Kabupaten_Mamuju.csv:
# photos    48
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mamuju_Utara.csv for missing values
# Columns with missing values in Kabupaten_Mamuju_Utara.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mandailing_Natal.csv for missing values
# Columns with missing values in Kabupaten_Mandailing_Natal.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Manggarai.csv for missing values
# Columns with missing values in Kabupaten_Manggarai.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Manggarai_Barat.csv for missing values
# Columns with missing values in Kabupaten_Manggarai_Barat.csv:
# photos    75
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Manggarai_Timur.csv for missing values
# Columns with missing values in Kabupaten_Manggarai_Timur.csv:
# photos    58
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Manokwari.csv for missing values
# Columns with missing values in Kabupaten_Manokwari.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Manokwari_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Manokwari_Selatan.csv:
# photos    10
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mappi.csv for missing values
# Columns with missing values in Kabupaten_Mappi.csv:
# photos    15
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Maros.csv for missing values
# Columns with missing values in Kabupaten_Maros.csv:
# photos    67
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Maybrat.csv for missing values
# Columns with missing values in Kabupaten_Maybrat.csv:
# photos    3
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Melawi.csv for missing values
# Columns with missing values in Kabupaten_Melawi.csv:
# photos    34
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mempawah.csv for missing values
# Columns with missing values in Kabupaten_Mempawah.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Merangin.csv for missing values
# Columns with missing values in Kabupaten_Merangin.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Merauke.csv for missing values
# Columns with missing values in Kabupaten_Merauke.csv:
# photos    13
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mesuji.csv for missing values
# Columns with missing values in Kabupaten_Mesuji.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mimika.csv for missing values
# Columns with missing values in Kabupaten_Mimika.csv:
# photos    5
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Minahasa.csv for missing values
# Columns with missing values in Kabupaten_Minahasa.csv:
# photos    108
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Minahasa_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Minahasa_Selatan.csv:
# photos    64
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Minahasa_Tenggara.csv for missing values
# Columns with missing values in Kabupaten_Minahasa_Tenggara.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Minahasa_Utara.csv for missing values
# Columns with missing values in Kabupaten_Minahasa_Utara.csv:
# photos    83
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Mojokerto.csv for missing values
# Columns with missing values in Kabupaten_Mojokerto.csv:
# photos    39
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Morowali.csv for missing values
# Columns with missing values in Kabupaten_Morowali.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Morowali_Utara.csv for missing values
# Columns with missing values in Kabupaten_Morowali_Utara.csv:
# photos    21
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Muara_Enim.csv for missing values
# Columns with missing values in Kabupaten_Muara_Enim.csv:
# photos    62
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Muaro_Jambi.csv for missing values
# Columns with missing values in Kabupaten_Muaro_Jambi.csv:
# photos    53
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Muna.csv for missing values
# Columns with missing values in Kabupaten_Muna.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Muna_Barat.csv for missing values
# Columns with missing values in Kabupaten_Muna_Barat.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Murung_Raya.csv for missing values
# Columns with missing values in Kabupaten_Murung_Raya.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Musi_Banyuasin.csv for missing values
# Columns with missing values in Kabupaten_Musi_Banyuasin.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Musi_Rawas.csv for missing values
# Columns with missing values in Kabupaten_Musi_Rawas.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Musi_Rawas_Utara.csv for missing values
# Columns with missing values in Kabupaten_Musi_Rawas_Utara.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nabire.csv for missing values
# Columns with missing values in Kabupaten_Nabire.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nagan_Raya.csv for missing values
# Columns with missing values in Kabupaten_Nagan_Raya.csv:
# photos    33
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nagekeo.csv for missing values
# Columns with missing values in Kabupaten_Nagekeo.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Natuna.csv for missing values
# Columns with missing values in Kabupaten_Natuna.csv:
# photos    54
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nduga.csv for missing values
# Columns with missing values in Kabupaten_Nduga.csv:
# photos    16
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ngada.csv for missing values
# Columns with missing values in Kabupaten_Ngada.csv:
# photos    38
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nganjuk.csv for missing values
# Columns with missing values in Kabupaten_Nganjuk.csv:
# photos    65
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ngawi.csv for missing values
# Columns with missing values in Kabupaten_Ngawi.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nias.csv for missing values
# Columns with missing values in Kabupaten_Nias.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nias_Barat.csv for missing values
# Columns with missing values in Kabupaten_Nias_Barat.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nias_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Nias_Selatan.csv:
# photos    59
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nias_Utara.csv for missing values
# Columns with missing values in Kabupaten_Nias_Utara.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Nunukan.csv for missing values
# Columns with missing values in Kabupaten_Nunukan.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ogan_Ilir.csv for missing values
# Columns with missing values in Kabupaten_Ogan_Ilir.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ogan_Komering_Ilir.csv for missing values
# Columns with missing values in Kabupaten_Ogan_Komering_Ilir.csv:
# photos    72
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ogan_Komering_Ulu.csv for missing values
# Columns with missing values in Kabupaten_Ogan_Komering_Ulu.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ogan_Komering_Ulu_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Ogan_Komering_Ulu_Selatan.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ogan_Komering_Ulu_Timur.csv for missing values
# Columns with missing values in Kabupaten_Ogan_Komering_Ulu_Timur.csv:
# photos    80
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pacitan.csv for missing values
# Columns with missing values in Kabupaten_Pacitan.csv:
# photos    136
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Padang_Lawas.csv for missing values
# Columns with missing values in Kabupaten_Padang_Lawas.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Padang_Lawas_Utara.csv for missing values
# Columns with missing values in Kabupaten_Padang_Lawas_Utara.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Padang_Pariaman.csv for missing values
# Columns with missing values in Kabupaten_Padang_Pariaman.csv:
# photos    39
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pakpak_Bharat.csv for missing values
# Columns with missing values in Kabupaten_Pakpak_Bharat.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pamekasan.csv for missing values
# Columns with missing values in Kabupaten_Pamekasan.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pandeglang.csv for missing values
# Columns with missing values in Kabupaten_Pandeglang.csv:
# photos    111
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pangandaran.csv for missing values
# Columns with missing values in Kabupaten_Pangandaran.csv:
# photos    69
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pangkajene_Dan_Kepulauan.csv for missing values
# Columns with missing values in Kabupaten_Pangkajene_Dan_Kepulauan.csv:
# photos    34
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Paniai.csv for missing values
# Columns with missing values in Kabupaten_Paniai.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Parigi_Moutong.csv for missing values
# Columns with missing values in Kabupaten_Parigi_Moutong.csv:
# photos    66
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pasaman.csv for missing values
# Columns with missing values in Kabupaten_Pasaman.csv:
# photos    40
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pasaman_Barat.csv for missing values
# Columns with missing values in Kabupaten_Pasaman_Barat.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Paser.csv for missing values
# Columns with missing values in Kabupaten_Paser.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pasuruan.csv for missing values
# Columns with missing values in Kabupaten_Pasuruan.csv:
# photos    94
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pati.csv for missing values
# Columns with missing values in Kabupaten_Pati.csv:
# photos    113
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pegunungan_Bintang.csv for missing values
# Columns with missing values in Kabupaten_Pegunungan_Bintang.csv:
# photos    13
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pekalongan.csv for missing values
# Columns with missing values in Kabupaten_Pekalongan.csv:
# photos    68
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pelalawan.csv for missing values
# Columns with missing values in Kabupaten_Pelalawan.csv:
# photos    51
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pemalang.csv for missing values
# Columns with missing values in Kabupaten_Pemalang.csv:
# photos    82
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Penajam_Paser_Utara.csv for missing values
# Columns with missing values in Kabupaten_Penajam_Paser_Utara.csv:
# photos    67
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Penukal_Abab_Lematang_Ilir.csv for missing values
# Columns with missing values in Kabupaten_Penukal_Abab_Lematang_Ilir.csv:
# photos    57
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pesawaran.csv for missing values
# Columns with missing values in Kabupaten_Pesawaran.csv:
# photos    80
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pesisir_Barat.csv for missing values
# Columns with missing values in Kabupaten_Pesisir_Barat.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pesisir_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Pesisir_Selatan.csv:
# photos    58
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pidie.csv for missing values
# Columns with missing values in Kabupaten_Pidie.csv:
# photos    83
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pidie_Jaya.csv for missing values
# Columns with missing values in Kabupaten_Pidie_Jaya.csv:
# photos    66
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pinrang.csv for missing values
# Columns with missing values in Kabupaten_Pinrang.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pohuwato.csv for missing values
# Columns with missing values in Kabupaten_Pohuwato.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Polewali_Mandar.csv for missing values
# Columns with missing values in Kabupaten_Polewali_Mandar.csv:
# photos    53
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Ponorogo.csv for missing values
# Columns with missing values in Kabupaten_Ponorogo.csv:
# photos    118
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Poso.csv for missing values
# Columns with missing values in Kabupaten_Poso.csv:
# photos    40
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pringsewu.csv for missing values
# Columns with missing values in Kabupaten_Pringsewu.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Probolinggo.csv for missing values
# Columns with missing values in Kabupaten_Probolinggo.csv:
# photos    107
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pulang_Pisau.csv for missing values
# Columns with missing values in Kabupaten_Pulang_Pisau.csv:
# photos    51
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Pulau_Morotai.csv for missing values
# Columns with missing values in Kabupaten_Pulau_Morotai.csv:
# photos    22
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Puncak.csv for missing values
# Columns with missing values in Kabupaten_Puncak.csv:
# photos    3
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Puncak_Jaya.csv for missing values
# Columns with missing values in Kabupaten_Puncak_Jaya.csv:
# photos    6
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Purbalingga.csv for missing values
# Columns with missing values in Kabupaten_Purbalingga.csv:
# photos    71
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Purwakarta.csv for missing values
# Columns with missing values in Kabupaten_Purwakarta.csv:
# photos    77
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Purworejo.csv for missing values
# Columns with missing values in Kabupaten_Purworejo.csv:
# photos    134
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Raja_Ampat.csv for missing values
# Columns with missing values in Kabupaten_Raja_Ampat.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Rembang.csv for missing values
# Columns with missing values in Kabupaten_Rembang.csv:
# photos    54
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Rokan_Hilir.csv for missing values
# Columns with missing values in Kabupaten_Rokan_Hilir.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Rokan_Hulu.csv for missing values
# Columns with missing values in Kabupaten_Rokan_Hulu.csv:
# photos    26
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Rote_Ndao.csv for missing values
# Columns with missing values in Kabupaten_Rote_Ndao.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sabu_Raijua.csv for missing values
# Columns with missing values in Kabupaten_Sabu_Raijua.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sambas.csv for missing values
# Columns with missing values in Kabupaten_Sambas.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Samosir.csv for missing values
# Columns with missing values in Kabupaten_Samosir.csv:
# photos    45
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sampang.csv for missing values
# Columns with missing values in Kabupaten_Sampang.csv:
# photos    54
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sanggau.csv for missing values
# Columns with missing values in Kabupaten_Sanggau.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sarmi.csv for missing values
# Columns with missing values in Kabupaten_Sarmi.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sarolangun.csv for missing values
# Columns with missing values in Kabupaten_Sarolangun.csv:
# photos    33
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Sekadau.csv for missing values
# Columns with missing values in Kabupaten_Sekadau.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Semarang.csv for missing values
# Columns with missing values in Kabupaten_Semarang.csv:
# photos    112
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Seram_Bagian_Barat.csv for missing values
# Columns with missing values in Kabupaten_Seram_Bagian_Barat.csv:
# photos    13
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Seram_Bagian_Timur.csv for missing values
# Columns with missing values in Kabupaten_Seram_Bagian_Timur.csv:
# photos    4
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Serang.csv for missing values
# Columns with missing values in Kabupaten_Serang.csv:
# photos    143
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Serdang_Bedagai.csv for missing values
# Columns with missing values in Kabupaten_Serdang_Bedagai.csv:
# photos    54
# ...
# photos    11
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Teluk_Wondama.csv for missing values
# Columns with missing values in Kabupaten_Teluk_Wondama.csv:
# photos    15
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Temanggung.csv for missing values
# Columns with missing values in Kabupaten_Temanggung.csv:
# photos    94
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Timor_Tengah_Selatan.csv for missing values
# Columns with missing values in Kabupaten_Timor_Tengah_Selatan.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Timor_Tengah_Utara.csv for missing values
# Columns with missing values in Kabupaten_Timor_Tengah_Utara.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Toba_Samosir.csv for missing values
# Columns with missing values in Kabupaten_Toba_Samosir.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Tojo_Una_Una.csv for missing values
# Columns with missing values in Kabupaten_Tojo_Una_Una.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Tolikara.csv for missing values
# Columns with missing values in Kabupaten_Tolikara.csv:
# photos    5
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Toli_Toli.csv for missing values
# Columns with missing values in Kabupaten_Toli_Toli.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Toraja_Utara.csv for missing values
# Columns with missing values in Kabupaten_Toraja_Utara.csv:
# photos    71
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Trenggalek.csv for missing values
# Columns with missing values in Kabupaten_Trenggalek.csv:
# photos    77
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Tuban.csv for missing values
# Columns with missing values in Kabupaten_Tuban.csv:
# photos    84
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Tulang_Bawang.csv for missing values
# Columns with missing values in Kabupaten_Tulang_Bawang.csv:
# photos    48
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Tulang_Bawang_Barat.csv for missing values
# Columns with missing values in Kabupaten_Tulang_Bawang_Barat.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Tulungagung.csv for missing values
# Columns with missing values in Kabupaten_Tulungagung.csv:
# photos    93
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Wajo.csv for missing values
# Columns with missing values in Kabupaten_Wajo.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Wakatobi.csv for missing values
# Columns with missing values in Kabupaten_Wakatobi.csv:
# photos    2
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Waropen.csv for missing values
# Columns with missing values in Kabupaten_Waropen.csv:
# photos    45
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Way_Kanan.csv for missing values
# Columns with missing values in Kabupaten_Way_Kanan.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Wonogiri.csv for missing values
# Columns with missing values in Kabupaten_Wonogiri.csv:
# photos    147
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Wonosobo.csv for missing values
# Columns with missing values in Kabupaten_Wonosobo.csv:
# photos    106
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Yahukimo.csv for missing values
# Columns with missing values in Kabupaten_Yahukimo.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kabupaten_Yalimo.csv for missing values
# Columns with missing values in Kabupaten_Yalimo.csv:
# photos    10
# dtype: int64
# Processing TA_DS_clean\Kab_Kepulauan_Seribu.csv for missing values
# Columns with missing values in Kab_Kepulauan_Seribu.csv:
# photos    9
# dtype: int64
# Processing TA_DS_clean\Kota_Ambon.csv for missing values
# Columns with missing values in Kota_Ambon.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kota_Balikpapan.csv for missing values
# Columns with missing values in Kota_Balikpapan.csv:
# photos    45
# dtype: int64
# Processing TA_DS_clean\Kota_Bandar_Lampung.csv for missing values
# Columns with missing values in Kota_Bandar_Lampung.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kota_Banda_Aceh.csv for missing values
# Columns with missing values in Kota_Banda_Aceh.csv:
# photos    16
# dtype: int64
# Processing TA_DS_clean\Kota_Bandung.csv for missing values
# Columns with missing values in Kota_Bandung.csv:
# photos    96
# dtype: int64
# Processing TA_DS_clean\Kota_Banjar.csv for missing values
# Columns with missing values in Kota_Banjar.csv:
# photos    28
# dtype: int64
# Processing TA_DS_clean\Kota_Banjarbaru.csv for missing values
# Columns with missing values in Kota_Banjarbaru.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kota_Banjarmasin.csv for missing values
# Columns with missing values in Kota_Banjarmasin.csv:
# photos    68
# dtype: int64
# Processing TA_DS_clean\Kota_Batam.csv for missing values
# Columns with missing values in Kota_Batam.csv:
# photos    93
# dtype: int64
# Processing TA_DS_clean\Kota_Batu.csv for missing values
# Columns with missing values in Kota_Batu.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kota_Baubau.csv for missing values
# Columns with missing values in Kota_Baubau.csv:
# photos    27
# dtype: int64
# Processing TA_DS_clean\Kota_Bekasi.csv for missing values
# Columns with missing values in Kota_Bekasi.csv:
# photos    49
# dtype: int64
# Processing TA_DS_clean\Kota_Biak.csv for missing values
# Columns with missing values in Kota_Biak.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kota_Bima.csv for missing values
# Columns with missing values in Kota_Bima.csv:
# photos    16
# dtype: int64
# Processing TA_DS_clean\Kota_Binjai.csv for missing values
# Columns with missing values in Kota_Binjai.csv:
# photos    15
# dtype: int64
# Processing TA_DS_clean\Kota_Bitung.csv for missing values
# Columns with missing values in Kota_Bitung.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kota_Blitar.csv for missing values
# Columns with missing values in Kota_Blitar.csv:
# photos    15
# dtype: int64
# Processing TA_DS_clean\Kota_Bogor.csv for missing values
# Columns with missing values in Kota_Bogor.csv:
# photos    46
# dtype: int64
# Processing TA_DS_clean\Kota_Bontang.csv for missing values
# Columns with missing values in Kota_Bontang.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kota_Bukittinggi.csv for missing values
# Columns with missing values in Kota_Bukittinggi.csv:
# photos    11
# dtype: int64
# Processing TA_DS_clean\Kota_Cilegon.csv for missing values
# Columns with missing values in Kota_Cilegon.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kota_Cimahi.csv for missing values
# Columns with missing values in Kota_Cimahi.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kota_Cirebon.csv for missing values
# Columns with missing values in Kota_Cirebon.csv:
# photos    13
# dtype: int64
# Processing TA_DS_clean\Kota_Denpasar.csv for missing values
# Columns with missing values in Kota_Denpasar.csv:
# photos    38
# dtype: int64
# Processing TA_DS_clean\Kota_Depok.csv for missing values
# Columns with missing values in Kota_Depok.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kota_Dumai.csv for missing values
# Columns with missing values in Kota_Dumai.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kota_Gorontalo.csv for missing values
# Columns with missing values in Kota_Gorontalo.csv:
# photos    32
# dtype: int64
# Processing TA_DS_clean\Kota_Jakarta_Barat.csv for missing values
# Columns with missing values in Kota_Jakarta_Barat.csv:
# photos    34
# dtype: int64
# Processing TA_DS_clean\Kota_Jakarta_Pusat.csv for missing values
# Columns with missing values in Kota_Jakarta_Pusat.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kota_Jakarta_Selatan.csv for missing values
# Columns with missing values in Kota_Jakarta_Selatan.csv:
# photos    60
# dtype: int64
# Processing TA_DS_clean\Kota_Jakarta_Timur.csv for missing values
# Columns with missing values in Kota_Jakarta_Timur.csv:
# photos    66
# dtype: int64
# Processing TA_DS_clean\Kota_Jakarta_Utara.csv for missing values
# Columns with missing values in Kota_Jakarta_Utara.csv:
# photos    43
# dtype: int64
# Processing TA_DS_clean\Kota_Jambi.csv for missing values
# Columns with missing values in Kota_Jambi.csv:
# photos    37
# dtype: int64
# Processing TA_DS_clean\Kota_Jayapura.csv for missing values
# Columns with missing values in Kota_Jayapura.csv:
# photos    61
# dtype: int64
# Processing TA_DS_clean\Kota_Kediri.csv for missing values
# Columns with missing values in Kota_Kediri.csv:
# photos    42
# dtype: int64
# Processing TA_DS_clean\Kota_Kendari.csv for missing values
# Columns with missing values in Kota_Kendari.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kota_Kupang.csv for missing values
# Columns with missing values in Kota_Kupang.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kota_Lubuklinggau.csv for missing values
# Columns with missing values in Kota_Lubuklinggau.csv:
# photos    10
# dtype: int64
# Processing TA_DS_clean\Kota_Madiun.csv for missing values
# Columns with missing values in Kota_Madiun.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kota_Magelang.csv for missing values
# Columns with missing values in Kota_Magelang.csv:
# photos    9
# dtype: int64
# Processing TA_DS_clean\Kota_Makassar.csv for missing values
# Columns with missing values in Kota_Makassar.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kota_Malang.csv for missing values
# Columns with missing values in Kota_Malang.csv:
# photos    30
# dtype: int64
# Processing TA_DS_clean\Kota_Mamuju.csv for missing values
# Columns with missing values in Kota_Mamuju.csv:
# photos    12
# dtype: int64
# Processing TA_DS_clean\Kota_Mamuju_Utara.csv for missing values
# Columns with missing values in Kota_Mamuju_Utara.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kota_Manado.csv for missing values
# Columns with missing values in Kota_Manado.csv:
# photos    45
# dtype: int64
# Processing TA_DS_clean\Kota_Mataram.csv for missing values
# Columns with missing values in Kota_Mataram.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kota_Medan.csv for missing values
# Columns with missing values in Kota_Medan.csv:
# photos    55
# dtype: int64
# Processing TA_DS_clean\Kota_Metro.csv for missing values
# Columns with missing values in Kota_Metro.csv:
# photos    13
# dtype: int64
# Processing TA_DS_clean\Kota_Mojokerto.csv for missing values
# Columns with missing values in Kota_Mojokerto.csv:
# photos    29
# dtype: int64
# Processing TA_DS_clean\Kota_Padang.csv for missing values
# Columns with missing values in Kota_Padang.csv:
# photos    65
# dtype: int64
# Processing TA_DS_clean\Kota_Padang_Panjang.csv for missing values
# Columns with missing values in Kota_Padang_Panjang.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kota_Pagar_Alam.csv for missing values
# Columns with missing values in Kota_Pagar_Alam.csv:
# photos    22
# dtype: int64
# Processing TA_DS_clean\Kota_Palangka_Raya.csv for missing values
# Columns with missing values in Kota_Palangka_Raya.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kota_Palembang.csv for missing values
# Columns with missing values in Kota_Palembang.csv:
# photos    70
# dtype: int64
# Processing TA_DS_clean\Kota_Palopo.csv for missing values
# Columns with missing values in Kota_Palopo.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kota_Palu.csv for missing values
# Columns with missing values in Kota_Palu.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kota_Pangkal_Pinang.csv for missing values
# Columns with missing values in Kota_Pangkal_Pinang.csv:
# photos    26
# dtype: int64
# Processing TA_DS_clean\Kota_Parepare.csv for missing values
# Columns with missing values in Kota_Parepare.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kota_Pariaman.csv for missing values
# Columns with missing values in Kota_Pariaman.csv:
# photos    22
# dtype: int64
# Processing TA_DS_clean\Kota_Pasuruan.csv for missing values
# Columns with missing values in Kota_Pasuruan.csv:
# photos    11
# dtype: int64
# Processing TA_DS_clean\Kota_Payakumbuh.csv for missing values
# Columns with missing values in Kota_Payakumbuh.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kota_Pekalongan.csv for missing values
# Columns with missing values in Kota_Pekalongan.csv:
# photos    21
# dtype: int64
# Processing TA_DS_clean\Kota_Pekanbaru.csv for missing values
# Columns with missing values in Kota_Pekanbaru.csv:
# photos    44
# dtype: int64
# Processing TA_DS_clean\Kota_Pematang_Siantar.csv for missing values
# Columns with missing values in Kota_Pematang_Siantar.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kota_Pontianak.csv for missing values
# Columns with missing values in Kota_Pontianak.csv:
# photos    26
# dtype: int64
# Processing TA_DS_clean\Kota_Prabumulih.csv for missing values
# Columns with missing values in Kota_Prabumulih.csv:
# photos    25
# dtype: int64
# Processing TA_DS_clean\Kota_Probolinggo.csv for missing values
# Columns with missing values in Kota_Probolinggo.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kota_Salatiga.csv for missing values
# Columns with missing values in Kota_Salatiga.csv:
# photos    12
# dtype: int64
# Processing TA_DS_clean\Kota_Samarinda.csv for missing values
# Columns with missing values in Kota_Samarinda.csv:
# photos    56
# dtype: int64
# Processing TA_DS_clean\Kota_Sawahlunto.csv for missing values
# Columns with missing values in Kota_Sawahlunto.csv:
# photos    18
# dtype: int64
# Processing TA_DS_clean\Kota_Semarang.csv for missing values
# Columns with missing values in Kota_Semarang.csv:
# photos    36
# dtype: int64
# Processing TA_DS_clean\Kota_Serang.csv for missing values
# Columns with missing values in Kota_Serang.csv:
# photos    33
# dtype: int64
# Processing TA_DS_clean\Kota_Singkawang.csv for missing values
# Columns with missing values in Kota_Singkawang.csv:
# photos    19
# dtype: int64
# Processing TA_DS_clean\Kota_Soe.csv for missing values
# Columns with missing values in Kota_Soe.csv:
# photos    15
# dtype: int64
# Processing TA_DS_clean\Kota_Sorong.csv for missing values
# Columns with missing values in Kota_Sorong.csv:
# photos    22
# dtype: int64
# Processing TA_DS_clean\Kota_Sukabumi.csv for missing values
# Columns with missing values in Kota_Sukabumi.csv:
# photos    23
# dtype: int64
# Processing TA_DS_clean\Kota_Surabaya.csv for missing values
# Columns with missing values in Kota_Surabaya.csv:
# photos    59
# dtype: int64
# Processing TA_DS_clean\Kota_Surakarta.csv for missing values
# Columns with missing values in Kota_Surakarta.csv:
# photos    17
# dtype: int64
# Processing TA_DS_clean\Kota_Taman.csv for missing values
# Columns with missing values in Kota_Taman.csv:
# photos    1
# dtype: int64
# Processing TA_DS_clean\Kota_Tangerang.csv for missing values
# Columns with missing values in Kota_Tangerang.csv:
# photos    62
# dtype: int64
# Processing TA_DS_clean\Kota_Tangerang_Selatan.csv for missing values
# Columns with missing values in Kota_Tangerang_Selatan.csv:
# photos    52
# dtype: int64
# Processing TA_DS_clean\Kota_Tanjungbalai.csv for missing values
# Columns with missing values in Kota_Tanjungbalai.csv:
# photos    20
# dtype: int64
# Processing TA_DS_clean\Kota_Tanjung_Pinang.csv for missing values
# Columns with missing values in Kota_Tanjung_Pinang.csv:
# photos    13
# dtype: int64
# Processing TA_DS_clean\Kota_Tarakan.csv for missing values
# Columns with missing values in Kota_Tarakan.csv:
# photos    24
# dtype: int64
# Processing TA_DS_clean\Kota_Tasikmalaya.csv for missing values
# Columns with missing values in Kota_Tasikmalaya.csv:
# photos    35
# dtype: int64
# Processing TA_DS_clean\Kota_Tebing_Tinggi.csv for missing values
# Columns with missing values in Kota_Tebing_Tinggi.csv:
# photos    31
# dtype: int64
# Processing TA_DS_clean\Kota_Tegal.csv for missing values
# Columns with missing values in Kota_Tegal.csv:
# photos    18
# dtype: int64
# Processing TA_DS_clean\Kota_Ternate.csv for missing values
# Columns with missing values in Kota_Ternate.csv:
# photos    16
# dtype: int64
# Processing TA_DS_clean\Kota_Tidore_Kepulauan.csv for missing values
# Columns with missing values in Kota_Tidore_Kepulauan.csv:
# photos    12
# dtype: int64
# Processing TA_DS_clean\Kota_Tomohon.csv for missing values
# Columns with missing values in Kota_Tomohon.csv:
# photos    39
# dtype: int64
# Processing TA_DS_clean\Kota_Tual.csv for missing values
# Columns with missing values in Kota_Tual.csv:
# photos    25
# dtype: int64
# Missing values check completed.
